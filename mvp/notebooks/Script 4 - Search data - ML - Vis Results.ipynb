# %% [markdown]
# # Search Data, ML analysis, Vis functions
# - Data from clinicaltrials.gov

# %%
import json, os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import nltk

# %% [markdown]
# ## Load working dataset with parsed information

# %%
# paths
path_to_json_file = os.path.abspath('../data/json/')

# 
#json file 
#
# json_file = '/all_parsed_data_json' 
json_file = '/sample_json' 
file = '{}{}.json'.format(path_to_json_file, json_file)

# load json file
df = pd.read_json(file)

# %%
df.head()
# Out:
#            nct_id study_first_submitted  \
# 0     NCT00058058         April 7, 2003
# 1     NCT01980602    September 24, 2013
# 10    NCT01277458      January 14, 2011
# 100   NCT01164891         July 16, 2010
# 1000  NCT03795727       January 3, 2019
#
#                                              source  \
# 0     American College of Radiology Imaging Network
# 1                                University of Hull
# 10                            Public Health England
# 100                               Hoffmann-La Roche
# 1000                               Cairo University
#
#                                             brief_title      overall_status  \
# 0     Magnetic Resonance Imaging in Women Recently D...           Completed
# 1     Effect of Exercise on Patients With Claudicati...      Unknown status
# 10    Ethnicity Data in HIV Positive Men Who Have Se...      Unknown status
# 100   A Pharmacokinetic and Metabolism Study of 14C-...           Completed
# ...
