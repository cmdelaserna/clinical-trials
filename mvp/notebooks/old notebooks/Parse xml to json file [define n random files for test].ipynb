# %% [markdown]
# # Clinical trials: Parse all XML files

# %%
#Data: clinicaltrials.gov

# %%
# reset variables and turn off autosave
# %reset
# %autosave 0

# %%
import zipfile
import sys
import time
import json
import re
import os
import xml.etree.ElementTree as ET
import shutil
import pandas as pd
from collections import Counter

# %%
# Print messages to the terminal

# sys.stdout = open('/dev/stdout', 'w')

# %% [markdown]
# ## Setup: create paths and folders

# %%
'''
Create paths and folders
'''

# Folders with xml files
path_to_all_xml_trials = os.path.abspath('../data/all_trials/')

# Test folder ~100 files
path_to_test_folder = os.path.abspath('../data/test/')

#Remove old files from test folder
try:
    shutil.rmtree(path_to_test_folder) 
except FileNotFoundError:
    pass

# Path for json folder
path_to_json_file = os.path.abspath('../data/json/')

# Variable for all parsed files
all_parsed_files = []

print('\nPaths and folders created\n')
# Out:
# Paths and folders created

# %%
# Create folders

create_folders_errors = []

def create_folders(paths=[]):
    for p in paths:
        try:
            os.mkdir(p)
            if p:
                print('{} created'.format(p))
        except IOError as e:
            create_folders_errors.append(e)
            pass

    print('\nSetup folders created with exceptions: {}\n'.format(create_folders_errors))
    
all_folders = [path_to_all_xml_trials, path_to_test_folder, path_to_json_file]
    
# create folders
create_folders(all_folders)
# Out:
# /Users/cmserna/Sites/clinical trials/mvp/data/test created
#
# Setup folders created with exceptions: [FileExistsError(17, 'File exists'), FileExistsError(17, 'File exists')]

# %% [markdown]
# ### Create test folder with n random files

# %%
'''
Select n random files from all trials and save them in test folder
'''
files_for_test = 1000

import random

# Pending: If files in test folder, delete them
random_files = []
random_files = random.sample(os.listdir(path_to_all_xml_trials), files_for_test)
print('Random files: {}'.format(len(random_files)))

for f in random_files:
    src = os.path.join(path_to_all_xml_trials, f)
    shutil.copy(src, path_to_test_folder)
# Out:
# Random files: 1000

# %%
print(random_files[0:5])
# Out:
# ['NCT03703011.xml', 'NCT00718315.xml', 'NCT03652753.xml', 'NCT03403504.xml', 'NCT01145014.xml']

# %% [markdown]
# ## Parse xml files

# %%
'''
Parse all xml files and save them in a all_parsed_files variable.
Slow. Checks for xml files
'''

def parse_xml_files(path_to_folder):
    for filename in os.listdir(path_to_folder):
#         if not filename.endswith('.xml'): continue
        fullname = os.path.join(path_to_folder, filename)
        all_parsed_files.append(ET.parse(fullname).getroot())
        
        # Checking message to the terminal
        print("{} file parsed\n".format(fullname))

    print('Number of files parsed: {}\n'.format(len(all_parsed_files)))
        
    return all_parsed_files

# %%
# Run function
all_parsed_files.clear()
# %time parse_xml_files(path_to_test_folder)
# Out:
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02802423.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02278575.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00921440.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03706820.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00913380.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02079610.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03103295.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01998529.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02785419.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03372629.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01600157.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01466530.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03195036.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02941042.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03040804.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02704715.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00881543.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03334734.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02019537.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01781273.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02772640.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00582400.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01480102.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00158886.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02390817.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01643330.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02515461.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02386709.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01933542.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01373944.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01547104.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00452634.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03561584.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03580746.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03142828.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03442413.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00247260.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02221011.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00005996.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01860495.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02152696.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00779025.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02501005.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00746564.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03696017.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03526744.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00005148.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03428594.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01247571.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02584231.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02403362.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01813916.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02885571.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03185754.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03380858.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02652624.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00543842.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01213875.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03465319.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03635580.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02721186.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03416322.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01521650.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02823808.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03007225.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00425737.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00931320.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01629511.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01401231.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03334864.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02823613.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01369498.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01914289.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03190824.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00121017.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01595295.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01226576.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03138837.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02431715.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02047474.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02796274.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03494725.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02664753.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00305045.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02738762.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00760370.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00548444.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02072356.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00805324.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02459873.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00899119.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03661099.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00173355.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03240276.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02448758.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03675984.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01380171.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01249365.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02987205.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03583099.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02091557.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02899013.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02117726.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03637023.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01284101.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01219036.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02035020.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01346254.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02144168.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03403504.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02687581.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02125409.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03470298.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02624570.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01233973.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00377559.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00357851.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03414905.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02645617.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03133195.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00071812.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01369472.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03357497.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00581269.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00313222.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00904826.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02817789.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00064012.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00340691.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00119990.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02333006.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01474330.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03089814.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01018784.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01378962.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03266666.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00603759.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02360670.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01788319.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01117662.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00337623.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01219608.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00735228.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00216606.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02101593.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03744988.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03455829.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02144636.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02991885.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02273778.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01094392.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01677520.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03062527.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02948699.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00465712.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00579449.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01023841.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02534324.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03093051.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03695653.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01938404.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00229970.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01300013.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00323284.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02245750.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00033007.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00887445.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01056549.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01704040.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00004654.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02301338.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02769273.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02946879.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01417286.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02083432.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03049748.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02965118.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02505503.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02709395.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02850835.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01846520.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01058148.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02638376.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02601508.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03106467.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00643630.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01071928.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03427138.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01202942.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00754416.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01239732.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01740947.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02926235.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03550417.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02439788.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01304316.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02864589.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02262702.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00951405.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01229904.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00839020.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01793909.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01787968.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00858390.xml file parsed
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03729583.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02423317.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00624520.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02976012.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02982187.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02717234.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02524652.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00471770.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01230892.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00237224.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02198560.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00462917.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00131612.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02459652.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03773458.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03297515.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01038245.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00000394.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02524860.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01708889.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02219789.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00480207.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03548649.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03599206.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00874055.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02428257.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00368251.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00722839.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03766295.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03164746.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01386658.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01546155.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03593850.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02326155.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01583023.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02282436.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01876147.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03422094.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01167608.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01782352.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00795275.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00372619.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02851043.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03462329.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01847365.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03241082.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00005472.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02101086.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00020631.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03009240.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03162393.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00296088.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00323141.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03471130.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00483184.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00812214.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03684317.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03659604.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03446950.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01264692.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01675232.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03284645.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02123186.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00908310.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00837876.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00738153.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03735641.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00288301.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01798966.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02729155.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01686594.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00503633.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01731262.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00991900.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00955201.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02054871.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01416467.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01500577.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03463681.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02209259.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03317366.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00897182.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01808560.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00800215.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03688100.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01871935.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00527579.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01945879.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02628262.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02732548.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03693911.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02160041.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00013832.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02044861.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00818116.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02908568.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01719510.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00888277.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00002863.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02105961.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00061308.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02073175.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00207753.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02413489.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01419392.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00355940.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03587857.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02785692.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00939523.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03157856.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02372006.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01043055.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01967953.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02330237.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01948973.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03214731.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01513681.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00725920.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01366079.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00894933.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00636753.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01750853.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02206815.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00596830.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02133157.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02969369.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00558350.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03677882.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02793193.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03442881.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01760239.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02065310.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01495988.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02243384.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02954770.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00434512.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00957372.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00716079.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00857831.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00344721.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00947388.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00534937.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00281333.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01448733.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03051607.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03741673.xml file parsed
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00784719.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02368288.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03266198.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02978885.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03602170.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00978965.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03652753.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01022866.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03172182.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00534664.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00371163.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00352547.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01388374.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02117180.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02995070.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03396900.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01423227.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02384967.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00326573.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00030381.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02219139.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03481010.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00736554.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00006196.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03519711.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02872610.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01341158.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02815462.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00806273.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00035789.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00507533.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01102595.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02805842.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01073436.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00001202.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02596282.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00422604.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02209909.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00593554.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01756599.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02723318.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02575469.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01054300.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00732875.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03603652.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03548402.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03514355.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01545011.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01074749.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01369979.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01658748.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02945644.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00578721.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03067818.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01123837.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03532191.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02835638.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01398228.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03636373.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01885468.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00885027.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03005535.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03445494.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00141141.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03488394.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00568724.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02698202.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00679068.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00971763.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00381524.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01937351.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02923674.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01708590.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02109185.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00634140.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01438372.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00444392.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03742960.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03163511.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01765556.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01272544.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01144728.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02776085.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01897454.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01124786.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03706677.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02075099.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00356083.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01859663.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02896556.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00373217.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02762019.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03458000.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03208478.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01971892.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02522650.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03463525.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01205282.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00321009.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03706339.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03415464.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02059798.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01060449.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01610518.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03245801.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02506686.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02901574.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00713310.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00043797.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03497507.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02590627.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01634451.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01304017.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02367976.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00789776.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03009669.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01818011.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03772080.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03668782.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01989052.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03099252.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02317705.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03020238.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02447341.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00532818.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03125369.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03182101.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01532258.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01995877.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02451046.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03380221.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01589627.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00674375.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03617341.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01202513.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00917397.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01733277.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03022994.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01716975.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02014896.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03318497.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01951014.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02073825.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02581475.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01391637.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03294122.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01117415.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00541970.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01578200.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00000271.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03035942.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03712618.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00380393.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01928069.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00591760.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01582347.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00598988.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03112655.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02750514.xml file parsed
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00718315.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01886755.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02306200.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01210898.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00003585.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00023127.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00056433.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01145014.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01987271.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01806948.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01993589.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03727516.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02317523.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00577187.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00774813.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01727804.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03419871.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00986050.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03528460.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00910026.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03729739.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03608085.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01504724.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01287104.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01050829.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03317353.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03407469.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00771017.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02994238.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02858154.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01184339.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00150241.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02296996.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02513251.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00823823.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01582971.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03508362.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02630550.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02337751.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03564509.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00214929.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00885612.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03393494.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00795756.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02147795.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01885936.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03556020.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01220219.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03770936.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00112892.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03518359.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03637699.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01099020.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00005646.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02404129.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03024333.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01720563.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03495531.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02499744.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01247727.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00445042.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02062073.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00300989.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00524537.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02948153.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00379457.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02201381.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00343720.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00070434.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00656864.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03670303.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02692911.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01767012.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02520869.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00002277.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00614666.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02322996.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02156063.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00852202.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02676856.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03258320.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03200639.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00888095.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02343367.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00275912.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02086097.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00399776.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02582775.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03067155.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00719394.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01542983.xml file parsed
#
# ...
#  <Element 'clinical_study' at 0x115a9d408>,
#  <Element 'clinical_study' at 0x115aabdb8>,
#  <Element 'clinical_study' at 0x115abc688>,
#  <Element 'clinical_study' at 0x115ac5958>,
#  <Element 'clinical_study' at 0x115ae7728>,
#  <Element 'clinical_study' at 0x115af1f98>,
#  <Element 'clinical_study' at 0x115b059f8>,
#  <Element 'clinical_study' at 0x115b15048>,
#  <Element 'clinical_study' at 0x115b1f868>,
#  <Element 'clinical_study' at 0x115b2df48>,
#  <Element 'clinical_study' at 0x115b45ea8>,
#  <Element 'clinical_study' at 0x115b54a48>,
#  <Element 'clinical_study' at 0x115b5de08>,
#  <Element 'clinical_study' at 0x115b72048>,
#  <Element 'clinical_study' at 0x115b85368>,
#  <Element 'clinical_study' at 0x115b96688>,
#  <Element 'clinical_study' at 0x115ba9408>,
#  <Element 'clinical_study' at 0x115bb2a98>,
#  <Element 'clinical_study' at 0x115bc13b8>,
#  <Element 'clinical_study' at 0x115bc8b88>,
#  <Element 'clinical_study' at 0x115be01d8>,
#  <Element 'clinical_study' at 0x115beca48>,
#  <Element 'clinical_study' at 0x115d5a0e8>,
#  <Element 'clinical_study' at 0x115d5e868>,
#  <Element 'clinical_study' at 0x115d697c8>,
#  <Element 'clinical_study' at 0x115d72548>,
#  <Element 'clinical_study' at 0x115d7ca98>,
#  <Element 'clinical_study' at 0x115d87c78>,
#  <Element 'clinical_study' at 0x115d97368>,
#  <Element 'clinical_study' at 0x115d9f408>,
#  <Element 'clinical_study' at 0x115dc5138>,
#  <Element 'clinical_study' at 0x115dd2e08>,
#  <Element 'clinical_study' at 0x115de2458>,
#  <Element 'clinical_study' at 0x115df3548>,
#  <Element 'clinical_study' at 0x115e03958>,
#  <Element 'clinical_study' at 0x115e0fdb8>,
#  <Element 'clinical_study' at 0x115e57598>,
#  <Element 'clinical_study' at 0x115e88a98>,
#  <Element 'clinical_study' at 0x115e90ea8>,
#  <Element 'clinical_study' at 0x115ec91d8>,
#  <Element 'clinical_study' at 0x115ed9228>,
#  <Element 'clinical_study' at 0x115ee2098>,
#  <Element 'clinical_study' at 0x115eed868>,
#  <Element 'clinical_study' at 0x115ef8368>,
#  <Element 'clinical_study' at 0x115f05598>,
#  <Element 'clinical_study' at 0x115f160e8>,
#  <Element 'clinical_study' at 0x115f24778>,
#  <Element 'clinical_study' at 0x115f335e8>,
#  <Element 'clinical_study' at 0x115f443b8>,
#  <Element 'clinical_study' at 0x115f50c78>,
#  <Element 'clinical_study' at 0x115f5b908>,
#  <Element 'clinical_study' at 0x115f62cc8>,
#  <Element 'clinical_study' at 0x115f6ef98>,
#  <Element 'clinical_study' at 0x115f77db8>,
#  <Element 'clinical_study' at 0x115f809f8>,
#  <Element 'clinical_study' at 0x115f8fcc8>,
#  <Element 'clinical_study' at 0x115f9f048>,
#  <Element 'clinical_study' at 0x115fb1f98>,
#  <Element 'clinical_study' at 0x115fc1e58>,
#  <Element 'clinical_study' at 0x115fd2408>,
#  <Element 'clinical_study' at 0x116073a98>,
#  <Element 'clinical_study' at 0x116087548>,
#  <Element 'clinical_study' at 0x11609cc78>,
#  <Element 'clinical_study' at 0x1160aae58>,
#  <Element 'clinical_study' at 0x1160b4b88>,
#  <Element 'clinical_study' at 0x1160bcf48>,
#  <Element 'clinical_study' at 0x1160d1098>,
#  <Element 'clinical_study' at 0x1160e0ef8>,
#  <Element 'clinical_study' at 0x1160eec28>,
#  <Element 'clinical_study' at 0x1160eebd8>,
#  <Element 'clinical_study' at 0x116104188>,
#  <Element 'clinical_study' at 0x11610f548>,
#  <Element 'clinical_study' at 0x11611a818>,
#  <Element 'clinical_study' at 0x11612f7c8>,
#  <Element 'clinical_study' at 0x116137278>,
#  <Element 'clinical_study' at 0x116140548>,
#  <Element 'clinical_study' at 0x1161502c8>,
#  <Element 'clinical_study' at 0x116160e58>,
#  <Element 'clinical_study' at 0x1161686d8>,
#  <Element 'clinical_study' at 0x1161736d8>,
#  <Element 'clinical_study' at 0x116182778>,
#  <Element 'clinical_study' at 0x11618ecc8>,
#  <Element 'clinical_study' at 0x1161989f8>,
#  <Element 'clinical_study' at 0x1161a9958>,
#  <Element 'clinical_study' at 0x1161b1f48>,
#  <Element 'clinical_study' at 0x1161c1458>,
#  <Element 'clinical_study' at 0x1161cac28>,
#  <Element 'clinical_study' at 0x1161d5908>,
#  <Element 'clinical_study' at 0x1161dfbd8>,
#  <Element 'clinical_study' at 0x1161ee138>,
#  <Element 'clinical_study' at 0x1161fdc28>,
#  <Element 'clinical_study' at 0x116205818>,
#  <Element 'clinical_study' at 0x1162106d8>,
#  <Element 'clinical_study' at 0x11622c638>,
#  <Element 'clinical_study' at 0x11623ec28>,
#  <Element 'clinical_study' at 0x1162464f8>,
#  <Element 'clinical_study' at 0x116251ae8>,
#  <Element 'clinical_study' at 0x116262638>,
#  <Element 'clinical_study' at 0x116270188>,
#  <Element 'clinical_study' at 0x1162a26d8>,
#  <Element 'clinical_study' at 0x1162b1f48>,
#  <Element 'clinical_study' at 0x1162c1408>,
#  <Element 'clinical_study' at 0x1162d3228>,
#  <Element 'clinical_study' at 0x1162dcb88>,
#  <Element 'clinical_study' at 0x1162ea9f8>,
#  <Element 'clinical_study' at 0x1163044f8>,
#  <Element 'clinical_study' at 0x11630f458>,
#  <Element 'clinical_study' at 0x116323638>,
#  <Element 'clinical_study' at 0x116331408>,
#  <Element 'clinical_study' at 0x11633ac78>,
#  <Element 'clinical_study' at 0x116343958>,
#  <Element 'clinical_study' at 0x116354ef8>,
#  <Element 'clinical_study' at 0x11635fb88>,
#  <Element 'clinical_study' at 0x116369958>,
#  <Element 'clinical_study' at 0x116377b88>,
#  <Element 'clinical_study' at 0x116383b38>,
#  <Element 'clinical_study' at 0x116399368>,
#  <Element 'clinical_study' at 0x1163a2bd8>,
#  <Element 'clinical_study' at 0x1163b5228>,
#  <Element 'clinical_study' at 0x1163bec78>,
#  <Element 'clinical_study' at 0x1163cc188>,
#  <Element 'clinical_study' at 0x1163df5e8>,
#  <Element 'clinical_study' at 0x116421b38>,
#  <Element 'clinical_study' at 0x116430228>,
#  <Element 'clinical_study' at 0x116482d18>,
#  <Element 'clinical_study' at 0x1164ed8b8>,
#  <Element 'clinical_study' at 0x116527d18>,
#  <Element 'clinical_study' at 0x116538318>,
#  <Element 'clinical_study' at 0x116545868>,
#  <Element 'clinical_study' at 0x116558b38>,
#  <Element 'clinical_study' at 0x11657dc28>,
#  <Element 'clinical_study' at 0x11658a048>,
#  <Element 'clinical_study' at 0x11659b598>,
#  <Element 'clinical_study' at 0x1165ac098>,
#  <Element 'clinical_study' at 0x1165b2b88>,
#  <Element 'clinical_study' at 0x1165bd818>,
#  <Element 'clinical_study' at 0x1165c8598>,
#  <Element 'clinical_study' at 0x1165d90e8>,
#  <Element 'clinical_study' at 0x116628f98>,
#  <Element 'clinical_study' at 0x11663a408>,
#  <Element 'clinical_study' at 0x116644ef8>,
#  <Element 'clinical_study' at 0x11664fe58>,
#  <Element 'clinical_study' at 0x116654728>,
#  <Element 'clinical_study' at 0x1166618b8>,
#  <Element 'clinical_study' at 0x11667aae8>,
#  <Element 'clinical_study' at 0x1166bcb38>,
#  <Element 'clinical_study' at 0x1166c8d68>,
#  <Element 'clinical_study' at 0x1166db2c8>,
#  <Element 'clinical_study' at 0x1166e36d8>,
#  <Element 'clinical_study' at 0x1166ef7c8>,
#  <Element 'clinical_study' at 0x116709278>,
#  <Element 'clinical_study' at 0x116716cc8>,
#  <Element 'clinical_study' at 0x116763368>,
#  <Element 'clinical_study' at 0x11678dae8>,
#  <Element 'clinical_study' at 0x1167a3278>,
#  <Element 'clinical_study' at 0x1167d39f8>,
#  <Element 'clinical_study' at 0x1167dfea8>,
#  <Element 'clinical_study' at 0x1167f0908>,
#  <Element 'clinical_study' at 0x1167fee58>,
#  <Element 'clinical_study' at 0x1168453b8>,
#  <Element 'clinical_study' at 0x1168829a8>,
#  <Element 'clinical_study' at 0x116891228>,
#  <Element 'clinical_study' at 0x11689b188>,
#  <Element 'clinical_study' at 0x11691a9a8>,
#  <Element 'clinical_study' at 0x11692b548>,
#  <Element 'clinical_study' at 0x1169348b8>,
#  <Element 'clinical_study' at 0x11694e958>,
#  <Element 'clinical_study' at 0x11695c048>,
#  <Element 'clinical_study' at 0x1169a2048>,
#  <Element 'clinical_study' at 0x1169ad728>,
#  <Element 'clinical_study' at 0x1169ba6d8>,
#  <Element 'clinical_study' at 0x1169ccd18>,
#  <Element 'clinical_study' at 0x1169fab38>,
#  <Element 'clinical_study' at 0x116a35b88>,
#  <Element 'clinical_study' at 0x116a47368>,
#  <Element 'clinical_study' at 0x116a69868>,
#  <Element 'clinical_study' at 0x116a71cc8>,
#  <Element 'clinical_study' at 0x116a83638>,
#  <Element 'clinical_study' at 0x116a8d778>,
#  <Element 'clinical_study' at 0x116ab82c8>,
#  <Element 'clinical_study' at 0x116b2b9a8>,
#  <Element 'clinical_study' at 0x116b3ab38>,
#  <Element 'clinical_study' at 0x116b648b8>,
#  <Element 'clinical_study' at 0x116b709f8>,
#  <Element 'clinical_study' at 0x116b7cb38>,
#  <Element 'clinical_study' at 0x116b8aef8>,
#  <Element 'clinical_study' at 0x116dc4188>,
#  <Element 'clinical_study' at 0x116dcc8b8>,
#  <Element 'clinical_study' at 0x116ddfc78>,
#  <Element 'clinical_study' at 0x116dea908>,
#  <Element 'clinical_study' at 0x116dfdb38>,
#  <Element 'clinical_study' at 0x116e119f8>,
#  <Element 'clinical_study' at 0x116e21ae8>,
#  <Element 'clinical_study' at 0x116e29bd8>,
#  <Element 'clinical_study' at 0x116e61778>,
#  <Element 'clinical_study' at 0x116e6bbd8>,
#  <Element 'clinical_study' at 0x116e88278>,
#  <Element 'clinical_study' at 0x116e96048>,
#  <Element 'clinical_study' at 0x116ec3138>,
#  <Element 'clinical_study' at 0x116ec8e58>,
#  <Element 'clinical_study' at 0x116edbe58>,
#  <Element 'clinical_study' at 0x116ee8728>,
#  <Element 'clinical_study' at 0x116ef97c8>,
#  <Element 'clinical_study' at 0x116f0a318>,
#  <Element 'clinical_study' at 0x116f13e08>,
#  <Element 'clinical_study' at 0x116f48b38>,
#  <Element 'clinical_study' at 0x116f557c8>,
#  <Element 'clinical_study' at 0x116f55778>,
#  <Element 'clinical_study' at 0x116f72548>,
#  <Element 'clinical_study' at 0x116f82278>,
#  <Element 'clinical_study' at 0x116f8a2c8>,
#  <Element 'clinical_study' at 0x116f951d8>,
#  <Element 'clinical_study' at 0x116fabd68>,
#  <Element 'clinical_study' at 0x116fe7818>,
#  <Element 'clinical_study' at 0x116fede58>,
#  <Element 'clinical_study' at 0x117000d18>,
#  <Element 'clinical_study' at 0x117018638>,
#  <Element 'clinical_study' at 0x1173ea1d8>,
#  <Element 'clinical_study' at 0x1173f7458>,
#  <Element 'clinical_study' at 0x117406ae8>,
#  <Element 'clinical_study' at 0x117414318>,
#  <Element 'clinical_study' at 0x117418c78>,
#  <Element 'clinical_study' at 0x117424958>,
#  <Element 'clinical_study' at 0x117435318>,
#  <Element 'clinical_study' at 0x11743e2c8>,
#  <Element 'clinical_study' at 0x11744b3b8>,
#  <Element 'clinical_study' at 0x117454408>,
#  <Element 'clinical_study' at 0x117466ef8>,
#  <Element 'clinical_study' at 0x117475188>,
#  <Element 'clinical_study' at 0x117480b38>,
#  <Element 'clinical_study' at 0x11748a458>,
#  <Element 'clinical_study' at 0x1174a8c78>,
#  <Element 'clinical_study' at 0x1174b2ae8>,
#  <Element 'clinical_study' at 0x1174c1408>,
#  <Element 'clinical_study' at 0x1174cf0e8>,
#  <Element 'clinical_study' at 0x1175a4bd8>,
#  <Element 'clinical_study' at 0x1175cdf48>,
#  <Element 'clinical_study' at 0x1175d7548>,
#  <Element 'clinical_study' at 0x1175f1f48>,
#  <Element 'clinical_study' at 0x11760ac28>,
#  <Element 'clinical_study' at 0x117615868>,
#  <Element 'clinical_study' at 0x117623958>,
#  <Element 'clinical_study' at 0x1176337c8>,
#  <Element 'clinical_study' at 0x117648f98>,
#  <Element 'clinical_study' at 0x117655598>,
#  <Element 'clinical_study' at 0x117666458>,
#  <Element 'clinical_study' at 0x1176b8368>,
#  <Element 'clinical_study' at 0x1176c3bd8>,
#  <Element 'clinical_study' at 0x117804bd8>,
#  <Element 'clinical_study' at 0x1178114a8>,
#  <Element 'clinical_study' at 0x11781cc28>,
#  <Element 'clinical_study' at 0x11782f098>,
#  <Element 'clinical_study' at 0x11783bd68>,
#  <Element 'clinical_study' at 0x11784d138>,
#  <Element 'clinical_study' at 0x117859318>,
#  <Element 'clinical_study' at 0x117864a98>,
#  <Element 'clinical_study' at 0x11787a5e8>,
#  <Element 'clinical_study' at 0x117897138>,
#  <Element 'clinical_study' at 0x11789cf48>,
#  <Element 'clinical_study' at 0x117949db8>,
#  <Element 'clinical_study' at 0x1179650e8>,
#  <Element 'clinical_study' at 0x11796ab88>,
#  <Element 'clinical_study' at 0x117974688>,
#  <Element 'clinical_study' at 0x11797bc78>,
#  <Element 'clinical_study' at 0x117985908>,
#  <Element 'clinical_study' at 0x11799db38>,
#  <Element 'clinical_study' at 0x1179a7a98>,
#  <Element 'clinical_study' at 0x1179b8548>,
#  <Element 'clinical_study' at 0x1179c26d8>,
#  <Element 'clinical_study' at 0x1179cdb38>,
#  <Element 'clinical_study' at 0x1179d3048>,
#  <Element 'clinical_study' at 0x1179f1a98>,
#  <Element 'clinical_study' at 0x1179fa688>,
#  <Element 'clinical_study' at 0x117a0f138>,
#  <Element 'clinical_study' at 0x117a22228>,
#  <Element 'clinical_study' at 0x117a2bc28>,
#  <Element 'clinical_study' at 0x117a43bd8>,
#  <Element 'clinical_study' at 0x117a66728>,
#  <Element 'clinical_study' at 0x117a70e08>,
#  <Element 'clinical_study' at 0x117a7bea8>,
#  <Element 'clinical_study' at 0x117aab728>,
#  <Element 'clinical_study' at 0x117ab9278>,
#  <Element 'clinical_study' at 0x117ad2cc8>,
#  <Element 'clinical_study' at 0x117ae2818>,
#  <Element 'clinical_study' at 0x117aee368>,
#  <Element 'clinical_study' at 0x117bc1228>,
#  <Element 'clinical_study' at 0x117bc50e8>,
#  <Element 'clinical_study' at 0x117bceb38>,
#  <Element 'clinical_study' at 0x117bdfd68>,
#  <Element 'clinical_study' at 0x117bef7c8>,
#  <Element 'clinical_study' at 0x117bff188>,
#  <Element 'clinical_study' at 0x117c08688>,
#  <Element 'clinical_study' at 0x117c165e8>,
#  <Element 'clinical_study' at 0x117c23b88>,
#  <Element 'clinical_study' at 0x117c34408>,
#  <Element 'clinical_study' at 0x117c3e1d8>,
#  <Element 'clinical_study' at 0x117c44f48>,
#  <Element 'clinical_study' at 0x117c58048>,
#  <Element 'clinical_study' at 0x117c5f9a8>,
#  <Element 'clinical_study' at 0x117ce97c8>,
#  <Element 'clinical_study' at 0x117cf2bd8>,
#  <Element 'clinical_study' at 0x117d09228>,
#  <Element 'clinical_study' at 0x117d208b8>,
#  <Element 'clinical_study' at 0x117d2d5e8>,
#  <Element 'clinical_study' at 0x117d3dbd8>,
#  <Element 'clinical_study' at 0x117d46958>,
#  <Element 'clinical_study' at 0x117d53cc8>,
#  <Element 'clinical_study' at 0x117d658b8>,
#  <Element 'clinical_study' at 0x117d6c868>,
#  <Element 'clinical_study' at 0x117d77728>,
#  <Element 'clinical_study' at 0x117d90598>,
#  <Element 'clinical_study' at 0x117d99278>,
#  <Element 'clinical_study' at 0x117da46d8>,
#  <Element 'clinical_study' at 0x117dae7c8>,
#  <Element 'clinical_study' at 0x117db8778>,
#  <Element 'clinical_study' at 0x117e4b4a8>,
#  <Element 'clinical_study' at 0x117e5f548>,
#  <Element 'clinical_study' at 0x117e731d8>,
#  <Element 'clinical_study' at 0x117e80638>,
#  <Element 'clinical_study' at 0x117e934f8>,
#  <Element 'clinical_study' at 0x117e9d4f8>,
#  <Element 'clinical_study' at 0x117ea7408>,
#  <Element 'clinical_study' at 0x117eb64f8>,
#  <Element 'clinical_study' at 0x117ebbd68>,
#  <Element 'clinical_study' at 0x117ecb1d8>,
#  <Element 'clinical_study' at 0x117ed7138>,
#  <Element 'clinical_study' at 0x117ee4b38>,
#  <Element 'clinical_study' at 0x117efdf98>,
#  <Element 'clinical_study' at 0x117f0d318>,
#  <Element 'clinical_study' at 0x117f157c8>,
#  <Element 'clinical_study' at 0x117f24818>,
#  <Element 'clinical_study' at 0x117f3b318>,
#  <Element 'clinical_study' at 0x117f51048>,
#  <Element 'clinical_study' at 0x117f58ea8>,
#  <Element 'clinical_study' at 0x117f68a48>,
#  <Element 'clinical_study' at 0x117f784f8>,
#  <Element 'clinical_study' at 0x117f7eef8>,
#  <Element 'clinical_study' at 0x117fa3688>,
#  <Element 'clinical_study' at 0x117fae818>,
#  <Element 'clinical_study' at 0x117fc3d18>,
#  <Element 'clinical_study' at 0x117fd48b8>,
#  <Element 'clinical_study' at 0x117fe3728>,
#  <Element 'clinical_study' at 0x117feb598>,
#  <Element 'clinical_study' at 0x117ff7a98>,
#  <Element 'clinical_study' at 0x117ffeef8>,
#  <Element 'clinical_study' at 0x11800bea8>,
#  <Element 'clinical_study' at 0x1180143b8>,
#  <Element 'clinical_study' at 0x1180263b8>,
#  <Element 'clinical_study' at 0x118031638>,
#  <Element 'clinical_study' at 0x11807df98>,
#  <Element 'clinical_study' at 0x11808f818>,
#  <Element 'clinical_study' at 0x11809f0e8>,
#  <Element 'clinical_study' at 0x1180a9908>,
#  <Element 'clinical_study' at 0x1180b4598>,
#  <Element 'clinical_study' at 0x11819dcc8>,
#  <Element 'clinical_study' at 0x1181ac228>,
#  <Element 'clinical_study' at 0x1181bcea8>,
#  <Element 'clinical_study' at 0x118279868>,
#  <Element 'clinical_study' at 0x118279818>,
#  <Element 'clinical_study' at 0x11836bef8>,
#  <Element 'clinical_study' at 0x118373688>,
#  <Element 'clinical_study' at 0x11837f688>,
#  <Element 'clinical_study' at 0x11838a5e8>]

# %%
print(len(all_parsed_files))
# Out:
# 1000

# %% [markdown]
# ## Extract tags from parsed trials

# %%
# Dictionary to hold all data
all_data_dictionary = {}

# Final json file
json_file = '/all_trials_json' #name json file  

print('\nCreated dictionary and path to json file\n')
# Out:
# Created dictionary and path to json file

# %% [markdown]
# ### Parse tags in files

# %%
'''
Find values by unique tags in XML files 
Save them in a dictionary 
Export them to a json file
'''

def create_dictionary_from_tag(tag, parsed_files = all_parsed_files, name_dictionary = all_data_dictionary):
    
    # Variable to store values
    keys = []
    values = []
    
    # Iterate through all xml parsed files and tags, and append data to values
    for n in parsed_files:
        for i in n.iter(tag):
            if i.text != 0:
                values.append(i.text)
            else:
                values.append('nan') #get values
                # Checking message to the terminal
            print("{} file parsed\n".format(i.text))
    
    # Create dictionary and set tags as keys
    name_dictionary.setdefault(tag, [])
    
    # Append values to dictionary
    for i in values:
        name_dictionary[tag].append(i)
        print("{} file added to the dictionary\n".format(i))
        
        
# Execute function only with unique values
# %time create_dictionary_from_tag('nct_id')
# %time create_dictionary_from_tag('study_first_submitted')
# %time create_dictionary_from_tag('source')
# %time create_dictionary_from_tag('brief_title')
# %time create_dictionary_from_tag('study_type')

print('Dictionary created')
# Out:
# NCT02802423 file parsed
#
# NCT02278575 file parsed
#
# NCT00921440 file parsed
#
# NCT03706820 file parsed
#
# NCT00913380 file parsed
#
# NCT02079610 file parsed
#
# NCT03103295 file parsed
#
# NCT01998529 file parsed
#
# NCT02785419 file parsed
#
# NCT03372629 file parsed
#
# NCT01600157 file parsed
#
# NCT01466530 file parsed
#
# NCT03195036 file parsed
#
# NCT02941042 file parsed
#
# NCT03040804 file parsed
#
# NCT02704715 file parsed
#
# NCT00881543 file parsed
#
# NCT03334734 file parsed
#
# NCT02019537 file parsed
#
# NCT01781273 file parsed
#
# NCT02772640 file parsed
#
# NCT00582400 file parsed
#
# NCT01480102 file parsed
#
# NCT00158886 file parsed
#
# NCT02390817 file parsed
#
# NCT01643330 file parsed
#
# NCT02515461 file parsed
#
# NCT02386709 file parsed
#
# NCT01933542 file parsed
#
# NCT01373944 file parsed
#
# NCT01547104 file parsed
#
# NCT00452634 file parsed
#
# NCT03561584 file parsed
#
# NCT03580746 file parsed
#
# NCT03142828 file parsed
#
# NCT03442413 file parsed
#
# NCT00247260 file parsed
#
# NCT02221011 file parsed
#
# NCT00005996 file parsed
#
# NCT01860495 file parsed
#
# NCT02152696 file parsed
#
# NCT00779025 file parsed
#
# NCT02501005 file parsed
#
# NCT00746564 file parsed
#
# NCT03696017 file parsed
#
# NCT03526744 file parsed
#
# NCT00005148 file parsed
#
# NCT03428594 file parsed
#
# NCT01247571 file parsed
#
# NCT02584231 file parsed
#
# NCT02403362 file parsed
#
# NCT01813916 file parsed
#
# NCT02885571 file parsed
#
# NCT03185754 file parsed
#
# NCT03380858 file parsed
#
# NCT02652624 file parsed
#
# NCT00543842 file parsed
#
# NCT01213875 file parsed
#
# NCT03465319 file parsed
#
# NCT03635580 file parsed
#
# NCT02721186 file parsed
#
# NCT03416322 file parsed
#
# NCT01521650 file parsed
#
# NCT02823808 file parsed
#
# NCT03007225 file parsed
#
# NCT00425737 file parsed
#
# NCT00931320 file parsed
#
# NCT01629511 file parsed
#
# NCT01401231 file parsed
#
# NCT03334864 file parsed
#
# NCT02823613 file parsed
#
# NCT01369498 file parsed
#
# NCT01914289 file parsed
#
# NCT03190824 file parsed
#
# NCT00121017 file parsed
#
# NCT01595295 file parsed
#
# NCT01226576 file parsed
#
# NCT03138837 file parsed
#
# NCT02431715 file parsed
#
# NCT02047474 file parsed
#
# NCT02796274 file parsed
#
# NCT03494725 file parsed
#
# NCT02664753 file parsed
#
# NCT00305045 file parsed
#
# NCT02738762 file parsed
#
# NCT00760370 file parsed
#
# NCT00548444 file parsed
#
# NCT02072356 file parsed
#
# NCT00805324 file parsed
#
# NCT02459873 file parsed
#
# NCT00899119 file parsed
#
# NCT03661099 file parsed
#
# NCT00173355 file parsed
#
# NCT03240276 file parsed
#
# NCT02448758 file parsed
#
# NCT03675984 file parsed
#
# NCT01380171 file parsed
#
# NCT01249365 file parsed
#
# NCT02987205 file parsed
#
# NCT03583099 file parsed
#
# NCT02091557 file parsed
#
# NCT02899013 file parsed
#
# NCT02117726 file parsed
#
# NCT03637023 file parsed
#
# NCT01284101 file parsed
#
# NCT01219036 file parsed
#
# NCT02035020 file parsed
#
# NCT01346254 file parsed
#
# NCT02144168 file parsed
#
# NCT03403504 file parsed
#
# NCT02687581 file parsed
#
# NCT02125409 file parsed
#
# NCT03470298 file parsed
#
# NCT02624570 file parsed
#
# NCT01233973 file parsed
#
# NCT00377559 file parsed
#
# NCT00357851 file parsed
#
# NCT03414905 file parsed
#
# NCT02645617 file parsed
#
# NCT03133195 file parsed
#
# NCT00071812 file parsed
#
# NCT01369472 file parsed
#
# NCT03357497 file parsed
#
# NCT00581269 file parsed
#
# NCT00313222 file parsed
#
# NCT00904826 file parsed
#
# NCT02817789 file parsed
#
# NCT00064012 file parsed
#
# NCT00340691 file parsed
#
# NCT00119990 file parsed
#
# NCT02333006 file parsed
#
# NCT01474330 file parsed
#
# NCT03089814 file parsed
#
# NCT01018784 file parsed
#
# NCT01378962 file parsed
#
# NCT03266666 file parsed
#
# NCT00603759 file parsed
#
# NCT02360670 file parsed
#
# NCT01788319 file parsed
#
# NCT01117662 file parsed
#
# NCT00337623 file parsed
#
# NCT01219608 file parsed
#
# NCT00735228 file parsed
#
# NCT00216606 file parsed
#
# NCT02101593 file parsed
#
# NCT03744988 file parsed
#
# NCT03455829 file parsed
#
# NCT02144636 file parsed
#
# NCT02991885 file parsed
#
# NCT02273778 file parsed
#
# NCT01094392 file parsed
#
# NCT01677520 file parsed
#
# NCT03062527 file parsed
#
# NCT02948699 file parsed
#
# NCT00465712 file parsed
#
# NCT00579449 file parsed
#
# NCT01023841 file parsed
#
# NCT02534324 file parsed
#
# NCT03093051 file parsed
#
# NCT03695653 file parsed
#
# NCT01938404 file parsed
#
# NCT00229970 file parsed
#
# NCT01300013 file parsed
#
# NCT00323284 file parsed
#
# NCT02245750 file parsed
#
# NCT00033007 file parsed
#
# NCT00887445 file parsed
#
# NCT01056549 file parsed
#
# NCT01704040 file parsed
#
# NCT00004654 file parsed
#
# NCT02301338 file parsed
#
# NCT02769273 file parsed
#
# NCT02946879 file parsed
#
# NCT01417286 file parsed
#
# NCT02083432 file parsed
#
# NCT03049748 file parsed
#
# NCT02965118 file parsed
#
# NCT02505503 file parsed
#
# NCT02709395 file parsed
#
# NCT02850835 file parsed
#
# NCT01846520 file parsed
#
# NCT01058148 file parsed
#
# NCT02638376 file parsed
#
# NCT02601508 file parsed
#
# NCT03106467 file parsed
#
# NCT00643630 file parsed
#
# NCT01071928 file parsed
#
# NCT03427138 file parsed
#
# NCT01202942 file parsed
#
# NCT00754416 file parsed
#
# NCT01239732 file parsed
#
# NCT01740947 file parsed
#
# NCT02926235 file parsed
#
# NCT03550417 file parsed
#
# NCT02439788 file parsed
#
# NCT01304316 file parsed
#
# NCT02864589 file parsed
#
# NCT02262702 file parsed
#
# NCT00951405 file parsed
#
# NCT01229904 file parsed
#
# NCT00839020 file parsed
#
# NCT01793909 file parsed
#
# NCT01787968 file parsed
#
# NCT00858390 file parsed
#
# NCT03729583 file parsed
#
# NCT02423317 file parsed
#
# NCT00624520 file parsed
#
# NCT02976012 file parsed
#
# NCT02982187 file parsed
#
# NCT02717234 file parsed
#
# NCT02524652 file parsed
#
# NCT00471770 file parsed
#
# NCT01230892 file parsed
#
# NCT00237224 file parsed
#
# NCT02198560 file parsed
#
# NCT00462917 file parsed
#
# NCT00131612 file parsed
#
# NCT02459652 file parsed
#
# NCT03773458 file parsed
#
# NCT03297515 file parsed
#
# NCT01038245 file parsed
#
# NCT00000394 file parsed
#
# NCT02524860 file parsed
#
# NCT01708889 file parsed
#
# NCT02219789 file parsed
#
# NCT00480207 file parsed
#
# NCT03548649 file parsed
#
# NCT03599206 file parsed
#
# NCT00874055 file parsed
#
# NCT02428257 file parsed
#
# NCT00368251 file parsed
#
# NCT00722839 file parsed
#
# NCT03766295 file parsed
#
# NCT03164746 file parsed
#
# NCT01386658 file parsed
#
# NCT01546155 file parsed
#
# NCT03593850 file parsed
#
# NCT02326155 file parsed
#
# NCT01583023 file parsed
#
# NCT02282436 file parsed
#
# NCT01876147 file parsed
#
# NCT03422094 file parsed
#
# NCT01167608 file parsed
#
# NCT01782352 file parsed
#
# NCT00795275 file parsed
#
# NCT00372619 file parsed
#
# NCT02851043 file parsed
#
# NCT03462329 file parsed
#
# NCT01847365 file parsed
#
# NCT03241082 file parsed
#
# NCT00005472 file parsed
#
# NCT02101086 file parsed
#
# NCT00020631 file parsed
#
# NCT03009240 file parsed
#
# NCT03162393 file parsed
#
# NCT00296088 file parsed
#
# NCT00323141 file parsed
#
# NCT03471130 file parsed
#
# NCT00483184 file parsed
#
# NCT00812214 file parsed
#
# NCT03684317 file parsed
#
# NCT03659604 file parsed
#
# NCT03446950 file parsed
#
# NCT01264692 file parsed
#
# NCT01675232 file parsed
#
# NCT03284645 file parsed
#
# NCT02123186 file parsed
#
# NCT00908310 file parsed
#
# NCT00837876 file parsed
#
# NCT00738153 file parsed
#
# NCT03735641 file parsed
#
# NCT00288301 file parsed
#
# NCT01798966 file parsed
#
# NCT02729155 file parsed
#
# NCT01686594 file parsed
#
# NCT00503633 file parsed
#
# NCT01731262 file parsed
#
# NCT00991900 file parsed
#
# NCT00955201 file parsed
#
# NCT02054871 file parsed
#
# NCT01416467 file parsed
#
# NCT01500577 file parsed
#
# NCT03463681 file parsed
#
# NCT02209259 file parsed
#
# NCT03317366 file parsed
#
# NCT00897182 file parsed
#
# NCT01808560 file parsed
#
# NCT00800215 file parsed
#
# NCT03688100 file parsed
#
# NCT01871935 file parsed
#
# NCT00527579 file parsed
#
# NCT01945879 file parsed
#
# NCT02628262 file parsed
#
# NCT02732548 file parsed
#
# NCT03693911 file parsed
#
# NCT02160041 file parsed
#
# NCT00013832 file parsed
#
# NCT02044861 file parsed
#
# NCT00818116 file parsed
#
# NCT02908568 file parsed
#
# NCT01719510 file parsed
#
# NCT00888277 file parsed
#
# NCT00002863 file parsed
#
# NCT02105961 file parsed
#
# NCT00061308 file parsed
#
# NCT02073175 file parsed
#
# NCT00207753 file parsed
#
# NCT02413489 file parsed
#
# NCT01419392 file parsed
#
# NCT00355940 file parsed
#
# NCT03587857 file parsed
#
# NCT02785692 file parsed
#
# NCT00939523 file parsed
#
# NCT03157856 file parsed
#
# NCT02372006 file parsed
#
# NCT01043055 file parsed
#
# NCT01967953 file parsed
#
# NCT02330237 file parsed
#
# NCT01948973 file parsed
#
# NCT03214731 file parsed
#
# NCT01513681 file parsed
#
# NCT00725920 file parsed
#
# NCT01366079 file parsed
#
# NCT00894933 file parsed
#
# NCT00636753 file parsed
#
# NCT01750853 file parsed
#
# NCT02206815 file parsed
#
# NCT00596830 file parsed
#
# NCT02133157 file parsed
#
# NCT02969369 file parsed
#
# NCT00558350 file parsed
#
# NCT03677882 file parsed
#
# NCT02793193 file parsed
#
# NCT03442881 file parsed
#
# NCT01760239 file parsed
#
# NCT02065310 file parsed
#
# NCT01495988 file parsed
#
# NCT02243384 file parsed
#
# NCT02954770 file parsed
#
# NCT00434512 file parsed
#
# NCT00957372 file parsed
#
# NCT00716079 file parsed
#
# NCT00857831 file parsed
#
# NCT00344721 file parsed
#
# NCT00947388 file parsed
#
# NCT00534937 file parsed
#
# NCT00281333 file parsed
#
# NCT01448733 file parsed
#
# NCT03051607 file parsed
#
# NCT03741673 file parsed
#
# NCT00784719 file parsed
#
# NCT02368288 file parsed
#
# NCT03266198 file parsed
#
# NCT02978885 file parsed
#
# NCT03602170 file parsed
#
# NCT00978965 file parsed
#
# NCT03652753 file parsed
#
# NCT01022866 file parsed
#
# NCT03172182 file parsed
#
# NCT00534664 file parsed
#
# NCT00371163 file parsed
#
# NCT00352547 file parsed
#
# NCT01388374 file parsed
#
# NCT02117180 file parsed
#
# NCT02995070 file parsed
#
# NCT03396900 file parsed
#
# NCT01423227 file parsed
#
# NCT02384967 file parsed
#
# NCT00326573 file parsed
#
# NCT00030381 file parsed
#
# NCT02219139 file parsed
#
# NCT03481010 file parsed
#
# NCT00736554 file parsed
#
# NCT00006196 file parsed
#
# NCT03519711 file parsed
#
# NCT02872610 file parsed
#
# NCT01341158 file parsed
#
# NCT02815462 file parsed
#
# NCT00806273 file parsed
#
# NCT00035789 file parsed
#
# NCT00507533 file parsed
#
# NCT01102595 file parsed
#
# NCT02805842 file parsed
#
# NCT01073436 file parsed
#
# NCT00001202 file parsed
#
# NCT02596282 file parsed
#
# NCT00422604 file parsed
#
# NCT02209909 file parsed
#
# NCT00593554 file parsed
#
# NCT01756599 file parsed
#
# NCT02723318 file parsed
#
# NCT02575469 file parsed
#
# NCT01054300 file parsed
#
# NCT00732875 file parsed
#
# NCT03603652 file parsed
#
# NCT03548402 file parsed
#
# NCT03514355 file parsed
#
# NCT01545011 file parsed
#
# NCT01074749 file parsed
#
# NCT01369979 file parsed
#
# NCT01658748 file parsed
#
# NCT02945644 file parsed
#
# NCT00578721 file parsed
#
# NCT03067818 file parsed
#
# NCT01123837 file parsed
#
# NCT03532191 file parsed
#
# NCT02835638 file parsed
#
# NCT01398228 file parsed
#
# NCT03636373 file parsed
#
# NCT01885468 file parsed
#
# NCT00885027 file parsed
#
# NCT03005535 file parsed
#
# NCT03445494 file parsed
#
# NCT00141141 file parsed
#
# NCT03488394 file parsed
#
# NCT00568724 file parsed
#
# NCT02698202 file parsed
#
# NCT00679068 file parsed
#
# NCT00971763 file parsed
#
# NCT00381524 file parsed
#
# NCT01937351 file parsed
#
# NCT02923674 file parsed
#
# NCT01708590 file parsed
#
# NCT02109185 file parsed
#
# NCT00634140 file parsed
#
# NCT01438372 file parsed
#
# NCT00444392 file parsed
#
# NCT03742960 file parsed
#
# NCT03163511 file parsed
#
# NCT01765556 file parsed
#
# NCT01272544 file parsed
#
# NCT01144728 file parsed
#
# NCT02776085 file parsed
#
# NCT01897454 file parsed
#
# NCT01124786 file parsed
#
# NCT03706677 file parsed
#
# NCT02075099 file parsed
#
# NCT00356083 file parsed
#
# NCT01859663 file parsed
#
# NCT02896556 file parsed
#
# NCT00373217 file parsed
#
# NCT02762019 file parsed
#
# NCT03458000 file parsed
#
# NCT03208478 file parsed
#
# NCT01971892 file parsed
#
# NCT02522650 file parsed
#
# NCT03463525 file parsed
#
# NCT01205282 file parsed
#
# NCT00321009 file parsed
#
# NCT03706339 file parsed
#
# NCT03415464 file parsed
#
# NCT02059798 file parsed
#
# NCT01060449 file parsed
#
# NCT01610518 file parsed
#
# NCT03245801 file parsed
#
# NCT02506686 file parsed
#
# NCT02901574 file parsed
#
# NCT00713310 file parsed
#
# NCT00043797 file parsed
#
# NCT03497507 file parsed
#
# NCT02590627 file parsed
#
# NCT01634451 file parsed
#
# NCT01304017 file parsed
#
# NCT02367976 file parsed
#
# NCT00789776 file parsed
#
# NCT03009669 file parsed
#
# NCT01818011 file parsed
#
# NCT03772080 file parsed
#
# NCT03668782 file parsed
#
# NCT01989052 file parsed
#
# NCT03099252 file parsed
#
# NCT02317705 file parsed
#
# NCT03020238 file parsed
#
# NCT02447341 file parsed
#
# NCT00532818 file parsed
#
# NCT03125369 file parsed
#
# NCT03182101 file parsed
#
# NCT01532258 file parsed
#
# NCT01995877 file parsed
#
# NCT02451046 file parsed
#
# NCT03380221 file parsed
#
# NCT01589627 file parsed
#
# NCT00674375 file parsed
#
# NCT03617341 file parsed
#
# NCT01202513 file parsed
#
# NCT00917397 file parsed
#
# NCT01733277 file parsed
#
# NCT03022994 file parsed
#
# NCT01716975 file parsed
#
# NCT02014896 file parsed
#
# NCT03318497 file parsed
#
# NCT01951014 file parsed
#
# NCT02073825 file parsed
#
# NCT02581475 file parsed
#
# NCT01391637 file parsed
#
# NCT03294122 file parsed
#
# NCT01117415 file parsed
#
# NCT00541970 file parsed
#
# NCT01578200 file parsed
#
# NCT00000271 file parsed
#
# NCT03035942 file parsed
#
# NCT03712618 file parsed
#
# NCT00380393 file parsed
#
# NCT01928069 file parsed
#
# NCT00591760 file parsed
#
# NCT01582347 file parsed
#
# NCT00598988 file parsed
#
# NCT03112655 file parsed
#
# NCT02750514 file parsed
#
# NCT00718315 file parsed
#
# NCT01886755 file parsed
#
# NCT02306200 file parsed
#
# NCT01210898 file parsed
#
# NCT00003585 file parsed
#
# NCT00023127 file parsed
#
# NCT00056433 file parsed
#
# NCT01145014 file parsed
#
# NCT01987271 file parsed
#
# NCT01806948 file parsed
#
# NCT01993589 file parsed
#
# NCT03727516 file parsed
#
# NCT02317523 file parsed
#
# NCT00577187 file parsed
#
# NCT00774813 file parsed
#
# NCT01727804 file parsed
#
# NCT03419871 file parsed
#
# NCT00986050 file parsed
#
# NCT03528460 file parsed
#
# NCT00910026 file parsed
#
# NCT03729739 file parsed
#
# NCT03608085 file parsed
#
# NCT01504724 file parsed
#
# NCT01287104 file parsed
#
# NCT01050829 file parsed
#
# NCT03317353 file parsed
#
# NCT03407469 file parsed
#
# NCT00771017 file parsed
#
# NCT02994238 file parsed
#
# NCT02858154 file parsed
#
# NCT01184339 file parsed
#
# NCT00150241 file parsed
#
# NCT02296996 file parsed
#
# NCT02513251 file parsed
#
# NCT00823823 file parsed
#
# NCT01582971 file parsed
#
# NCT03508362 file parsed
#
# NCT02630550 file parsed
#
# NCT02337751 file parsed
#
# NCT03564509 file parsed
#
# NCT00214929 file parsed
#
# NCT00885612 file parsed
#
# NCT03393494 file parsed
#
# NCT00795756 file parsed
#
# NCT02147795 file parsed
#
# NCT01885936 file parsed
#
# NCT03556020 file parsed
#
# NCT01220219 file parsed
#
# NCT03770936 file parsed
#
# NCT00112892 file parsed
#
# NCT03518359 file parsed
#
# NCT03637699 file parsed
#
# NCT01099020 file parsed
#
# NCT00005646 file parsed
#
# NCT02404129 file parsed
#
# NCT03024333 file parsed
#
# NCT01720563 file parsed
#
# NCT03495531 file parsed
#
# NCT02499744 file parsed
#
# NCT01247727 file parsed
#
# NCT00445042 file parsed
#
# NCT02062073 file parsed
#
# NCT00300989 file parsed
#
# NCT00524537 file parsed
#
# NCT02948153 file parsed
#
# NCT00379457 file parsed
#
# NCT02201381 file parsed
#
# NCT00343720 file parsed
#
# NCT00070434 file parsed
#
# NCT00656864 file parsed
#
# NCT03670303 file parsed
#
# NCT02692911 file parsed
#
# NCT01767012 file parsed
#
# NCT02520869 file parsed
#
# NCT00002277 file parsed
#
# NCT00614666 file parsed
#
# NCT02322996 file parsed
#
# NCT02156063 file parsed
#
# NCT00852202 file parsed
#
# NCT02676856 file parsed
#
# NCT03258320 file parsed
#
# NCT03200639 file parsed
#
# NCT00888095 file parsed
#
# NCT02343367 file parsed
#
# NCT00275912 file parsed
#
# NCT02086097 file parsed
#
# NCT00399776 file parsed
#
# NCT02582775 file parsed
#
# NCT03067155 file parsed
#
# NCT00719394 file parsed
#
# NCT01542983 file parsed
#
# NCT02413736 file parsed
#
# NCT01776320 file parsed
#
# NCT00020969 file parsed
#
# NCT03377842 file parsed
#
# NCT03068702 file parsed
#
# NCT03457077 file parsed
#
# NCT01434342 file parsed
#
# NCT03262532 file parsed
#
# NCT03537768 file parsed
#
# NCT00606840 file parsed
#
# NCT00838435 file parsed
#
# NCT02436824 file parsed
#
# NCT02583906 file parsed
#
# NCT02563158 file parsed
#
# NCT03709004 file parsed
#
# NCT00857025 file parsed
#
# NCT01612507 file parsed
#
# NCT00313248 file parsed
#
# NCT02590211 file parsed
#
# NCT03223181 file parsed
#
# NCT02462044 file parsed
#
# NCT02917720 file parsed
#
# NCT01437267 file parsed
#
# NCT00009243 file parsed
#
# NCT02919709 file parsed
#
# NCT00430157 file parsed
#
# NCT00934960 file parsed
#
# NCT00005469 file parsed
#
# NCT03362697 file parsed
#
# NCT03238599 file parsed
#
# NCT01875354 file parsed
#
# NCT00609544 file parsed
#
# NCT01713153 file parsed
#
# NCT00367042 file parsed
#
# NCT02216968 file parsed
#
# NCT00006362 file parsed
#
# NCT02656836 file parsed
#
# NCT03254641 file parsed
#
# NCT03195933 file parsed
#
# NCT01774123 file parsed
#
# NCT01546883 file parsed
#
# NCT01403298 file parsed
#
# NCT03706521 file parsed
#
# NCT03493958 file parsed
#
# NCT03002246 file parsed
#
# NCT02782520 file parsed
#
# NCT02472119 file parsed
#
# NCT03750968 file parsed
#
# NCT01343342 file parsed
#
# NCT02055209 file parsed
#
# NCT02909452 file parsed
#
# NCT01464983 file parsed
#
# NCT00430989 file parsed
#
# NCT01429129 file parsed
#
# NCT02172846 file parsed
#
# NCT01980732 file parsed
#
# NCT03052673 file parsed
#
# NCT01778335 file parsed
#
# NCT00860262 file parsed
#
# NCT01932619 file parsed
#
# NCT03166267 file parsed
#
# NCT03768011 file parsed
#
# NCT02592239 file parsed
#
# NCT02300272 file parsed
#
# NCT01213004 file parsed
#
# NCT03134508 file parsed
#
# NCT03586830 file parsed
#
# NCT01182766 file parsed
#
# NCT02620631 file parsed
#
# NCT03413618 file parsed
#
# NCT03283722 file parsed
#
# NCT00612950 file parsed
#
# NCT02660229 file parsed
#
# NCT01307267 file parsed
#
# NCT00751855 file parsed
#
# NCT01093469 file parsed
#
# NCT03402932 file parsed
#
# NCT02009761 file parsed
#
# NCT03343314 file parsed
#
# NCT00394108 file parsed
#
# NCT03114592 file parsed
#
# NCT03389347 file parsed
#
# NCT03557112 file parsed
#
# NCT03530189 file parsed
#
# NCT01902446 file parsed
#
# NCT03653455 file parsed
#
# NCT03344484 file parsed
#
# NCT00905996 file parsed
#
# NCT01096303 file parsed
#
# NCT00005642 file parsed
#
# NCT02909296 file parsed
#
# NCT00761410 file parsed
#
# NCT02344550 file parsed
#
# NCT00452738 file parsed
#
# NCT02665741 file parsed
#
# NCT03047486 file parsed
#
# NCT00033657 file parsed
#
# NCT01847495 file parsed
#
# NCT02610335 file parsed
#
# NCT03364218 file parsed
#
# NCT01592838 file parsed
#
# NCT00047671 file parsed
#
# NCT01609322 file parsed
#
# NCT00657163 file parsed
#
# NCT03575819 file parsed
#
# NCT00359346 file parsed
#
# NCT02466594 file parsed
#
# NCT01838525 file parsed
#
# NCT02792491 file parsed
#
# NCT03204539 file parsed
#
# NCT00352950 file parsed
#
# NCT00259636 file parsed
#
# NCT01627236 file parsed
#
# NCT01660633 file parsed
#
# NCT00461864 file parsed
#
# NCT01421953 file parsed
#
# NCT03171532 file parsed
#
# NCT01883947 file parsed
#
# NCT00336622 file parsed
#
# NCT01899274 file parsed
#
# NCT03638180 file parsed
#
# NCT00123240 file parsed
#
# NCT01677039 file parsed
#
# NCT01396031 file parsed
#
# NCT03545893 file parsed
#
# NCT00560170 file parsed
#
# NCT00001023 file parsed
#
# NCT00409461 file parsed
#
# NCT02625038 file parsed
#
# NCT03281122 file parsed
#
# NCT03329079 file parsed
#
# NCT00001235 file parsed
#
# NCT03725488 file parsed
#
# NCT01589809 file parsed
#
# NCT02595151 file parsed
#
# NCT00828191 file parsed
#
# NCT03221790 file parsed
#
# NCT02525484 file parsed
#
# NCT01697709 file parsed
#
# NCT01260610 file parsed
#
# NCT00139386 file parsed
#
# NCT02667873 file parsed
#
# NCT03701607 file parsed
#
# NCT02113371 file parsed
#
# NCT02133937 file parsed
#
# NCT02429232 file parsed
#
# NCT00590421 file parsed
#
# NCT00305305 file parsed
#
# NCT02055495 file parsed
#
# NCT03174028 file parsed
#
# NCT02205554 file parsed
#
# NCT02017301 file parsed
#
# NCT03336710 file parsed
#
# NCT00638703 file parsed
#
# NCT01506232 file parsed
#
# NCT03371498 file parsed
#
# NCT02619188 file parsed
#
# NCT01215773 file parsed
#
# NCT00845520 file parsed
#
# NCT00792675 file parsed
#
# NCT00323739 file parsed
#
# NCT00226655 file parsed
#
# NCT01937260 file parsed
#
# NCT00056134 file parsed
#
# NCT00721695 file parsed
#
# NCT01529164 file parsed
#
# NCT00003647 file parsed
#
# NCT00139256 file parsed
#
# NCT00970996 file parsed
#
# NCT03487237 file parsed
#
# NCT00724074 file parsed
#
# NCT00405002 file parsed
#
# NCT00949858 file parsed
#
# NCT02731573 file parsed
#
# NCT01326780 file parsed
#
# NCT03519152 file parsed
#
# NCT02106806 file parsed
#
# NCT02061137 file parsed
#
# NCT00769808 file parsed
#
# NCT03029299 file parsed
#
# NCT02988128 file parsed
#
# NCT01606670 file parsed
#
# NCT02767245 file parsed
#
# NCT02800837 file parsed
#
# NCT03751384 file parsed
#
# NCT00269802 file parsed
#
# NCT01780818 file parsed
#
# NCT03008733 file parsed
#
# NCT01399827 file parsed
#
# NCT02213900 file parsed
#
# NCT02968355 file parsed
#
# NCT00138203 file parsed
#
# NCT00298025 file parsed
#
# NCT00712699 file parsed
#
# NCT02543203 file parsed
#
# NCT00781768 file parsed
#
# NCT00382928 file parsed
#
# NCT01703442 file parsed
#
# NCT01221428 file parsed
#
# NCT00254163 file parsed
#
# NCT03419754 file parsed
#
# NCT03654820 file parsed
#
# NCT00646035 file parsed
#
# NCT03703011 file parsed
#
# NCT01707368 file parsed
#
# NCT01387945 file parsed
#
# NCT02904070 file parsed
#
# NCT00187356 file parsed
#
# NCT00672386 file parsed
#
# NCT00922194 file parsed
#
# NCT00632775 file parsed
#
# NCT00904423 file parsed
#
# NCT02987621 file parsed
#
# NCT01325116 file parsed
#
# NCT02878187 file parsed
#
# NCT00280683 file parsed
#
# NCT02149524 file parsed
#
# NCT03166605 file parsed
#
# NCT00728507 file parsed
#
# NCT00857090 file parsed
#
# NCT02036333 file parsed
#
# NCT02256319 file parsed
#
# NCT01644643 file parsed
#
# NCT02384317 file parsed
#
# NCT03576781 file parsed
#
# NCT00340262 file parsed
#
# NCT03358394 file parsed
#
# NCT02819141 file parsed
#
# NCT00656422 file parsed
#
# NCT02182245 file parsed
#
# NCT00517439 file parsed
#
# NCT00313404 file parsed
#
# NCT02932475 file parsed
#
# NCT01535599 file parsed
#
# NCT03688815 file parsed
#
# NCT03177330 file parsed
#
# NCT03063437 file parsed
#
# NCT01041950 file parsed
#
# NCT01109082 file parsed
#
# NCT00417404 file parsed
#
# NCT03497754 file parsed
#
# NCT00700856 file parsed
#
# NCT02333812 file parsed
#
# NCT02001818 file parsed
#
# NCT00126360 file parsed
#
# NCT01926145 file parsed
#
# NCT01847222 file parsed
#
# NCT02474043 file parsed
#
# NCT02618109 file parsed
#
# NCT02226562 file parsed
#
# NCT00389077 file parsed
#
# NCT02215369 file parsed
#
# NCT01171313 file parsed
#
# NCT00385671 file parsed
#
# NCT03582826 file parsed
#
# NCT03181672 file parsed
#
# NCT00243971 file parsed
#
# NCT00420069 file parsed
#
# NCT01112111 file parsed
#
# NCT01756508 file parsed
#
# NCT01796704 file parsed
#
# NCT02657408 file parsed
#
# NCT00575861 file parsed
#
# NCT02608736 file parsed
#
# NCT00538746 file parsed
#
# NCT01437774 file parsed
#
# NCT00004937 file parsed
#
# NCT00801957 file parsed
#
# NCT01490736 file parsed
#
# NCT03383354 file parsed
#
# NCT03542747 file parsed
#
# NCT02252354 file parsed
#
# NCT03174002 file parsed
#
# NCT00172692 file parsed
#
# NCT00619268 file parsed
#
# NCT02785172 file parsed
#
# NCT02892981 file parsed
#
# NCT01923818 file parsed
#
# NCT02064855 file parsed
#
# NCT03761693 file parsed
#
# NCT03503045 file parsed
#
# NCT02779478 file parsed
#
# NCT00673738 file parsed
#
# NCT03329391 file parsed
#
# NCT03574597 file parsed
#
# NCT02822703 file parsed
#
# NCT01965483 file parsed
#
# NCT02957175 file parsed
#
# NCT02269891 file parsed
#
# NCT00568607 file parsed
#
# NCT02334566 file parsed
#
# NCT01103622 file parsed
#
# NCT00265811 file parsed
#
# NCT00167700 file parsed
#
# NCT03472482 file parsed
#
# NCT01349803 file parsed
#
# NCT02720874 file parsed
#
# NCT01033695 file parsed
#
# NCT01652742 file parsed
#
# NCT00275223 file parsed
#
# NCT00269178 file parsed
#
# NCT02045290 file parsed
#
# NCT00968305 file parsed
#
# NCT01801930 file parsed
#
# NCT00003133 file parsed
#
# NCT00660803 file parsed
#
# NCT00748631 file parsed
#
# NCT02099890 file parsed
#
# NCT00071214 file parsed
#
# NCT02460783 file parsed
#
# NCT02831179 file parsed
#
# NCT02427386 file parsed
#
# NCT03576586 file parsed
#
# NCT02415335 file parsed
#
# NCT00663338 file parsed
#
# NCT01919398 file parsed
#
# NCT00314353 file parsed
#
# NCT02323386 file parsed
#
# NCT02589652 file parsed
#
# NCT03141645 file parsed
#
# NCT02376608 file parsed
#
# NCT01889238 file parsed
#
# NCT00447785 file parsed
#
# NCT02237898 file parsed
#
# NCT01707030 file parsed
#
# NCT01518816 file parsed
#
# NCT02062996 file parsed
#
# NCT03082222 file parsed
#
# NCT03456284 file parsed
#
# NCT01023295 file parsed
#
# NCT03620396 file parsed
#
# NCT00641238 file parsed
#
# NCT02318264 file parsed
#
# NCT03311828 file parsed
#
# NCT00247858 file parsed
#
# NCT01428453 file parsed
#
# NCT01477619 file parsed
#
# NCT00003052 file parsed
#
# NCT00440388 file parsed
#
# NCT00064961 file parsed
#
# NCT03495024 file parsed
#
# NCT01761994 file parsed
#
# NCT02553564 file parsed
#
# NCT01056146 file parsed
#
# NCT00146068 file parsed
#
# NCT00057603 file parsed
#
# NCT01231165 file parsed
#
# NCT00411489 file parsed
#
# NCT01518790 file parsed
#
# NCT00245297 file parsed
#
# NCT00475696 file parsed
#
# NCT02118792 file parsed
#
# NCT01439789 file parsed
#
# NCT00793208 file parsed
#
# NCT02522000 file parsed
#
# NCT03610451 file parsed
#
# NCT02902003 file parsed
#
# NCT00004475 file parsed
#
# NCT00222378 file parsed
#
# NCT03100357 file parsed
#
# NCT00354211 file parsed
#
# NCT03047785 file parsed
#
# NCT03212066 file parsed
#
# NCT03204162 file parsed
#
# NCT02724436 file parsed
#
# NCT00703196 file parsed
#
# NCT02258087 file parsed
#
# NCT02425579 file parsed
#
# NCT02325050 file parsed
#
# NCT03167125 file parsed
#
# NCT03271099 file parsed
#
# NCT01313065 file parsed
#
# NCT00339599 file parsed
#
# NCT03307655 file parsed
#
# NCT01336582 file parsed
#
# NCT02961764 file parsed
#
# NCT02646098 file parsed
#
# NCT02285556 file parsed
#
# NCT02305342 file parsed
#
# NCT00801164 file parsed
#
# NCT00421629 file parsed
#
# NCT01243684 file parsed
#
# NCT00000809 file parsed
#
# NCT02060006 file parsed
#
# NCT00807703 file parsed
#
# NCT01694667 file parsed
#
# NCT02444390 file parsed
#
# NCT02231554 file parsed
#
# NCT01993511 file parsed
#
# NCT02502500 file parsed
#
# NCT00104299 file parsed
#
# NCT01141361 file parsed
#
# NCT03462888 file parsed
#
# NCT02513394 file parsed
#
# NCT00612105 file parsed
#
# NCT02149251 file parsed
#
# NCT03409224 file parsed
#
# NCT01862107 file parsed
#
# NCT00743821 file parsed
#
# NCT02750995 file parsed
#
# NCT02802423 file added to the dictionary
#
# NCT02278575 file added to the dictionary
#
# NCT00921440 file added to the dictionary
#
# NCT03706820 file added to the dictionary
#
# NCT00913380 file added to the dictionary
#
# NCT02079610 file added to the dictionary
#
# NCT03103295 file added to the dictionary
#
# NCT01998529 file added to the dictionary
#
# NCT02785419 file added to the dictionary
#
# NCT03372629 file added to the dictionary
#
# NCT01600157 file added to the dictionary
#
# NCT01466530 file added to the dictionary
#
# NCT03195036 file added to the dictionary
#
# NCT02941042 file added to the dictionary
#
# NCT03040804 file added to the dictionary
#
# NCT02704715 file added to the dictionary
#
# NCT00881543 file added to the dictionary
#
# NCT03334734 file added to the dictionary
#
# NCT02019537 file added to the dictionary
#
# NCT01781273 file added to the dictionary
#
# NCT02772640 file added to the dictionary
#
# NCT00582400 file added to the dictionary
#
# NCT01480102 file added to the dictionary
#
# NCT00158886 file added to the dictionary
#
# NCT02390817 file added to the dictionary
#
# NCT01643330 file added to the dictionary
#
# NCT02515461 file added to the dictionary
#
# NCT02386709 file added to the dictionary
#
# NCT01933542 file added to the dictionary
#
# NCT01373944 file added to the dictionary
#
# NCT01547104 file added to the dictionary
#
# NCT00452634 file added to the dictionary
#
# NCT03561584 file added to the dictionary
#
# NCT03580746 file added to the dictionary
#
# NCT03142828 file added to the dictionary
#
# NCT03442413 file added to the dictionary
#
# NCT00247260 file added to the dictionary
#
# NCT02221011 file added to the dictionary
#
# NCT00005996 file added to the dictionary
#
# NCT01860495 file added to the dictionary
#
# NCT02152696 file added to the dictionary
#
# NCT00779025 file added to the dictionary
#
# NCT02501005 file added to the dictionary
#
# NCT00746564 file added to the dictionary
#
# NCT03696017 file added to the dictionary
#
# NCT03526744 file added to the dictionary
#
# NCT00005148 file added to the dictionary
#
# NCT03428594 file added to the dictionary
#
# NCT01247571 file added to the dictionary
#
# NCT02584231 file added to the dictionary
#
# NCT02403362 file added to the dictionary
#
# NCT01813916 file added to the dictionary
#
# NCT02885571 file added to the dictionary
#
# NCT03185754 file added to the dictionary
#
# NCT03380858 file added to the dictionary
#
# NCT02652624 file added to the dictionary
#
# NCT00543842 file added to the dictionary
#
# NCT01213875 file added to the dictionary
#
# NCT03465319 file added to the dictionary
#
# NCT03635580 file added to the dictionary
#
# NCT02721186 file added to the dictionary
#
# NCT03416322 file added to the dictionary
#
# NCT01521650 file added to the dictionary
#
# NCT02823808 file added to the dictionary
#
# NCT03007225 file added to the dictionary
#
# NCT00425737 file added to the dictionary
#
# NCT00931320 file added to the dictionary
#
# NCT01629511 file added to the dictionary
#
# NCT01401231 file added to the dictionary
#
# NCT03334864 file added to the dictionary
#
# NCT02823613 file added to the dictionary
#
# NCT01369498 file added to the dictionary
#
# NCT01914289 file added to the dictionary
#
# NCT03190824 file added to the dictionary
#
# NCT00121017 file added to the dictionary
#
# NCT01595295 file added to the dictionary
#
# NCT01226576 file added to the dictionary
#
# NCT03138837 file added to the dictionary
#
# NCT02431715 file added to the dictionary
#
# NCT02047474 file added to the dictionary
#
# NCT02796274 file added to the dictionary
#
# NCT03494725 file added to the dictionary
#
# NCT02664753 file added to the dictionary
#
# NCT00305045 file added to the dictionary
#
# NCT02738762 file added to the dictionary
#
# NCT00760370 file added to the dictionary
#
# NCT00548444 file added to the dictionary
#
# NCT02072356 file added to the dictionary
#
# NCT00805324 file added to the dictionary
#
# NCT02459873 file added to the dictionary
#
# NCT00899119 file added to the dictionary
#
# NCT03661099 file added to the dictionary
#
# NCT00173355 file added to the dictionary
#
# NCT03240276 file added to the dictionary
#
# NCT02448758 file added to the dictionary
#
# NCT03675984 file added to the dictionary
#
# NCT01380171 file added to the dictionary
#
# NCT01249365 file added to the dictionary
#
# NCT02987205 file added to the dictionary
#
# NCT03583099 file added to the dictionary
#
# NCT02091557 file added to the dictionary
#
# NCT02899013 file added to the dictionary
#
# NCT02117726 file added to the dictionary
#
# NCT03637023 file added to the dictionary
#
# NCT01284101 file added to the dictionary
#
# NCT01219036 file added to the dictionary
#
# NCT02035020 file added to the dictionary
#
# NCT01346254 file added to the dictionary
#
# NCT02144168 file added to the dictionary
#
# NCT03403504 file added to the dictionary
#
# NCT02687581 file added to the dictionary
#
# NCT02125409 file added to the dictionary
#
# NCT03470298 file added to the dictionary
#
# NCT02624570 file added to the dictionary
#
# NCT01233973 file added to the dictionary
#
# NCT00377559 file added to the dictionary
#
# NCT00357851 file added to the dictionary
#
# NCT03414905 file added to the dictionary
#
# NCT02645617 file added to the dictionary
#
# NCT03133195 file added to the dictionary
#
# NCT00071812 file added to the dictionary
#
# NCT01369472 file added to the dictionary
#
# NCT03357497 file added to the dictionary
#
# NCT00581269 file added to the dictionary
#
# NCT00313222 file added to the dictionary
#
# NCT00904826 file added to the dictionary
#
# NCT02817789 file added to the dictionary
#
# NCT00064012 file added to the dictionary
#
# NCT00340691 file added to the dictionary
#
# NCT00119990 file added to the dictionary
#
# NCT02333006 file added to the dictionary
#
# NCT01474330 file added to the dictionary
#
# NCT03089814 file added to the dictionary
#
# NCT01018784 file added to the dictionary
#
# NCT01378962 file added to the dictionary
#
# NCT03266666 file added to the dictionary
#
# NCT00603759 file added to the dictionary
#
# NCT02360670 file added to the dictionary
#
# NCT01788319 file added to the dictionary
#
# NCT01117662 file added to the dictionary
#
# NCT00337623 file added to the dictionary
#
# NCT01219608 file added to the dictionary
#
# NCT00735228 file added to the dictionary
#
# NCT00216606 file added to the dictionary
#
# NCT02101593 file added to the dictionary
#
# NCT03744988 file added to the dictionary
#
# NCT03455829 file added to the dictionary
#
# NCT02144636 file added to the dictionary
#
# NCT02991885 file added to the dictionary
#
# NCT02273778 file added to the dictionary
#
# NCT01094392 file added to the dictionary
#
# NCT01677520 file added to the dictionary
#
# NCT03062527 file added to the dictionary
#
# NCT02948699 file added to the dictionary
#
# NCT00465712 file added to the dictionary
#
# NCT00579449 file added to the dictionary
#
# NCT01023841 file added to the dictionary
#
# NCT02534324 file added to the dictionary
#
# NCT03093051 file added to the dictionary
#
# NCT03695653 file added to the dictionary
#
# NCT01938404 file added to the dictionary
#
# NCT00229970 file added to the dictionary
#
# NCT01300013 file added to the dictionary
#
# NCT00323284 file added to the dictionary
#
# NCT02245750 file added to the dictionary
#
# NCT00033007 file added to the dictionary
#
# NCT00887445 file added to the dictionary
#
# NCT01056549 file added to the dictionary
#
# NCT01704040 file added to the dictionary
#
# NCT00004654 file added to the dictionary
#
# NCT02301338 file added to the dictionary
#
# NCT02769273 file added to the dictionary
#
# NCT02946879 file added to the dictionary
#
# NCT01417286 file added to the dictionary
#
# NCT02083432 file added to the dictionary
#
# NCT03049748 file added to the dictionary
#
# NCT02965118 file added to the dictionary
#
# NCT02505503 file added to the dictionary
#
# NCT02709395 file added to the dictionary
#
# NCT02850835 file added to the dictionary
#
# NCT01846520 file added to the dictionary
#
# NCT01058148 file added to the dictionary
#
# NCT02638376 file added to the dictionary
#
# NCT02601508 file added to the dictionary
#
# NCT03106467 file added to the dictionary
#
# NCT00643630 file added to the dictionary
#
# NCT01071928 file added to the dictionary
#
# NCT03427138 file added to the dictionary
#
# NCT01202942 file added to the dictionary
#
# NCT00754416 file added to the dictionary
#
# NCT01239732 file added to the dictionary
#
# NCT01740947 file added to the dictionary
#
# NCT02926235 file added to the dictionary
#
# NCT03550417 file added to the dictionary
#
# NCT02439788 file added to the dictionary
#
# NCT01304316 file added to the dictionary
#
# NCT02864589 file added to the dictionary
#
# NCT02262702 file added to the dictionary
#
# NCT00951405 file added to the dictionary
#
# NCT01229904 file added to the dictionary
#
# NCT00839020 file added to the dictionary
#
# NCT01793909 file added to the dictionary
#
# NCT01787968 file added to the dictionary
#
# NCT00858390 file added to the dictionary
#
# NCT03729583 file added to the dictionary
#
# NCT02423317 file added to the dictionary
#
# NCT00624520 file added to the dictionary
#
# NCT02976012 file added to the dictionary
#
# NCT02982187 file added to the dictionary
#
# NCT02717234 file added to the dictionary
#
# NCT02524652 file added to the dictionary
#
# NCT00471770 file added to the dictionary
#
# NCT01230892 file added to the dictionary
#
# NCT00237224 file added to the dictionary
#
# NCT02198560 file added to the dictionary
#
# NCT00462917 file added to the dictionary
#
# NCT00131612 file added to the dictionary
#
# NCT02459652 file added to the dictionary
#
# NCT03773458 file added to the dictionary
#
# NCT03297515 file added to the dictionary
#
# NCT01038245 file added to the dictionary
#
# NCT00000394 file added to the dictionary
#
# NCT02524860 file added to the dictionary
#
# NCT01708889 file added to the dictionary
#
# NCT02219789 file added to the dictionary
#
# NCT00480207 file added to the dictionary
#
# NCT03548649 file added to the dictionary
#
# NCT03599206 file added to the dictionary
#
# NCT00874055 file added to the dictionary
#
# NCT02428257 file added to the dictionary
#
# NCT00368251 file added to the dictionary
#
# NCT00722839 file added to the dictionary
#
# NCT03766295 file added to the dictionary
#
# NCT03164746 file added to the dictionary
#
# NCT01386658 file added to the dictionary
#
# NCT01546155 file added to the dictionary
#
# NCT03593850 file added to the dictionary
#
# NCT02326155 file added to the dictionary
#
# NCT01583023 file added to the dictionary
#
# NCT02282436 file added to the dictionary
#
# NCT01876147 file added to the dictionary
#
# NCT03422094 file added to the dictionary
#
# NCT01167608 file added to the dictionary
#
# NCT01782352 file added to the dictionary
#
# NCT00795275 file added to the dictionary
#
# NCT00372619 file added to the dictionary
#
# NCT02851043 file added to the dictionary
#
# NCT03462329 file added to the dictionary
#
# NCT01847365 file added to the dictionary
#
# NCT03241082 file added to the dictionary
#
# NCT00005472 file added to the dictionary
#
# NCT02101086 file added to the dictionary
#
# NCT00020631 file added to the dictionary
#
# NCT03009240 file added to the dictionary
#
# NCT03162393 file added to the dictionary
#
# NCT00296088 file added to the dictionary
#
# NCT00323141 file added to the dictionary
#
# NCT03471130 file added to the dictionary
#
# NCT00483184 file added to the dictionary
#
# NCT00812214 file added to the dictionary
#
# NCT03684317 file added to the dictionary
#
# NCT03659604 file added to the dictionary
#
# NCT03446950 file added to the dictionary
#
# NCT01264692 file added to the dictionary
#
# NCT01675232 file added to the dictionary
#
# NCT03284645 file added to the dictionary
#
# NCT02123186 file added to the dictionary
#
# NCT00908310 file added to the dictionary
#
# NCT00837876 file added to the dictionary
#
# NCT00738153 file added to the dictionary
#
# NCT03735641 file added to the dictionary
#
# NCT00288301 file added to the dictionary
#
# NCT01798966 file added to the dictionary
#
# NCT02729155 file added to the dictionary
#
# NCT01686594 file added to the dictionary
#
# NCT00503633 file added to the dictionary
#
# NCT01731262 file added to the dictionary
#
# NCT00991900 file added to the dictionary
#
# NCT00955201 file added to the dictionary
#
# NCT02054871 file added to the dictionary
#
# NCT01416467 file added to the dictionary
#
# NCT01500577 file added to the dictionary
#
# NCT03463681 file added to the dictionary
#
# NCT02209259 file added to the dictionary
#
# NCT03317366 file added to the dictionary
#
# NCT00897182 file added to the dictionary
#
# NCT01808560 file added to the dictionary
#
# NCT00800215 file added to the dictionary
#
# NCT03688100 file added to the dictionary
#
# NCT01871935 file added to the dictionary
#
# NCT00527579 file added to the dictionary
#
# NCT01945879 file added to the dictionary
#
# NCT02628262 file added to the dictionary
#
# NCT02732548 file added to the dictionary
#
# NCT03693911 file added to the dictionary
#
# NCT02160041 file added to the dictionary
#
# NCT00013832 file added to the dictionary
#
# NCT02044861 file added to the dictionary
#
# NCT00818116 file added to the dictionary
#
# NCT02908568 file added to the dictionary
#
# NCT01719510 file added to the dictionary
#
# NCT00888277 file added to the dictionary
#
# NCT00002863 file added to the dictionary
#
# NCT02105961 file added to the dictionary
#
# NCT00061308 file added to the dictionary
#
# NCT02073175 file added to the dictionary
#
# NCT00207753 file added to the dictionary
#
# NCT02413489 file added to the dictionary
#
# NCT01419392 file added to the dictionary
#
# NCT00355940 file added to the dictionary
#
# NCT03587857 file added to the dictionary
#
# NCT02785692 file added to the dictionary
#
# NCT00939523 file added to the dictionary
#
# NCT03157856 file added to the dictionary
#
# NCT02372006 file added to the dictionary
#
# NCT01043055 file added to the dictionary
#
# NCT01967953 file added to the dictionary
#
# NCT02330237 file added to the dictionary
#
# NCT01948973 file added to the dictionary
#
# NCT03214731 file added to the dictionary
#
# NCT01513681 file added to the dictionary
#
# NCT00725920 file added to the dictionary
#
# NCT01366079 file added to the dictionary
#
# NCT00894933 file added to the dictionary
#
# NCT00636753 file added to the dictionary
#
# NCT01750853 file added to the dictionary
#
# NCT02206815 file added to the dictionary
#
# NCT00596830 file added to the dictionary
#
# NCT02133157 file added to the dictionary
#
# NCT02969369 file added to the dictionary
#
# NCT00558350 file added to the dictionary
#
# NCT03677882 file added to the dictionary
#
# NCT02793193 file added to the dictionary
#
# NCT03442881 file added to the dictionary
#
# NCT01760239 file added to the dictionary
#
# NCT02065310 file added to the dictionary
#
# NCT01495988 file added to the dictionary
#
# NCT02243384 file added to the dictionary
#
# NCT02954770 file added to the dictionary
#
# NCT00434512 file added to the dictionary
#
# NCT00957372 file added to the dictionary
#
# NCT00716079 file added to the dictionary
#
# NCT00857831 file added to the dictionary
#
# NCT00344721 file added to the dictionary
#
# NCT00947388 file added to the dictionary
#
# NCT00534937 file added to the dictionary
#
# NCT00281333 file added to the dictionary
#
# NCT01448733 file added to the dictionary
#
# NCT03051607 file added to the dictionary
#
# NCT03741673 file added to the dictionary
#
# NCT00784719 file added to the dictionary
#
# NCT02368288 file added to the dictionary
#
# NCT03266198 file added to the dictionary
#
# NCT02978885 file added to the dictionary
#
# NCT03602170 file added to the dictionary
#
# NCT00978965 file added to the dictionary
#
# NCT03652753 file added to the dictionary
#
# NCT01022866 file added to the dictionary
#
# NCT03172182 file added to the dictionary
#
# NCT00534664 file added to the dictionary
#
# NCT00371163 file added to the dictionary
#
# NCT00352547 file added to the dictionary
#
# NCT01388374 file added to the dictionary
#
# NCT02117180 file added to the dictionary
#
# NCT02995070 file added to the dictionary
#
# NCT03396900 file added to the dictionary
#
# NCT01423227 file added to the dictionary
#
# NCT02384967 file added to the dictionary
#
# NCT00326573 file added to the dictionary
#
# NCT00030381 file added to the dictionary
#
# NCT02219139 file added to the dictionary
#
# NCT03481010 file added to the dictionary
#
# NCT00736554 file added to the dictionary
#
# NCT00006196 file added to the dictionary
#
# NCT03519711 file added to the dictionary
#
# NCT02872610 file added to the dictionary
#
# NCT01341158 file added to the dictionary
#
# NCT02815462 file added to the dictionary
#
# NCT00806273 file added to the dictionary
#
# NCT00035789 file added to the dictionary
#
# NCT00507533 file added to the dictionary
#
# NCT01102595 file added to the dictionary
#
# NCT02805842 file added to the dictionary
#
# NCT01073436 file added to the dictionary
#
# NCT00001202 file added to the dictionary
#
# NCT02596282 file added to the dictionary
#
# NCT00422604 file added to the dictionary
#
# NCT02209909 file added to the dictionary
#
# NCT00593554 file added to the dictionary
#
# NCT01756599 file added to the dictionary
#
# NCT02723318 file added to the dictionary
#
# NCT02575469 file added to the dictionary
#
# NCT01054300 file added to the dictionary
#
# NCT00732875 file added to the dictionary
#
# NCT03603652 file added to the dictionary
#
# NCT03548402 file added to the dictionary
#
# NCT03514355 file added to the dictionary
#
# NCT01545011 file added to the dictionary
#
# NCT01074749 file added to the dictionary
#
# NCT01369979 file added to the dictionary
#
# NCT01658748 file added to the dictionary
#
# NCT02945644 file added to the dictionary
#
# NCT00578721 file added to the dictionary
#
# NCT03067818 file added to the dictionary
#
# NCT01123837 file added to the dictionary
#
# NCT03532191 file added to the dictionary
#
# NCT02835638 file added to the dictionary
#
# NCT01398228 file added to the dictionary
#
# NCT03636373 file added to the dictionary
#
# NCT01885468 file added to the dictionary
#
# NCT00885027 file added to the dictionary
#
# NCT03005535 file added to the dictionary
#
# NCT03445494 file added to the dictionary
#
# NCT00141141 file added to the dictionary
#
# NCT03488394 file added to the dictionary
#
# NCT00568724 file added to the dictionary
#
# NCT02698202 file added to the dictionary
#
# NCT00679068 file added to the dictionary
#
# NCT00971763 file added to the dictionary
#
# NCT00381524 file added to the dictionary
#
# NCT01937351 file added to the dictionary
#
# NCT02923674 file added to the dictionary
#
# NCT01708590 file added to the dictionary
#
# NCT02109185 file added to the dictionary
#
# NCT00634140 file added to the dictionary
#
# NCT01438372 file added to the dictionary
#
# NCT00444392 file added to the dictionary
#
# NCT03742960 file added to the dictionary
#
# NCT03163511 file added to the dictionary
#
# NCT01765556 file added to the dictionary
#
# NCT01272544 file added to the dictionary
#
# NCT01144728 file added to the dictionary
#
# NCT02776085 file added to the dictionary
#
# NCT01897454 file added to the dictionary
#
# NCT01124786 file added to the dictionary
#
# NCT03706677 file added to the dictionary
#
# NCT02075099 file added to the dictionary
#
# NCT00356083 file added to the dictionary
#
# NCT01859663 file added to the dictionary
#
# NCT02896556 file added to the dictionary
#
# NCT00373217 file added to the dictionary
#
# NCT02762019 file added to the dictionary
#
# NCT03458000 file added to the dictionary
#
# NCT03208478 file added to the dictionary
#
# NCT01971892 file added to the dictionary
#
# NCT02522650 file added to the dictionary
#
# NCT03463525 file added to the dictionary
#
# NCT01205282 file added to the dictionary
#
# NCT00321009 file added to the dictionary
#
# NCT03706339 file added to the dictionary
#
# NCT03415464 file added to the dictionary
#
# NCT02059798 file added to the dictionary
#
# NCT01060449 file added to the dictionary
#
# NCT01610518 file added to the dictionary
#
# NCT03245801 file added to the dictionary
#
# NCT02506686 file added to the dictionary
#
# NCT02901574 file added to the dictionary
#
# NCT00713310 file added to the dictionary
#
# NCT00043797 file added to the dictionary
#
# NCT03497507 file added to the dictionary
#
# NCT02590627 file added to the dictionary
#
# NCT01634451 file added to the dictionary
#
# NCT01304017 file added to the dictionary
#
# NCT02367976 file added to the dictionary
#
# NCT00789776 file added to the dictionary
#
# NCT03009669 file added to the dictionary
#
# NCT01818011 file added to the dictionary
#
# NCT03772080 file added to the dictionary
#
# NCT03668782 file added to the dictionary
#
# NCT01989052 file added to the dictionary
#
# NCT03099252 file added to the dictionary
#
# NCT02317705 file added to the dictionary
#
# NCT03020238 file added to the dictionary
#
# NCT02447341 file added to the dictionary
#
# NCT00532818 file added to the dictionary
#
# NCT03125369 file added to the dictionary
#
# NCT03182101 file added to the dictionary
#
# NCT01532258 file added to the dictionary
#
# NCT01995877 file added to the dictionary
#
# NCT02451046 file added to the dictionary
#
# NCT03380221 file added to the dictionary
#
# NCT01589627 file added to the dictionary
#
# NCT00674375 file added to the dictionary
#
# NCT03617341 file added to the dictionary
#
# NCT01202513 file added to the dictionary
#
# NCT00917397 file added to the dictionary
#
# NCT01733277 file added to the dictionary
#
# NCT03022994 file added to the dictionary
#
# NCT01716975 file added to the dictionary
#
# NCT02014896 file added to the dictionary
#
# NCT03318497 file added to the dictionary
#
# NCT01951014 file added to the dictionary
#
# NCT02073825 file added to the dictionary
#
# NCT02581475 file added to the dictionary
#
# NCT01391637 file added to the dictionary
#
# NCT03294122 file added to the dictionary
#
# NCT01117415 file added to the dictionary
#
# NCT00541970 file added to the dictionary
#
# NCT01578200 file added to the dictionary
#
# NCT00000271 file added to the dictionary
#
# NCT03035942 file added to the dictionary
#
# NCT03712618 file added to the dictionary
#
# NCT00380393 file added to the dictionary
#
# NCT01928069 file added to the dictionary
#
# NCT00591760 file added to the dictionary
#
# NCT01582347 file added to the dictionary
#
# NCT00598988 file added to the dictionary
#
# NCT03112655 file added to the dictionary
#
# NCT02750514 file added to the dictionary
#
# NCT00718315 file added to the dictionary
#
# NCT01886755 file added to the dictionary
#
# NCT02306200 file added to the dictionary
#
# NCT01210898 file added to the dictionary
#
# NCT00003585 file added to the dictionary
#
# NCT00023127 file added to the dictionary
#
# NCT00056433 file added to the dictionary
#
# NCT01145014 file added to the dictionary
#
# NCT01987271 file added to the dictionary
#
# NCT01806948 file added to the dictionary
#
# NCT01993589 file added to the dictionary
#
# NCT03727516 file added to the dictionary
#
# NCT02317523 file added to the dictionary
#
# NCT00577187 file added to the dictionary
#
# NCT00774813 file added to the dictionary
#
# NCT01727804 file added to the dictionary
#
# NCT03419871 file added to the dictionary
#
# NCT00986050 file added to the dictionary
#
# NCT03528460 file added to the dictionary
#
# NCT00910026 file added to the dictionary
#
# NCT03729739 file added to the dictionary
#
# NCT03608085 file added to the dictionary
#
# NCT01504724 file added to the dictionary
#
# NCT01287104 file added to the dictionary
#
# NCT01050829 file added to the dictionary
#
# NCT03317353 file added to the dictionary
#
# NCT03407469 file added to the dictionary
#
# NCT00771017 file added to the dictionary
#
# NCT02994238 file added to the dictionary
#
# NCT02858154 file added to the dictionary
#
# NCT01184339 file added to the dictionary
#
# NCT00150241 file added to the dictionary
#
# NCT02296996 file added to the dictionary
#
# NCT02513251 file added to the dictionary
#
# NCT00823823 file added to the dictionary
#
# NCT01582971 file added to the dictionary
#
# NCT03508362 file added to the dictionary
#
# NCT02630550 file added to the dictionary
#
# ...
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Expanded Access file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational [Patient Registry] file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# N/A file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational [Patient Registry] file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational [Patient Registry] file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# Interventional file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Observational file added to the dictionary
#
# Interventional file added to the dictionary
#
# CPU times: user 221 ms, sys: 49.8 ms, total: 271 ms
# Wall time: 259 ms
# Dictionary created

# %%
'''
Check number of values for each key before creating a dataframe
'''

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))
# Out:
# nct_id 1000
# study_first_submitted 1000
# source 1000
# brief_title 1000
# study_type 1000

# %%
# Function for adding new tag

def add_new_tags(new_key):
    all_data_dictionary.setdefault(new_key, [])

    for n in all_parsed_files:
            value_conditions = n.find(new_key)
            if n.find(new_key) is not None:
                all_data_dictionary[new_key].append(value_conditions.text)
            else:
                all_data_dictionary[new_key].append('None')

    print('{} tag added'.format(new_key))

# %%
add_new_tags('condition')
add_new_tags('condition_browse/mesh_term')
add_new_tags('intervention_browse/mesh_term')
add_new_tags('detailed_description/textblock')
add_new_tags('brief_summary/textblock')
add_new_tags('location/facility/address/city')
add_new_tags('location/facility/address/country')
add_new_tags('location/facility/address/zip')
# Out:
# condition tag added
# condition_browse/mesh_term tag added
# intervention_browse/mesh_term tag added
# detailed_description/textblock tag added
# brief_summary/textblock tag added
# location/facility/address/city tag added
# location/facility/address/country tag added
# location/facility/address/zip tag added

# %%
'''
Check keys and number of values for each one
'''

print(all_data_dictionary.keys())

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))
# Out:
# dict_keys(['nct_id', 'study_first_submitted', 'source', 'brief_title', 'study_type', 'condition', 'condition_browse/mesh_term', 'intervention_browse/mesh_term', 'detailed_description/textblock', 'brief_summary/textblock', 'location/facility/address/city', 'location/facility/address/country', 'location/facility/address/zip'])
# nct_id 1000
# study_first_submitted 1000
# source 1000
# brief_title 1000
# study_type 1000
# condition 1000
# condition_browse/mesh_term 1000
# intervention_browse/mesh_term 1000
# detailed_description/textblock 1000
# brief_summary/textblock 1000
# location/facility/address/city 1000
# location/facility/address/country 1000
# location/facility/address/zip 1000

# %% [markdown]
# ## Dump results in a json file

# %%
# Dump dictionary into a JSON file
with open('{}{}.json'.format(path_to_json_file, json_file), 'w') as fp:
    json.dump(all_data_dictionary, fp)
    print('\nJSON file created\n')

    json_size = round(os.path.getsize(path_to_json_file + json_file + '.json') / 1000000, 2)
    print("JSON file: {} Mb".format(json_size))
# Out:
# JSON file created
#
# JSON file: 2.27 Mb

# %% [markdown]
# ## Test: Import json file in a dataframe

# %%
# Import json into a dataframe
file = '{}{}.json'.format(path_to_json_file, json_file)

df = pd.read_json(file)

# %%
df.head()
# Out:
#         nct_id study_first_submitted  \
# 0  NCT02802423         June 13, 2016
# 1  NCT02278575      October 28, 2014
# 2  NCT00921440         June 15, 2009
# 3  NCT03706820    September 29, 2018
# 4  NCT00913380          May 15, 2009
#
#                                        source  \
# 0                               BioLite, Inc.
# 1                      Vastra Gotaland Region
# 2                       University of Cologne
# 3        Aristotle University Of Thessaloniki
# 4  Seoul National University Bundang Hospital
#
#                                          brief_title      study_type  \
# 0  A Phase I/II, Open Label Study to Evaluate the...  Interventional
# 1  Atenativ Effect on Uterine Blood Flow and Pree...  Interventional
# 2  Computed Tomography Coronary Angiography (CTCA...   Observational
# 3  Exercise Hemodynamics in Patients With Pulmona...   Observational
# 4  Diagnosis of Acute Appendicitis: Low-dose Comp...  Interventional
#
#                          condition condition_browse/mesh_term  \
# 0    Triple Negative Breast Cancer           Breast Neoplasms
# 1      Antithrombin III Deficiency              Pre-Eclampsia
# 2          Coronary Artery Disease    Coronary Artery Disease
# 3  Exercise Pulmonary Hypertension    Hypertension, Pulmonary
# 4                     Appendicitis               Appendicitis
#
#   intervention_browse/mesh_term  \
# 0                     Docetaxel
# 1                 Antithrombins
# 2                          None
# 3                          None
# 4                          None
#
#                       detailed_description/textblock  \
# 0                                               None
# 1  \n      The study will be an open controlled p...
# 2  \n      A total of 50 patients prospectively u...
# 3  \n      Patients with fibrotic pulmonary disea...
# 4  \n      Acute appendicitis is a very common di...
#
#                              brief_summary/textblock  \
# 0  \n      The primary purpose of this study is t...
# 1  \n      The study will be an open controlled p...
# 2  \n      The investigators' rationale was to ev...
# 3  \n      The study evaluates the rest and exerc...
# 4  \n      The purpose of this study is to determ...
#
#   location/facility/address/city location/facility/address/country  \
# 0                           None                              None
# 1                     Gothenburg                            Sweden
# 2                           None                              None
# 3                   Thessaloniki                            Greece
# 4                       Seongnam                Korea, Republic of
#
#   location/facility/address/zip
# 0                          None
# 1                         41685
# 2                          None
# 3                         57010
# 4                       463-707

# %%
df['location/facility/address/city'].nunique()
# Out:
# 453
