# %% [markdown]
# # Clinical trials: Parse all XML files

# %%
#Data: clinicaltrials.gov

# %%
# reset variables and turn off autosave
# %reset
# %autosave 0
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import zipfile
import sys
import time
import json
import re
import os
import xml.etree.ElementTree as ET
import shutil
import pandas as pd
from collections import Counter

# %%
# Print messages to the terminal

sys.stdout = open('/dev/stdout', 'w')

# %% [markdown]
# ## Setup: create paths and folders

# %%
'''
Create paths and folders
'''

# Folders with xml files
path_to_all_xml_trials = os.path.abspath('../data/all_trials/')

# Test folder ~100 files
path_to_test_folder = os.path.abspath('../data/test/')

#Remove old files from test folder
try:
    shutil.rmtree(path_to_test_folder) 
except FileNotFoundError:
    pass

# Path for json folder
path_to_json_file = os.path.abspath('../data/json/')

# Variable for all parsed files
all_parsed_files = []

print('\nPaths and folders created\n')

# %%
# Create folders

create_folders_errors = []

def create_folders(paths=[]):
    for p in paths:
        try:
            os.mkdir(p)
            if p:
                print('{} created'.format(p))
        except IOError as e:
            create_folders_errors.append(e)
            pass

    print('\nSetup folders created with exceptions: {}\n'.format(create_folders_errors))
    
all_folders = [path_to_all_xml_trials, path_to_test_folder, path_to_json_file]
    
# create folders
create_folders(all_folders)

# %% [markdown]
# ### Create test folder with n random files

# %%
'''
Select n random files from all trials and save them in test folder
'''
files_for_test = 2000

import random

# Pending: If files in test folder, delete them
random_files = []
random_files = random.sample(os.listdir(path_to_all_xml_trials), files_for_test)
print('Random files: {}'.format(len(random_files)))

for f in random_files:
    src = os.path.join(path_to_all_xml_trials, f)
    shutil.copy(src, path_to_test_folder)

# %%
print(random_files[0:5])

# %% [markdown]
# ## Parse all xml files

# %%
'''
Parse all xml files and save them in a all_parsed_files variable.
Slow. Checks for xml files
'''

def parse_xml_files(path_to_folder):
    for filename in os.listdir(path_to_folder):
#         if not filename.endswith('.xml'): continue
        fullname = os.path.join(path_to_folder, filename)
        all_parsed_files.append(ET.parse(fullname).getroot())
        
        # Checking message to the terminal
        print("{} file parsed\n".format(fullname))

    print('Number of files parsed: {}\n'.format(len(all_parsed_files)))
        
    return all_parsed_files

# %%
# Run function
all_parsed_files.clear()
# %time parse_xml_files(path_to_test_folder)
# Out:
# [<Element 'clinical_study' at 0x11d24b3b8>,
#  <Element 'clinical_study' at 0x11d4fd7c8>,
#  <Element 'clinical_study' at 0x11d45a9f8>,
#  <Element 'clinical_study' at 0x11d215c28>,
#  <Element 'clinical_study' at 0x11d2531d8>,
#  <Element 'clinical_study' at 0x11d247ae8>,
#  <Element 'clinical_study' at 0x11d525688>,
#  <Element 'clinical_study' at 0x11d53fae8>,
#  <Element 'clinical_study' at 0x11d3f9868>,
#  <Element 'clinical_study' at 0x11c9f6a48>,
#  <Element 'clinical_study' at 0x11d191278>,
#  <Element 'clinical_study' at 0x11c916bd8>,
#  <Element 'clinical_study' at 0x11c36dc78>,
#  <Element 'clinical_study' at 0x11ce4e958>,
#  <Element 'clinical_study' at 0x11c86a9f8>,
#  <Element 'clinical_study' at 0x11c7c8688>,
#  <Element 'clinical_study' at 0x11c7a9cc8>,
#  <Element 'clinical_study' at 0x11c4c5278>,
#  <Element 'clinical_study' at 0x11c7628b8>,
#  <Element 'clinical_study' at 0x11c6e0e08>,
#  <Element 'clinical_study' at 0x11db23688>,
#  <Element 'clinical_study' at 0x11db655e8>,
#  <Element 'clinical_study' at 0x11dcb7408>,
#  <Element 'clinical_study' at 0x11dce63b8>,
#  <Element 'clinical_study' at 0x11e037cc8>,
#  <Element 'clinical_study' at 0x11e0b8b88>,
#  <Element 'clinical_study' at 0x11e12aa98>,
#  <Element 'clinical_study' at 0x11c5a0548>,
#  <Element 'clinical_study' at 0x11d502458>,
#  <Element 'clinical_study' at 0x11d4f7458>,
#  <Element 'clinical_study' at 0x11d4d66d8>,
#  <Element 'clinical_study' at 0x11d4f2f98>,
#  <Element 'clinical_study' at 0x11d274b88>,
#  <Element 'clinical_study' at 0x11d270908>,
#  <Element 'clinical_study' at 0x11d26d4f8>,
#  <Element 'clinical_study' at 0x11e09f958>,
#  <Element 'clinical_study' at 0x11e0a5318>,
#  <Element 'clinical_study' at 0x11cd3bf48>,
#  <Element 'clinical_study' at 0x11cd62598>,
#  <Element 'clinical_study' at 0x11d3a4958>,
#  <Element 'clinical_study' at 0x11d39b0e8>,
#  <Element 'clinical_study' at 0x11d395ae8>,
#  <Element 'clinical_study' at 0x11d3a0228>,
#  <Element 'clinical_study' at 0x11d3c1688>,
#  <Element 'clinical_study' at 0x11c616818>,
#  <Element 'clinical_study' at 0x11c60ac78>,
#  <Element 'clinical_study' at 0x11c5f6f98>,
#  <Element 'clinical_study' at 0x11c8c4278>,
#  <Element 'clinical_study' at 0x11c8b98b8>,
#  <Element 'clinical_study' at 0x11c8cb548>,
#  <Element 'clinical_study' at 0x11c709ae8>,
#  <Element 'clinical_study' at 0x11c6e8f48>,
#  <Element 'clinical_study' at 0x11c7089a8>,
#  <Element 'clinical_study' at 0x11c8382c8>,
#  <Element 'clinical_study' at 0x11c8364a8>,
#  <Element 'clinical_study' at 0x11e0bfbd8>,
#  <Element 'clinical_study' at 0x11cbc4a98>,
#  <Element 'clinical_study' at 0x11cbdb958>,
#  <Element 'clinical_study' at 0x11d15aae8>,
#  <Element 'clinical_study' at 0x11d16b8b8>,
#  <Element 'clinical_study' at 0x11c6d3228>,
#  <Element 'clinical_study' at 0x11d0252c8>,
#  <Element 'clinical_study' at 0x11d2a4f98>,
#  <Element 'clinical_study' at 0x11d022e58>,
#  <Element 'clinical_study' at 0x11d0134a8>,
#  <Element 'clinical_study' at 0x11d01a0e8>,
#  <Element 'clinical_study' at 0x11d03ed18>,
#  <Element 'clinical_study' at 0x11c452138>,
#  <Element 'clinical_study' at 0x11c430d18>,
#  <Element 'clinical_study' at 0x11c43bcc8>,
#  <Element 'clinical_study' at 0x10b4e4d68>,
#  <Element 'clinical_study' at 0x10b4f6818>,
#  <Element 'clinical_study' at 0x10b4db278>,
#  <Element 'clinical_study' at 0x11d0de3b8>,
#  <Element 'clinical_study' at 0x11d0ce688>,
#  <Element 'clinical_study' at 0x11c1eb0e8>,
#  <Element 'clinical_study' at 0x11c1e80e8>,
#  <Element 'clinical_study' at 0x11c1ffcc8>,
#  <Element 'clinical_study' at 0x11d1d36d8>,
#  <Element 'clinical_study' at 0x11d1d7688>,
#  <Element 'clinical_study' at 0x11d1f1868>,
#  <Element 'clinical_study' at 0x11d1ebea8>,
#  <Element 'clinical_study' at 0x11c2a2228>,
#  <Element 'clinical_study' at 0x11c27f8b8>,
#  <Element 'clinical_study' at 0x11c898908>,
#  <Element 'clinical_study' at 0x11db92958>,
#  <Element 'clinical_study' at 0x11dbb5818>,
#  <Element 'clinical_study' at 0x11dba6a48>,
#  <Element 'clinical_study' at 0x11db96a98>,
#  <Element 'clinical_study' at 0x11caf1c28>,
#  <Element 'clinical_study' at 0x11caf6f48>,
#  <Element 'clinical_study' at 0x11d40a9a8>,
#  <Element 'clinical_study' at 0x11d4bcea8>,
#  <Element 'clinical_study' at 0x11d4a94f8>,
#  <Element 'clinical_study' at 0x11ce13a98>,
#  <Element 'clinical_study' at 0x11ce1b6d8>,
#  <Element 'clinical_study' at 0x11d141b88>,
#  <Element 'clinical_study' at 0x11d47e7c8>,
#  <Element 'clinical_study' at 0x11d45de08>,
#  <Element 'clinical_study' at 0x11d448598>,
#  <Element 'clinical_study' at 0x11d472cc8>,
#  <Element 'clinical_study' at 0x11ccd3688>,
#  <Element 'clinical_study' at 0x11ccc76d8>,
#  <Element 'clinical_study' at 0x11cce1f98>,
#  <Element 'clinical_study' at 0x11ccc3458>,
#  <Element 'clinical_study' at 0x11cce2188>,
#  <Element 'clinical_study' at 0x11cb82408>,
#  <Element 'clinical_study' at 0x11cb93db8>,
#  <Element 'clinical_study' at 0x11c2fd0e8>,
#  <Element 'clinical_study' at 0x11c2edf98>,
#  <Element 'clinical_study' at 0x11c30c6d8>,
#  <Element 'clinical_study' at 0x11c516458>,
#  <Element 'clinical_study' at 0x11c314d68>,
#  <Element 'clinical_study' at 0x11cd80638>,
#  <Element 'clinical_study' at 0x11cd87d18>,
#  <Element 'clinical_study' at 0x11cda6f98>,
#  <Element 'clinical_study' at 0x11d33fdb8>,
#  <Element 'clinical_study' at 0x11d31d5e8>,
#  <Element 'clinical_study' at 0x11d32f3b8>,
#  <Element 'clinical_study' at 0x11d31a3b8>,
#  <Element 'clinical_study' at 0x11c7d1e08>,
#  <Element 'clinical_study' at 0x11c7d0778>,
#  <Element 'clinical_study' at 0x11c2a3d18>,
#  <Element 'clinical_study' at 0x11c2a89f8>,
#  <Element 'clinical_study' at 0x11d3ca368>,
#  <Element 'clinical_study' at 0x11cfe81d8>,
#  <Element 'clinical_study' at 0x11c9d66d8>,
#  <Element 'clinical_study' at 0x11c9bb2c8>,
#  <Element 'clinical_study' at 0x11c9029a8>,
#  <Element 'clinical_study' at 0x11c8e4908>,
#  <Element 'clinical_study' at 0x11c900408>,
#  <Element 'clinical_study' at 0x11c2314f8>,
#  <Element 'clinical_study' at 0x11c22d688>,
#  <Element 'clinical_study' at 0x11c239db8>,
#  <Element 'clinical_study' at 0x11c25d8b8>,
#  <Element 'clinical_study' at 0x11ca01638>,
#  <Element 'clinical_study' at 0x11ca0ac78>,
#  <Element 'clinical_study' at 0x11c96d3b8>,
#  <Element 'clinical_study' at 0x11c9799a8>,
#  <Element 'clinical_study' at 0x11c999908>,
#  <Element 'clinical_study' at 0x10b52ca48>,
#  <Element 'clinical_study' at 0x11c77ef98>,
#  <Element 'clinical_study' at 0x11c78e278>,
#  <Element 'clinical_study' at 0x11cdd4868>,
#  <Element 'clinical_study' at 0x11cdd7638>,
#  <Element 'clinical_study' at 0x11ce60ef8>,
#  <Element 'clinical_study' at 0x11ce2d278>,
#  <Element 'clinical_study' at 0x11ce5bb88>,
#  <Element 'clinical_study' at 0x11dc9b138>,
#  <Element 'clinical_study' at 0x11e02cea8>,
#  <Element 'clinical_study' at 0x11e022c78>,
#  <Element 'clinical_study' at 0x11d7a0d18>,
#  <Element 'clinical_study' at 0x11d797868>,
#  <Element 'clinical_study' at 0x11d78d048>,
#  <Element 'clinical_study' at 0x11de64228>,
#  <Element 'clinical_study' at 0x11de58458>,
#  <Element 'clinical_study' at 0x11d8a5bd8>,
#  <Element 'clinical_study' at 0x11d88a688>,
#  <Element 'clinical_study' at 0x11d89de08>,
#  <Element 'clinical_study' at 0x11d8b50e8>,
#  <Element 'clinical_study' at 0x11cc62228>,
#  <Element 'clinical_study' at 0x11cc50e08>,
#  <Element 'clinical_study' at 0x11cc52c78>,
#  <Element 'clinical_study' at 0x11cf8c728>,
#  <Element 'clinical_study' at 0x11cb43908>,
#  <Element 'clinical_study' at 0x11cb423b8>,
#  <Element 'clinical_study' at 0x11cb57d68>,
#  <Element 'clinical_study' at 0x11dbc5138>,
#  <Element 'clinical_study' at 0x11dbd34a8>,
#  <Element 'clinical_study' at 0x11dbe3818>,
#  <Element 'clinical_study' at 0x11dbf29a8>,
#  <Element 'clinical_study' at 0x11d98a7c8>,
#  <Element 'clinical_study' at 0x11d996228>,
#  <Element 'clinical_study' at 0x11d99bd68>,
#  <Element 'clinical_study' at 0x11d9a74a8>,
#  <Element 'clinical_study' at 0x11d9b52c8>,
#  <Element 'clinical_study' at 0x11d9b8ea8>,
#  <Element 'clinical_study' at 0x11dd4bc78>,
#  <Element 'clinical_study' at 0x11dd6e138>,
#  <Element 'clinical_study' at 0x11dd756d8>,
#  <Element 'clinical_study' at 0x11df40638>,
#  <Element 'clinical_study' at 0x11df4d408>,
#  <Element 'clinical_study' at 0x11df61318>,
#  <Element 'clinical_study' at 0x11d86e188>,
#  <Element 'clinical_study' at 0x11daad958>,
#  <Element 'clinical_study' at 0x11d93f6d8>,
#  <Element 'clinical_study' at 0x11d947a48>,
#  <Element 'clinical_study' at 0x11d955458>,
#  <Element 'clinical_study' at 0x11d966728>,
#  <Element 'clinical_study' at 0x11d970b88>,
#  <Element 'clinical_study' at 0x11d9c2a98>,
#  <Element 'clinical_study' at 0x11d9d27c8>,
#  <Element 'clinical_study' at 0x11d9ee0e8>,
#  <Element 'clinical_study' at 0x11c3be228>,
#  <Element 'clinical_study' at 0x11c3d6f48>,
#  <Element 'clinical_study' at 0x11c3e1d68>,
#  <Element 'clinical_study' at 0x11ceb7b88>,
#  <Element 'clinical_study' at 0x11cec7098>,
#  <Element 'clinical_study' at 0x11ced0048>,
#  <Element 'clinical_study' at 0x11cee8e08>,
#  <Element 'clinical_study' at 0x11d0534f8>,
#  <Element 'clinical_study' at 0x11d05e048>,
#  <Element 'clinical_study' at 0x11d078a48>,
#  <Element 'clinical_study' at 0x11d082d18>,
#  <Element 'clinical_study' at 0x11d5930e8>,
#  <Element 'clinical_study' at 0x11d598f98>,
#  <Element 'clinical_study' at 0x11d5aaae8>,
#  <Element 'clinical_study' at 0x11d5e8598>,
#  <Element 'clinical_study' at 0x11d623c78>,
#  <Element 'clinical_study' at 0x11d632818>,
#  <Element 'clinical_study' at 0x11d6440e8>,
#  <Element 'clinical_study' at 0x11d683138>,
#  <Element 'clinical_study' at 0x11d686d68>,
#  <Element 'clinical_study' at 0x11d68e8b8>,
#  <Element 'clinical_study' at 0x11d69d318>,
#  <Element 'clinical_study' at 0x11d6a9368>,
#  <Element 'clinical_study' at 0x11d6b3ef8>,
#  <Element 'clinical_study' at 0x11d6baea8>,
#  <Element 'clinical_study' at 0x11d6cc228>,
#  <Element 'clinical_study' at 0x11d6d7d68>,
#  <Element 'clinical_study' at 0x11d6e6db8>,
#  <Element 'clinical_study' at 0x11d6f5638>,
#  <Element 'clinical_study' at 0x11d700f98>,
#  <Element 'clinical_study' at 0x11d7135e8>,
#  <Element 'clinical_study' at 0x11d8351d8>,
#  <Element 'clinical_study' at 0x11d8ffea8>,
#  <Element 'clinical_study' at 0x11d92af48>,
#  <Element 'clinical_study' at 0x11d939f48>,
#  <Element 'clinical_study' at 0x11da0a1d8>,
#  <Element 'clinical_study' at 0x11da1c6d8>,
#  <Element 'clinical_study' at 0x11da25b88>,
#  <Element 'clinical_study' at 0x11da2f688>,
#  <Element 'clinical_study' at 0x11da43818>,
#  <Element 'clinical_study' at 0x11da55098>,
#  <Element 'clinical_study' at 0x11dd9bb38>,
#  <Element 'clinical_study' at 0x11ddac688>,
#  <Element 'clinical_study' at 0x11ddb3ae8>,
#  <Element 'clinical_study' at 0x11ddc28b8>,
#  <Element 'clinical_study' at 0x11deac9f8>,
#  <Element 'clinical_study' at 0x11deccb88>,
#  <Element 'clinical_study' at 0x11e1ac958>,
#  <Element 'clinical_study' at 0x11e1bb4f8>,
#  <Element 'clinical_study' at 0x11e1ca098>,
#  <Element 'clinical_study' at 0x11e1d3868>,
#  <Element 'clinical_study' at 0x11e1df958>,
#  <Element 'clinical_study' at 0x11e1f2278>,
#  <Element 'clinical_study' at 0x11e1fc5e8>,
#  <Element 'clinical_study' at 0x11e207778>,
#  <Element 'clinical_study' at 0x11e211d68>,
#  <Element 'clinical_study' at 0x11e23df48>,
#  <Element 'clinical_study' at 0x11e24f728>,
#  <Element 'clinical_study' at 0x11e259778>,
#  <Element 'clinical_study' at 0x11e273638>,
#  <Element 'clinical_study' at 0x11e277f98>,
#  <Element 'clinical_study' at 0x11e286458>,
#  <Element 'clinical_study' at 0x11e290408>,
#  <Element 'clinical_study' at 0x11e2a22c8>,
#  <Element 'clinical_study' at 0x11e2ebbd8>,
#  <Element 'clinical_study' at 0x11e2f5228>,
#  <Element 'clinical_study' at 0x11e2fa958>,
#  <Element 'clinical_study' at 0x11e32b908>,
#  <Element 'clinical_study' at 0x11e339868>,
#  <Element 'clinical_study' at 0x11e34cf98>,
#  <Element 'clinical_study' at 0x11e35d5e8>,
#  <Element 'clinical_study' at 0x11e36d868>,
#  <Element 'clinical_study' at 0x11e377e58>,
#  <Element 'clinical_study' at 0x11e384228>,
#  <Element 'clinical_study' at 0x11e3bf408>,
#  <Element 'clinical_study' at 0x11e3cfd18>,
#  <Element 'clinical_study' at 0x11e3dacc8>,
#  <Element 'clinical_study' at 0x11e3e89f8>,
#  <Element 'clinical_study' at 0x11e3f2b38>,
#  <Element 'clinical_study' at 0x11e3fbdb8>,
#  <Element 'clinical_study' at 0x11e40d138>,
#  <Element 'clinical_study' at 0x11e417958>,
#  <Element 'clinical_study' at 0x11e42ec78>,
#  <Element 'clinical_study' at 0x11e43d278>,
#  <Element 'clinical_study' at 0x11e4494f8>,
#  <Element 'clinical_study' at 0x11e44cf98>,
#  <Element 'clinical_study' at 0x11e45c138>,
#  <Element 'clinical_study' at 0x11e46ecc8>,
#  <Element 'clinical_study' at 0x11e480138>,
#  <Element 'clinical_study' at 0x11e48aea8>,
#  <Element 'clinical_study' at 0x11e49c188>,
#  <Element 'clinical_study' at 0x11e4a71d8>,
#  <Element 'clinical_study' at 0x11e4b4db8>,
#  <Element 'clinical_study' at 0x11e4c38b8>,
#  <Element 'clinical_study' at 0x11e4d3ae8>,
#  <Element 'clinical_study' at 0x11e4e3408>,
#  <Element 'clinical_study' at 0x11e4ec818>,
#  <Element 'clinical_study' at 0x11e4f5e08>,
#  <Element 'clinical_study' at 0x11e505548>,
#  <Element 'clinical_study' at 0x11e509138>,
#  <Element 'clinical_study' at 0x11e526278>,
#  <Element 'clinical_study' at 0x11e52ae08>,
#  <Element 'clinical_study' at 0x11e54c638>,
#  <Element 'clinical_study' at 0x11e5ce138>,
#  <Element 'clinical_study' at 0x11e5d7b38>,
#  <Element 'clinical_study' at 0x11e5e7b38>,
#  <Element 'clinical_study' at 0x11e6311d8>,
#  <Element 'clinical_study' at 0x11e63e048>,
#  <Element 'clinical_study' at 0x11e707688>,
#  <Element 'clinical_study' at 0x11e7334f8>,
#  <Element 'clinical_study' at 0x11e7b2778>,
#  <Element 'clinical_study' at 0x11e7bdae8>,
#  <Element 'clinical_study' at 0x11e7c6a98>,
#  <Element 'clinical_study' at 0x11e7d8368>,
#  <Element 'clinical_study' at 0x11e7e4548>,
#  <Element 'clinical_study' at 0x11e803e08>,
#  <Element 'clinical_study' at 0x11e8114f8>,
#  <Element 'clinical_study' at 0x11e835db8>,
#  <Element 'clinical_study' at 0x11e854a98>,
#  <Element 'clinical_study' at 0x11e87ae58>,
#  <Element 'clinical_study' at 0x11e88d408>,
#  <Element 'clinical_study' at 0x11e89e818>,
#  <Element 'clinical_study' at 0x11e8aff98>,
#  <Element 'clinical_study' at 0x11e8c08b8>,
#  <Element 'clinical_study' at 0x11e8ce318>,
#  <Element 'clinical_study' at 0x11e8d72c8>,
#  <Element 'clinical_study' at 0x11e8e3098>,
#  <Element 'clinical_study' at 0x11e8ef8b8>,
#  <Element 'clinical_study' at 0x11e8fff98>,
#  <Element 'clinical_study' at 0x11e90f8b8>,
#  <Element 'clinical_study' at 0x11e924548>,
#  <Element 'clinical_study' at 0x11e932638>,
#  <Element 'clinical_study' at 0x11e93a9a8>,
#  <Element 'clinical_study' at 0x11e94ac78>,
#  <Element 'clinical_study' at 0x11e955908>,
#  <Element 'clinical_study' at 0x11e970868>,
#  <Element 'clinical_study' at 0x11e97c6d8>,
#  <Element 'clinical_study' at 0x11e9b0ef8>,
#  <Element 'clinical_study' at 0x11e9bf1d8>,
#  <Element 'clinical_study' at 0x11e9cb6d8>,
#  <Element 'clinical_study' at 0x11e9d5cc8>,
#  <Element 'clinical_study' at 0x11e9deef8>,
#  <Element 'clinical_study' at 0x11ea0f908>,
#  <Element 'clinical_study' at 0x11ea1a458>,
#  <Element 'clinical_study' at 0x11ea31598>,
#  <Element 'clinical_study' at 0x11ea3a778>,
#  <Element 'clinical_study' at 0x11ea44b88>,
#  <Element 'clinical_study' at 0x11ea585e8>,
#  <Element 'clinical_study' at 0x11ea5df48>,
#  <Element 'clinical_study' at 0x11ea70408>,
#  <Element 'clinical_study' at 0x11ea799a8>,
#  <Element 'clinical_study' at 0x11ea86228>,
#  <Element 'clinical_study' at 0x11ea90958>,
#  <Element 'clinical_study' at 0x11eac67c8>,
#  <Element 'clinical_study' at 0x11ead0728>,
#  <Element 'clinical_study' at 0x11ead5e58>,
#  <Element 'clinical_study' at 0x11eae8ea8>,
#  <Element 'clinical_study' at 0x11eaefa48>,
#  <Element 'clinical_study' at 0x11eafcae8>,
#  <Element 'clinical_study' at 0x11eb08d68>,
#  <Element 'clinical_study' at 0x11eb1ccc8>,
#  <Element 'clinical_study' at 0x11eb26d18>,
#  <Element 'clinical_study' at 0x11eb42bd8>,
#  <Element 'clinical_study' at 0x11eb51958>,
#  <Element 'clinical_study' at 0x11eb62138>,
#  <Element 'clinical_study' at 0x11eb5d048>,
#  <Element 'clinical_study' at 0x11eb9fb38>,
#  <Element 'clinical_study' at 0x11ebafea8>,
#  <Element 'clinical_study' at 0x11ebde958>,
#  <Element 'clinical_study' at 0x11ebeabd8>,
#  <Element 'clinical_study' at 0x11ec7cd18>,
#  <Element 'clinical_study' at 0x11ec884a8>,
#  <Element 'clinical_study' at 0x11ec9a958>,
#  <Element 'clinical_study' at 0x11eca4548>,
#  <Element 'clinical_study' at 0x11ecbb0e8>,
#  <Element 'clinical_study' at 0x11ed2f688>,
#  <Element 'clinical_study' at 0x11ed39048>,
#  <Element 'clinical_study' at 0x11ed4a688>,
#  <Element 'clinical_study' at 0x11ed4cc78>,
#  <Element 'clinical_study' at 0x11ed60548>,
#  <Element 'clinical_study' at 0x11ed76778>,
#  <Element 'clinical_study' at 0x11ed824f8>,
#  <Element 'clinical_study' at 0x11eda3a98>,
#  <Element 'clinical_study' at 0x11edb01d8>,
#  <Element 'clinical_study' at 0x11edc8c78>,
#  <Element 'clinical_study' at 0x11edde598>,
#  <Element 'clinical_study' at 0x11edf5228>,
#  <Element 'clinical_study' at 0x11edf2048>,
#  <Element 'clinical_study' at 0x11ee06f98>,
#  <Element 'clinical_study' at 0x11ee18408>,
#  <Element 'clinical_study' at 0x11ee21598>,
#  <Element 'clinical_study' at 0x11ee30548>,
#  <Element 'clinical_study' at 0x11ee339a8>,
#  <Element 'clinical_study' at 0x11ee3f1d8>,
#  <Element 'clinical_study' at 0x11ee4a2c8>,
#  <Element 'clinical_study' at 0x11ee57598>,
#  <Element 'clinical_study' at 0x11ee62048>,
#  <Element 'clinical_study' at 0x11ee8f778>,
#  <Element 'clinical_study' at 0x11ee92db8>,
#  <Element 'clinical_study' at 0x11ee9bcc8>,
#  <Element 'clinical_study' at 0x11eeb9e58>,
#  <Element 'clinical_study' at 0x11eec74a8>,
#  <Element 'clinical_study' at 0x11eeced18>,
#  <Element 'clinical_study' at 0x11ef58778>,
#  <Element 'clinical_study' at 0x11ef60ae8>,
#  <Element 'clinical_study' at 0x11ef71278>,
#  <Element 'clinical_study' at 0x11ef812c8>,
#  <Element 'clinical_study' at 0x11efe9b88>,
#  <Element 'clinical_study' at 0x11eff29a8>,
#  <Element 'clinical_study' at 0x11effde08>,
#  <Element 'clinical_study' at 0x11f00e7c8>,
#  <Element 'clinical_study' at 0x11f0a1868>,
#  <Element 'clinical_study' at 0x11f0b3458>,
#  <Element 'clinical_study' at 0x11f0ee098>,
#  <Element 'clinical_study' at 0x11f112728>,
#  <Element 'clinical_study' at 0x11f11a188>,
#  <Element 'clinical_study' at 0x11f12d318>,
#  <Element 'clinical_study' at 0x11f14e728>,
#  <Element 'clinical_study' at 0x11f15d4f8>,
#  <Element 'clinical_study' at 0x11f16ba98>,
#  <Element 'clinical_study' at 0x11f1732c8>,
#  <Element 'clinical_study' at 0x11f1cf278>,
#  <Element 'clinical_study' at 0x11f1e01d8>,
#  <Element 'clinical_study' at 0x11f1e4868>,
#  <Element 'clinical_study' at 0x11f1f90e8>,
#  <Element 'clinical_study' at 0x11f205e08>,
#  <Element 'clinical_study' at 0x11f20fd18>,
#  <Element 'clinical_study' at 0x11f224188>,
#  <Element 'clinical_study' at 0x11f261bd8>,
#  <Element 'clinical_study' at 0x11f271368>,
#  <Element 'clinical_study' at 0x11f279048>,
#  <Element 'clinical_study' at 0x11f287368>,
#  <Element 'clinical_study' at 0x11f2abef8>,
#  <Element 'clinical_study' at 0x11f2b9b88>,
#  <Element 'clinical_study' at 0x11f2ca638>,
#  <Element 'clinical_study' at 0x11f2e87c8>,
#  <Element 'clinical_study' at 0x11f2fc548>,
#  <Element 'clinical_study' at 0x11f3064f8>,
#  <Element 'clinical_study' at 0x11f30a958>,
#  <Element 'clinical_study' at 0x11f312cc8>,
#  <Element 'clinical_study' at 0x11f31da48>,
#  <Element 'clinical_study' at 0x11f32b138>,
#  <Element 'clinical_study' at 0x11f336318>,
#  <Element 'clinical_study' at 0x11f340908>,
#  <Element 'clinical_study' at 0x11f359c78>,
#  <Element 'clinical_study' at 0x11f369db8>,
#  <Element 'clinical_study' at 0x11f37a638>,
#  <Element 'clinical_study' at 0x11f3825e8>,
#  <Element 'clinical_study' at 0x11f38cdb8>,
#  <Element 'clinical_study' at 0x11f3bf868>,
#  <Element 'clinical_study' at 0x11f3ce598>,
#  <Element 'clinical_study' at 0x11f3dfb88>,
#  <Element 'clinical_study' at 0x11f3ed4f8>,
#  <Element 'clinical_study' at 0x11f3f4db8>,
#  <Element 'clinical_study' at 0x11f407818>,
#  <Element 'clinical_study' at 0x11f416c78>,
#  <Element 'clinical_study' at 0x11f4240e8>,
#  <Element 'clinical_study' at 0x11f431cc8>,
#  <Element 'clinical_study' at 0x11f43e868>,
#  <Element 'clinical_study' at 0x11f452b38>,
#  <Element 'clinical_study' at 0x11f463368>,
#  <Element 'clinical_study' at 0x11f47c598>,
#  <Element 'clinical_study' at 0x11f486ef8>,
#  <Element 'clinical_study' at 0x11f49a228>,
#  <Element 'clinical_study' at 0x11f4b6138>,
#  <Element 'clinical_study' at 0x11f4bbe08>,
#  <Element 'clinical_study' at 0x11f4ce778>,
#  <Element 'clinical_study' at 0x11f4d9ea8>,
#  <Element 'clinical_study' at 0x11f4e0c78>,
#  <Element 'clinical_study' at 0x11f4ec7c8>,
#  <Element 'clinical_study' at 0x11f4f4cc8>,
#  <Element 'clinical_study' at 0x11f533318>,
#  <Element 'clinical_study' at 0x11f550368>,
#  <Element 'clinical_study' at 0x11f559a48>,
#  <Element 'clinical_study' at 0x11f562db8>,
#  <Element 'clinical_study' at 0x11f5741d8>,
#  <Element 'clinical_study' at 0x11f583598>,
#  <Element 'clinical_study' at 0x11f591408>,
#  <Element 'clinical_study' at 0x11f599e08>,
#  <Element 'clinical_study' at 0x11f5a94f8>,
#  <Element 'clinical_study' at 0x11f5b81d8>,
#  <Element 'clinical_study' at 0x11f5edcc8>,
#  <Element 'clinical_study' at 0x11f5f5f98>,
#  <Element 'clinical_study' at 0x11f616d18>,
#  <Element 'clinical_study' at 0x11f6363b8>,
#  <Element 'clinical_study' at 0x11f6d2548>,
#  <Element 'clinical_study' at 0x11f6d9958>,
#  <Element 'clinical_study' at 0x11f6f2688>,
#  <Element 'clinical_study' at 0x11f6fc3b8>,
#  <Element 'clinical_study' at 0x11f706228>,
#  <Element 'clinical_study' at 0x11f71c9f8>,
#  <Element 'clinical_study' at 0x11f74e598>,
#  <Element 'clinical_study' at 0x11f7d5818>,
#  <Element 'clinical_study' at 0x11f7e12c8>,
#  <Element 'clinical_study' at 0x11f7e6d68>,
#  <Element 'clinical_study' at 0x11f7f13b8>,
#  <Element 'clinical_study' at 0x11f815bd8>,
#  <Element 'clinical_study' at 0x11f8224a8>,
#  <Element 'clinical_study' at 0x11f82e138>,
#  <Element 'clinical_study' at 0x11f85ee08>,
#  <Element 'clinical_study' at 0x11f869d18>,
#  <Element 'clinical_study' at 0x11f875908>,
#  <Element 'clinical_study' at 0x11f8d5278>,
#  <Element 'clinical_study' at 0x11fa0c138>,
#  <Element 'clinical_study' at 0x11fa0ebd8>,
#  <Element 'clinical_study' at 0x11fa493b8>,
#  <Element 'clinical_study' at 0x11fa4fef8>,
#  <Element 'clinical_study' at 0x11fa64548>,
#  <Element 'clinical_study' at 0x11fa734f8>,
#  <Element 'clinical_study' at 0x11fa9ff48>,
#  <Element 'clinical_study' at 0x11faaca48>,
#  <Element 'clinical_study' at 0x11fab9f48>,
#  <Element 'clinical_study' at 0x11facb098>,
#  <Element 'clinical_study' at 0x11fad55e8>,
#  <Element 'clinical_study' at 0x11fae35e8>,
#  <Element 'clinical_study' at 0x11faebe58>,
#  <Element 'clinical_study' at 0x11fafc868>,
#  <Element 'clinical_study' at 0x11fb0b138>,
#  <Element 'clinical_study' at 0x11fb174a8>,
#  <Element 'clinical_study' at 0x11fb1cae8>,
#  <Element 'clinical_study' at 0x11fb2e868>,
#  <Element 'clinical_study' at 0x11fb45638>,
#  <Element 'clinical_study' at 0x11fb58ef8>,
#  <Element 'clinical_study' at 0x11fb67318>,
#  <Element 'clinical_study' at 0x11fb84bd8>,
#  <Element 'clinical_study' at 0x11fb93368>,
#  <Element 'clinical_study' at 0x11fb9d2c8>,
#  <Element 'clinical_study' at 0x11fbac2c8>,
#  <Element 'clinical_study' at 0x11fc19a48>,
#  <Element 'clinical_study' at 0x11fc25188>,
#  <Element 'clinical_study' at 0x11fc38ea8>,
#  <Element 'clinical_study' at 0x11fc435e8>,
#  <Element 'clinical_study' at 0x11fc52f98>,
#  <Element 'clinical_study' at 0x11fc86a98>,
#  <Element 'clinical_study' at 0x11fc90cc8>,
#  <Element 'clinical_study' at 0x11fca3638>,
#  <Element 'clinical_study' at 0x11fcb1228>,
#  <Element 'clinical_study' at 0x11fd03318>,
#  <Element 'clinical_study' at 0x11fd0def8>,
#  <Element 'clinical_study' at 0x11fd1f098>,
#  <Element 'clinical_study' at 0x11fd2b1d8>,
#  <Element 'clinical_study' at 0x11fd35408>,
#  <Element 'clinical_study' at 0x11fd3f4f8>,
#  <Element 'clinical_study' at 0x11fd48e08>,
#  <Element 'clinical_study' at 0x11fd5dd68>,
#  <Element 'clinical_study' at 0x11fd6dd68>,
#  <Element 'clinical_study' at 0x11fd807c8>,
#  <Element 'clinical_study' at 0x11fd8d868>,
#  <Element 'clinical_study' at 0x11fe01e08>,
#  <Element 'clinical_study' at 0x11fe0d8b8>,
#  <Element 'clinical_study' at 0x11fe1ba98>,
#  <Element 'clinical_study' at 0x11fe23b88>,
#  <Element 'clinical_study' at 0x11fe346d8>,
#  <Element 'clinical_study' at 0x11fe48598>,
#  <Element 'clinical_study' at 0x11fe5bb38>,
#  <Element 'clinical_study' at 0x11fe649f8>,
#  <Element 'clinical_study' at 0x11fe75278>,
#  <Element 'clinical_study' at 0x11fe84138>,
#  <Element 'clinical_study' at 0x11fe96188>,
#  <Element 'clinical_study' at 0x11fea0ae8>,
#  <Element 'clinical_study' at 0x11feaaf98>,
#  <Element 'clinical_study' at 0x11feb4818>,
#  <Element 'clinical_study' at 0x11febf5e8>,
#  <Element 'clinical_study' at 0x11feccea8>,
#  <Element 'clinical_study' at 0x11fedb048>,
#  <Element 'clinical_study' at 0x11ff299f8>,
#  <Element 'clinical_study' at 0x11ff5ad18>,
#  <Element 'clinical_study' at 0x11ff694a8>,
#  <Element 'clinical_study' at 0x11ff70ea8>,
#  <Element 'clinical_study' at 0x11ff7be08>,
#  <Element 'clinical_study' at 0x11ff922c8>,
#  <Element 'clinical_study' at 0x11ff9cc78>,
#  <Element 'clinical_study' at 0x11ffacc78>,
#  <Element 'clinical_study' at 0x11ffb2db8>,
#  <Element 'clinical_study' at 0x11ffc2ef8>,
#  <Element 'clinical_study' at 0x11ffcf048>,
#  <Element 'clinical_study' at 0x11ffe2818>,
#  <Element 'clinical_study' at 0x120001548>,
#  <Element 'clinical_study' at 0x12000da98>,
#  <Element 'clinical_study' at 0x12001db38>,
#  <Element 'clinical_study' at 0x12002fae8>,
#  <Element 'clinical_study' at 0x120036ef8>,
#  <Element 'clinical_study' at 0x120064f98>,
#  <Element 'clinical_study' at 0x12008c9a8>,
#  <Element 'clinical_study' at 0x12009d778>,
#  <Element 'clinical_study' at 0x1200e8548>,
#  <Element 'clinical_study' at 0x1200f7db8>,
#  <Element 'clinical_study' at 0x1201007c8>,
#  <Element 'clinical_study' at 0x12010ba98>,
#  <Element 'clinical_study' at 0x120124868>,
#  <Element 'clinical_study' at 0x12012f728>,
#  <Element 'clinical_study' at 0x120141048>,
#  <Element 'clinical_study' at 0x1201587c8>,
#  <Element 'clinical_study' at 0x120160548>,
#  <Element 'clinical_study' at 0x12016cea8>,
#  <Element 'clinical_study' at 0x12017c318>,
#  <Element 'clinical_study' at 0x120185868>,
#  <Element 'clinical_study' at 0x12018e6d8>,
#  <Element 'clinical_study' at 0x1201993b8>,
#  <Element 'clinical_study' at 0x1201a4548>,
#  <Element 'clinical_study' at 0x1201b82c8>,
#  <Element 'clinical_study' at 0x1201f3868>,
#  <Element 'clinical_study' at 0x120227228>,
#  <Element 'clinical_study' at 0x1202d9688>,
#  <Element 'clinical_study' at 0x1202eb7c8>,
#  <Element 'clinical_study' at 0x1202fb868>,
#  <Element 'clinical_study' at 0x12030d8b8>,
#  <Element 'clinical_study' at 0x1203168b8>,
#  <Element 'clinical_study' at 0x12036c818>,
#  <Element 'clinical_study' at 0x120378f98>,
#  <Element 'clinical_study' at 0x120386728>,
#  <Element 'clinical_study' at 0x120399e08>,
#  <Element 'clinical_study' at 0x1203aed18>,
#  <Element 'clinical_study' at 0x1203b6c78>,
#  <Element 'clinical_study' at 0x1203ca548>,
#  <Element 'clinical_study' at 0x1203d3c28>,
#  <Element 'clinical_study' at 0x1203df778>,
#  <Element 'clinical_study' at 0x1203e9728>,
#  <Element 'clinical_study' at 0x1203f5818>,
#  <Element 'clinical_study' at 0x120403368>,
#  <Element 'clinical_study' at 0x12042bf98>,
#  <Element 'clinical_study' at 0x120433e08>,
#  <Element 'clinical_study' at 0x120442548>,
#  <Element 'clinical_study' at 0x1204a8228>,
#  <Element 'clinical_study' at 0x1204ac048>,
#  <Element 'clinical_study' at 0x1204b7e08>,
#  <Element 'clinical_study' at 0x1204c3f48>,
#  <Element 'clinical_study' at 0x1204d56d8>,
#  <Element 'clinical_study' at 0x1204dee08>,
#  <Element 'clinical_study' at 0x1204ed1d8>,
#  <Element 'clinical_study' at 0x1204f8a48>,
#  <Element 'clinical_study' at 0x12050a188>,
#  <Element 'clinical_study' at 0x1205122c8>,
#  <Element 'clinical_study' at 0x120542958>,
#  <Element 'clinical_study' at 0x12054a7c8>,
#  <Element 'clinical_study' at 0x1206358b8>,
#  <Element 'clinical_study' at 0x1206444f8>,
#  <Element 'clinical_study' at 0x120651f48>,
#  <Element 'clinical_study' at 0x1206614f8>,
#  <Element 'clinical_study' at 0x120669ea8>,
#  <Element 'clinical_study' at 0x1206c7cc8>,
#  <Element 'clinical_study' at 0x1206d29a8>,
#  <Element 'clinical_study' at 0x120725368>,
#  <Element 'clinical_study' at 0x120731d68>,
#  <Element 'clinical_study' at 0x120740868>,
#  <Element 'clinical_study' at 0x1207498b8>,
#  <Element 'clinical_study' at 0x120759228>,
#  <Element 'clinical_study' at 0x120762408>,
#  <Element 'clinical_study' at 0x1207722c8>,
#  <Element 'clinical_study' at 0x12077ab38>,
#  <Element 'clinical_study' at 0x12078f278>,
#  <Element 'clinical_study' at 0x1207a0ae8>,
#  <Element 'clinical_study' at 0x1207aeef8>,
#  <Element 'clinical_study' at 0x1207cbae8>,
#  <Element 'clinical_study' at 0x1207d6408>,
#  <Element 'clinical_study' at 0x1207e0408>,
#  <Element 'clinical_study' at 0x1207ee958>,
#  <Element 'clinical_study' at 0x1207f69f8>,
#  <Element 'clinical_study' at 0x120810bd8>,
#  <Element 'clinical_study' at 0x1208a3ea8>,
#  <Element 'clinical_study' at 0x1208c1d18>,
#  <Element 'clinical_study' at 0x1208e5bd8>,
#  <Element 'clinical_study' at 0x1208f0688>,
#  <Element 'clinical_study' at 0x1208fce08>,
#  <Element 'clinical_study' at 0x120907548>,
#  <Element 'clinical_study' at 0x120914d18>,
#  <Element 'clinical_study' at 0x120925d18>,
#  <Element 'clinical_study' at 0x12093a318>,
#  <Element 'clinical_study' at 0x1209497c8>,
#  <Element 'clinical_study' at 0x120955868>,
#  <Element 'clinical_study' at 0x12096c138>,
#  <Element 'clinical_study' at 0x12097a778>,
#  <Element 'clinical_study' at 0x1209849f8>,
#  <Element 'clinical_study' at 0x120992188>,
#  <Element 'clinical_study' at 0x1209a1ea8>,
#  <Element 'clinical_study' at 0x1209aaa48>,
#  <Element 'clinical_study' at 0x120a2a9a8>,
#  <Element 'clinical_study' at 0x120a3d408>,
#  <Element 'clinical_study' at 0x120a478b8>,
#  <Element 'clinical_study' at 0x120a579f8>,
#  <Element 'clinical_study' at 0x120a65b88>,
#  <Element 'clinical_study' at 0x120a73548>,
#  <Element 'clinical_study' at 0x120a83a48>,
#  <Element 'clinical_study' at 0x120a92958>,
#  <Element 'clinical_study' at 0x120a96cc8>,
#  <Element 'clinical_study' at 0x120aa1c78>,
#  <Element 'clinical_study' at 0x120ab8b88>,
#  <Element 'clinical_study' at 0x120b37408>,
#  <Element 'clinical_study' at 0x120b48638>,
#  <Element 'clinical_study' at 0x120b4cf98>,
#  <Element 'clinical_study' at 0x120b5a368>,
#  <Element 'clinical_study' at 0x120b6c2c8>,
#  <Element 'clinical_study' at 0x120b74ef8>,
#  <Element 'clinical_study' at 0x120b8dbd8>,
#  <Element 'clinical_study' at 0x120b97868>,
#  <Element 'clinical_study' at 0x120b9bf98>,
#  <Element 'clinical_study' at 0x120baf318>,
#  <Element 'clinical_study' at 0x120bbc188>,
#  <Element 'clinical_study' at 0x120bc73b8>,
#  <Element 'clinical_study' at 0x120bd84f8>,
#  <Element 'clinical_study' at 0x120be1688>,
#  <Element 'clinical_study' at 0x120bf2458>,
#  <Element 'clinical_study' at 0x120bfaa48>,
#  <Element 'clinical_study' at 0x120c01cc8>,
#  <Element 'clinical_study' at 0x120c194a8>,
#  <Element 'clinical_study' at 0x120c2d548>,
#  <Element 'clinical_study' at 0x120c38a98>,
#  <Element 'clinical_study' at 0x120c46a98>,
#  <Element 'clinical_study' at 0x120c54cc8>,
#  <Element 'clinical_study' at 0x120c963b8>,
#  <Element 'clinical_study' at 0x120ca24f8>,
#  <Element 'clinical_study' at 0x120caee08>,
#  <Element 'clinical_study' at 0x120cc1f48>,
#  <Element 'clinical_study' at 0x120ccf7c8>,
#  <Element 'clinical_study' at 0x120cdd458>,
#  <Element 'clinical_study' at 0x120ce8b38>,
#  <Element 'clinical_study' at 0x120cf7818>,
#  <Element 'clinical_study' at 0x120d03688>,
#  <Element 'clinical_study' at 0x120daa638>,
#  <Element 'clinical_study' at 0x120db5e08>,
#  <Element 'clinical_study' at 0x120dc60e8>,
#  <Element 'clinical_study' at 0x120dd51d8>,
#  <Element 'clinical_study' at 0x120dd9cc8>,
#  <Element 'clinical_study' at 0x120ded598>,
#  <Element 'clinical_study' at 0x120e129f8>,
#  <Element 'clinical_study' at 0x120e1bc28>,
#  <Element 'clinical_study' at 0x120e321d8>,
#  <Element 'clinical_study' at 0x120e4bdb8>,
#  <Element 'clinical_study' at 0x120e59b88>,
#  <Element 'clinical_study' at 0x120ef6c78>,
#  <Element 'clinical_study' at 0x120f02db8>,
#  <Element 'clinical_study' at 0x120f2f188>,
#  <Element 'clinical_study' at 0x120f463b8>,
#  <Element 'clinical_study' at 0x120f6da98>,
#  <Element 'clinical_study' at 0x120f77ea8>,
#  <Element 'clinical_study' at 0x120f94098>,
#  <Element 'clinical_study' at 0x120f9da48>,
#  <Element 'clinical_study' at 0x120fa4e58>,
#  <Element 'clinical_study' at 0x120fbe2c8>,
#  <Element 'clinical_study' at 0x120fc7278>,
#  <Element 'clinical_study' at 0x120fd8f48>,
#  <Element 'clinical_study' at 0x120fe4d18>,
#  <Element 'clinical_study' at 0x121055638>,
#  <Element 'clinical_study' at 0x1210659a8>,
#  <Element 'clinical_study' at 0x1210754f8>,
#  <Element 'clinical_study' at 0x121081e08>,
#  <Element 'clinical_study' at 0x12113d5e8>,
#  <Element 'clinical_study' at 0x12114a368>,
#  <Element 'clinical_study' at 0x12115f9a8>,
#  <Element 'clinical_study' at 0x121167d68>,
#  <Element 'clinical_study' at 0x12117fdb8>,
#  <Element 'clinical_study' at 0x121246b38>,
#  <Element 'clinical_study' at 0x121254818>,
#  <Element 'clinical_study' at 0x12125c728>,
#  <Element 'clinical_study' at 0x121266f98>,
#  <Element 'clinical_study' at 0x121274688>,
#  <Element 'clinical_study' at 0x12127ed68>,
#  <Element 'clinical_study' at 0x12129a098>,
#  <Element 'clinical_study' at 0x1212ac318>,
#  <Element 'clinical_study' at 0x121393e58>,
#  <Element 'clinical_study' at 0x1213a5548>,
#  <Element 'clinical_study' at 0x1213ae3b8>,
#  <Element 'clinical_study' at 0x1213b8548>,
#  <Element 'clinical_study' at 0x1213cc1d8>,
#  <Element 'clinical_study' at 0x1213d4a48>,
#  <Element 'clinical_study' at 0x1213e2598>,
#  <Element 'clinical_study' at 0x1213ed6d8>,
#  <Element 'clinical_study' at 0x1213f9f98>,
#  <Element 'clinical_study' at 0x121409bd8>,
#  <Element 'clinical_study' at 0x12141a228>,
#  <Element 'clinical_study' at 0x121422138>,
#  <Element 'clinical_study' at 0x1214dd5e8>,
#  <Element 'clinical_study' at 0x1214e4458>,
#  <Element 'clinical_study' at 0x1214f0818>,
#  <Element 'clinical_study' at 0x1214f9db8>,
#  <Element 'clinical_study' at 0x121507bd8>,
#  <Element 'clinical_study' at 0x121560278>,
#  <Element 'clinical_study' at 0x121565048>,
#  <Element 'clinical_study' at 0x121574b88>,
#  <Element 'clinical_study' at 0x1216318b8>,
#  <Element 'clinical_study' at 0x121641d18>,
#  <Element 'clinical_study' at 0x121648cc8>,
#  <Element 'clinical_study' at 0x1216e2368>,
#  <Element 'clinical_study' at 0x1216ed368>,
#  <Element 'clinical_study' at 0x1216fa138>,
#  <Element 'clinical_study' at 0x1217079a8>,
#  <Element 'clinical_study' at 0x1217109a8>,
#  <Element 'clinical_study' at 0x12171af98>,
#  <Element 'clinical_study' at 0x12172d9f8>,
#  <Element 'clinical_study' at 0x121743778>,
#  <Element 'clinical_study' at 0x121752598>,
#  <Element 'clinical_study' at 0x121777958>,
#  <Element 'clinical_study' at 0x12178b138>,
#  <Element 'clinical_study' at 0x121794c78>,
#  <Element 'clinical_study' at 0x12179e228>,
#  <Element 'clinical_study' at 0x12182c778>,
#  <Element 'clinical_study' at 0x12183f458>,
#  <Element 'clinical_study' at 0x121848048>,
#  <Element 'clinical_study' at 0x1218567c8>,
#  <Element 'clinical_study' at 0x12186de08>,
#  <Element 'clinical_study' at 0x121879e58>,
#  <Element 'clinical_study' at 0x1218a9728>,
#  <Element 'clinical_study' at 0x1218b3c78>,
#  <Element 'clinical_study' at 0x1218bacc8>,
#  <Element 'clinical_study' at 0x1218d23b8>,
#  <Element 'clinical_study' at 0x1218e4458>,
#  <Element 'clinical_study' at 0x121a9b098>,
#  <Element 'clinical_study' at 0x121a9eae8>,
#  <Element 'clinical_study' at 0x121aa89f8>,
#  <Element 'clinical_study' at 0x121ab95e8>,
#  <Element 'clinical_study' at 0x121ac3318>,
#  <Element 'clinical_study' at 0x121b15818>,
#  <Element 'clinical_study' at 0x121b2a7c8>,
#  <Element 'clinical_study' at 0x121b35368>,
#  <Element 'clinical_study' at 0x121b70728>,
#  <Element 'clinical_study' at 0x121c09ef8>,
#  <Element 'clinical_study' at 0x121c1a5e8>,
#  <Element 'clinical_study' at 0x121c24548>,
#  <Element 'clinical_study' at 0x121c3b4f8>,
#  <Element 'clinical_study' at 0x121c454a8>,
#  <Element 'clinical_study' at 0x121c4f4f8>,
#  <Element 'clinical_study' at 0x121c5a778>,
#  <Element 'clinical_study' at 0x121c6b4a8>,
#  <Element 'clinical_study' at 0x121c7aa98>,
#  <Element 'clinical_study' at 0x1220f6e08>,
#  <Element 'clinical_study' at 0x122109958>,
#  <Element 'clinical_study' at 0x122122188>,
#  <Element 'clinical_study' at 0x122178f98>,
#  <Element 'clinical_study' at 0x122186408>,
#  <Element 'clinical_study' at 0x1221923b8>,
#  <Element 'clinical_study' at 0x1221a4a48>,
#  <Element 'clinical_study' at 0x1221ad228>,
#  <Element 'clinical_study' at 0x1221cda98>,
#  <Element 'clinical_study' at 0x1221da458>,
#  <Element 'clinical_study' at 0x1221e3318>,
#  <Element 'clinical_study' at 0x1221e9b38>,
#  <Element 'clinical_study' at 0x1221f7638>,
#  <Element 'clinical_study' at 0x122203598>,
#  <Element 'clinical_study' at 0x12220c8b8>,
#  <Element 'clinical_study' at 0x122218688>,
#  <Element 'clinical_study' at 0x122231188>,
#  <Element 'clinical_study' at 0x12242ccc8>,
#  <Element 'clinical_study' at 0x122447908>,
#  <Element 'clinical_study' at 0x122454ae8>,
#  <Element 'clinical_study' at 0x122465e58>,
#  <Element 'clinical_study' at 0x122471c28>,
#  <Element 'clinical_study' at 0x12248ed68>,
#  <Element 'clinical_study' at 0x12249b7c8>,
#  <Element 'clinical_study' at 0x1224ab7c8>,
#  <Element 'clinical_study' at 0x1224bb9f8>,
#  <Element 'clinical_study' at 0x1224c5c78>,
#  <Element 'clinical_study' at 0x1224d26d8>,
#  <Element 'clinical_study' at 0x12250d9f8>,
#  <Element 'clinical_study' at 0x1225181d8>,
#  <Element 'clinical_study' at 0x122523ae8>,
#  <Element 'clinical_study' at 0x122547638>,
#  <Element 'clinical_study' at 0x12254ab88>,
#  <Element 'clinical_study' at 0x12255f408>,
#  <Element 'clinical_study' at 0x12256a228>,
#  <Element 'clinical_study' at 0x122578c78>,
#  <Element 'clinical_study' at 0x122581d18>,
#  <Element 'clinical_study' at 0x1225d8598>,
#  <Element 'clinical_study' at 0x1225e27c8>,
#  <Element 'clinical_study' at 0x1225fb2c8>,
#  <Element 'clinical_study' at 0x122608098>,
#  <Element 'clinical_study' at 0x122611f98>,
#  <Element 'clinical_study' at 0x12263d1d8>,
#  <Element 'clinical_study' at 0x122645048>,
#  <Element 'clinical_study' at 0x122659278>,
#  <Element 'clinical_study' at 0x12265bbd8>,
#  <Element 'clinical_study' at 0x12266b0e8>,
#  <Element 'clinical_study' at 0x12267c228>,
#  <Element 'clinical_study' at 0x122685548>,
#  <Element 'clinical_study' at 0x12268da98>,
#  <Element 'clinical_study' at 0x1226c26d8>,
#  <Element 'clinical_study' at 0x1226ca1d8>,
#  <Element 'clinical_study' at 0x1226cdf98>,
#  <Element 'clinical_study' at 0x1226dc5e8>,
#  <Element 'clinical_study' at 0x1226ea188>,
#  <Element 'clinical_study' at 0x1226f3e08>,
#  <Element 'clinical_study' at 0x122705188>,
#  <Element 'clinical_study' at 0x122710a48>,
#  <Element 'clinical_study' at 0x1227196d8>,
#  <Element 'clinical_study' at 0x122734b88>,
#  <Element 'clinical_study' at 0x12273e728>,
#  <Element 'clinical_study' at 0x12274e0e8>,
#  <Element 'clinical_study' at 0x122763a98>,
#  <Element 'clinical_study' at 0x12276af98>,
#  <Element 'clinical_study' at 0x12277e278>,
#  <Element 'clinical_study' at 0x122784f98>,
#  <Element 'clinical_study' at 0x1227931d8>,
#  <Element 'clinical_study' at 0x1227a10e8>,
#  <Element 'clinical_study' at 0x1227f7ea8>,
#  <Element 'clinical_study' at 0x12280c598>,
#  <Element 'clinical_study' at 0x122817c28>,
#  <Element 'clinical_study' at 0x12282a5e8>,
#  <Element 'clinical_study' at 0x122833598>,
#  <Element 'clinical_study' at 0x122843bd8>,
#  <Element 'clinical_study' at 0x12284ce58>,
#  <Element 'clinical_study' at 0x122859778>,
#  <Element 'clinical_study' at 0x122863a98>,
#  <Element 'clinical_study' at 0x12286e138>,
#  <Element 'clinical_study' at 0x122877c28>,
#  <Element 'clinical_study' at 0x122992ae8>,
#  <Element 'clinical_study' at 0x1229a78b8>,
#  <Element 'clinical_study' at 0x1229d4c78>,
#  <Element 'clinical_study' at 0x1229e49f8>,
#  <Element 'clinical_study' at 0x122a12868>,
#  <Element 'clinical_study' at 0x122b1c368>,
#  <Element 'clinical_study' at 0x122b25d68>,
#  <Element 'clinical_study' at 0x122b35408>,
#  <Element 'clinical_study' at 0x122b3e368>,
#  <Element 'clinical_study' at 0x122b4e1d8>,
#  <Element 'clinical_study' at 0x122b5a2c8>,
#  <Element 'clinical_study' at 0x122b68d68>,
#  <Element 'clinical_study' at 0x122b75048>,
#  <Element 'clinical_study' at 0x122b7cc78>,
#  <Element 'clinical_study' at 0x122b87408>,
#  <Element 'clinical_study' at 0x122b96598>,
#  <Element 'clinical_study' at 0x122ba79f8>,
#  <Element 'clinical_study' at 0x122babc28>,
#  <Element 'clinical_study' at 0x122bbc9f8>,
#  <Element 'clinical_study' at 0x122bc5868>,
#  <Element 'clinical_study' at 0x122bd73b8>,
#  <Element 'clinical_study' at 0x122bedbd8>,
#  <Element 'clinical_study' at 0x122c02bd8>,
#  <Element 'clinical_study' at 0x122c13f98>,
#  <Element 'clinical_study' at 0x122d36368>,
#  <Element 'clinical_study' at 0x122d44548>,
#  <Element 'clinical_study' at 0x122d4d908>,
#  <Element 'clinical_study' at 0x122d63a48>,
#  <Element 'clinical_study' at 0x122d6f278>,
#  <Element 'clinical_study' at 0x122d84098>,
#  <Element 'clinical_study' at 0x122d8ea98>,
#  <Element 'clinical_study' at 0x122d97048>,
#  <Element 'clinical_study' at 0x122daed18>,
#  <Element 'clinical_study' at 0x122dd97c8>,
#  <Element 'clinical_study' at 0x122df0778>,
#  <Element 'clinical_study' at 0x122e00138>,
#  <Element 'clinical_study' at 0x122e018b8>,
#  <Element 'clinical_study' at 0x122e474f8>,
#  <Element 'clinical_study' at 0x122e53958>,
#  <Element 'clinical_study' at 0x122e8a598>,
#  <Element 'clinical_study' at 0x122e9b9f8>,
#  <Element 'clinical_study' at 0x122ea1cc8>,
#  <Element 'clinical_study' at 0x122ef0138>,
#  <Element 'clinical_study' at 0x122f14d68>,
#  <Element 'clinical_study' at 0x122f1dc78>,
#  <Element 'clinical_study' at 0x122f26f98>,
#  <Element 'clinical_study' at 0x122f409f8>,
#  <Element 'clinical_study' at 0x122f508b8>,
#  <Element 'clinical_study' at 0x122f769f8>,
#  <Element 'clinical_study' at 0x122f914f8>,
#  <Element 'clinical_study' at 0x122f999a8>,
#  <Element 'clinical_study' at 0x122fa7908>,
#  <Element 'clinical_study' at 0x122fdd228>,
#  <Element 'clinical_study' at 0x122fe6598>,
#  <Element 'clinical_study' at 0x122ff72c8>,
#  <Element 'clinical_study' at 0x123006958>,
#  <Element 'clinical_study' at 0x123013598>,
#  <Element 'clinical_study' at 0x1230225e8>,
#  <Element 'clinical_study' at 0x12302ca48>,
#  <Element 'clinical_study' at 0x12303e688>,
#  <Element 'clinical_study' at 0x1230504f8>,
#  <Element 'clinical_study' at 0x12305ad68>,
#  <Element 'clinical_study' at 0x123067318>,
#  <Element 'clinical_study' at 0x12306ccc8>,
#  <Element 'clinical_study' at 0x12307e458>,
#  <Element 'clinical_study' at 0x12308b278>,
#  <Element 'clinical_study' at 0x123096db8>,
#  <Element 'clinical_study' at 0x1230bb7c8>,
#  <Element 'clinical_study' at 0x1230cc138>,
#  <Element 'clinical_study' at 0x1230ea318>,
#  <Element 'clinical_study' at 0x1230fe6d8>,
#  <Element 'clinical_study' at 0x123110908>,
#  <Element 'clinical_study' at 0x12311ed68>,
#  <Element 'clinical_study' at 0x1231575e8>,
#  <Element 'clinical_study' at 0x123163ae8>,
#  <Element 'clinical_study' at 0x12316dd18>,
#  <Element 'clinical_study' at 0x123178ef8>,
#  <Element 'clinical_study' at 0x1231804a8>,
#  <Element 'clinical_study' at 0x12318c9f8>,
#  <Element 'clinical_study' at 0x12319a098>,
#  <Element 'clinical_study' at 0x1231b2cc8>,
#  <Element 'clinical_study' at 0x1231c48b8>,
#  <Element 'clinical_study' at 0x1231d0908>,
#  <Element 'clinical_study' at 0x1231dbcc8>,
#  <Element 'clinical_study' at 0x123233318>,
#  <Element 'clinical_study' at 0x123240e58>,
#  <Element 'clinical_study' at 0x1232ba7c8>,
#  <Element 'clinical_study' at 0x1232e27c8>,
#  <Element 'clinical_study' at 0x1232ed7c8>,
#  <Element 'clinical_study' at 0x1232fed18>,
#  <Element 'clinical_study' at 0x123306a98>,
#  <Element 'clinical_study' at 0x1233469f8>,
#  <Element 'clinical_study' at 0x123385bd8>,
#  <Element 'clinical_study' at 0x12339cf48>,
#  <Element 'clinical_study' at 0x1233b99f8>,
#  <Element 'clinical_study' at 0x1233c6cc8>,
#  <Element 'clinical_study' at 0x123462cc8>,
#  <Element 'clinical_study' at 0x12346dcc8>,
#  <Element 'clinical_study' at 0x12347e188>,
#  <Element 'clinical_study' at 0x123488278>,
#  <Element 'clinical_study' at 0x1234b1368>,
#  <Element 'clinical_study' at 0x1234bb0e8>,
#  <Element 'clinical_study' at 0x1234df458>,
#  <Element 'clinical_study' at 0x1234eb188>,
#  ...]

# %%
print(len(all_parsed_files))

# %% [markdown]
# ## Extract tags from parsed trials

# %%
# Dictionary to hold all data
all_data_dictionary = {}

# Final json file
json_file = '/all_trials_json' #name json file  

print('\nCreated dictionary and path to json file\n')

# %% [markdown]
# ### Parse tags in files

# %%
'''
Find values by unique tags in XML files 
Save them in a dictionary 
Export them to a json file
'''

def create_dictionary_from_tag(tag, parsed_files = all_parsed_files, name_dictionary = all_data_dictionary):
    
    # Variable to store values
    keys = []
    values = []
    
    # Iterate through all xml parsed files and tags, and append data to values
    for n in parsed_files:
        for i in n.iter(tag):
            if i.text != 0:
                values.append(i.text)
            else:
                values.append('nan') #get values
                # Checking message to the terminal
            print("{} file parsed\n".format(i.text))
    
    # Create dictionary and set tags as keys
    name_dictionary.setdefault(tag, [])
    
    # Append values to dictionary
    for i in values:
        name_dictionary[tag].append(i)
        print("{} file added to the dictionary\n".format(i))
        
        
# Execute function only with unique values
# %time create_dictionary_from_tag('nct_id')
# %time create_dictionary_from_tag('study_first_submitted')
# %time create_dictionary_from_tag('source')
# %time create_dictionary_from_tag('brief_title')

print('Dictionary created')

# %%
'''
Check number of values for each key before creating a dataframe
'''

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))

# %%
# Function for adding new tag

def add_new_tags(new_key):
    all_data_dictionary.setdefault(new_key, [])

    for n in all_parsed_files:
            value_conditions = n.find(new_key)
            if n.find(new_key) is not None:
                all_data_dictionary[new_key].append(value_conditions.text)
            else:
                all_data_dictionary[new_key].append('None')

    print('{} tag added'.format(new_key))

# %%
add_new_tags('condition')
add_new_tags('detailed_description/textblock')
add_new_tags('brief_summary/textblock')

# %%
'''
Check keys and number of values for each one
'''

print(all_data_dictionary.keys())

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))

# %% [markdown]
# ## Dump results in a json file

# %%
# Dump dictionary into a JSON file
with open('{}{}.json'.format(path_to_json_file, json_file), 'w') as fp:
    json.dump(all_data_dictionary, fp)
    print('\nJSON file created\n')

    json_size = round(os.path.getsize(path_to_json_file + json_file + '.json') / 1000000, 2)
    print("JSON file: {} Mb".format(json_size))

# %% [markdown]
# ## Import json file in a dataframe

# %%
# Import json into a dataframe
file = '{}{}.json'.format(path_to_json_file, json_file)

df = pd.read_json(file)

# %%
df.head()
# Out:
#         nct_id study_first_submitted                          source  \
# 0  NCT02776787           May 5, 2016        University of Washington
# 1  NCT00797472     November 24, 2008  American Scitech International
# 2  NCT03499821         April 9, 2018          Staar Surgical Company
# 3  NCT01224028      October 18, 2010             Astellas Pharma Inc
# 4  NCT02279680         June 23, 2014       University Hospital, Caen
#
#                                          brief_title          condition  \
# 0  DEBUT: Diverticulitis Evaluation of Patient Bu...     Diverticulitis
# 1  Study Comparing R-mabHD and a Combination of A...  Hodgkin's Disease
# 2  Clinical Performance of a Phakic Intraocular L...         Presbyopia
# 3  A Study to Evaluate the Efficacy and Safety of...    IgA Nephropathy
# 4  Associative Memory in Adults With an Autism Sp...  Autistic Disorder
#
#                       detailed_description/textblock  \
# 0  \n      This study will examine both clinical ...
# 1  \n      The primary objective is to compare th...
# 2  \n      This is a prospective, open-labeled, m...
# 3                                               None
# 4                                               None
#
#                              brief_summary/textblock
# 0  \n      Half of all Americans over 60 years of...
# 1  \n      120 subjects with Hodgkin's disease wi...
# 2  \n      This study will evaluate the clinical ...
# 3  \n      This study is to evaluate efficacy and...
# 4  \n      The objective of this multidisciplinar...

# %%
# rename columns & delete \n values

# %%
df['detailed_description/textblock'][0]
# Out:
# "\n      This study will examine both clinical and non-clinical reasons for pursuing surgery, taking\n      into account previously unexplored areas in surgical decision-making including the\n      comprehensive impact of this disease, as well as factors that impact a surgeon's willingness\n      to recommend surgery. Ultimately, this patient-centered research approach will help us\n      understand the impact of treatment decisions on a patient's quality of life, work, and\n      clinical symptoms, and will ultimately help to inform our recommendations for the treatment\n      of patients with diverticulitis.\n\n      The DEBUT study was developed from questions raised by our Washington State Surgical\n      Collaborative, (SCOAP Colon and Rectal Surgery Work Group) and will be carried out in clinics\n      and hospitals across Washington State, Oregon, and California. The investigators invite\n      patients to participate in research activities designed to identify the impact of\n      diverticulitis and treatment options, in order to better understand the outcomes that matter\n      most to patients. Patients who are considering surgery or who have received treatment for\n      their diverticulitis will be recruited for study participation. Participants will complete a\n      baseline survey via a convenient electronic platform, and follow-up surveys will be sent\n      quarterly for up to four years. These surveys will examine quality of life, overall health,\n      and clinical symptoms to understand what drives patients and surgeons to an operation, as\n      well as how that decision impacts quality of life and recurrent events in patients that\n      choose to have surgery compared to those that do not have surgery. Participating surgeons\n      will complete surveys that examine their indications for surgery and surgical outcomes.\n    "

# %%
# Create a new column: study_first_submitted as dates

df['dates'] = pd.to_datetime(df['study_first_submitted'])

# %%
df.head()
# Out:
#         nct_id study_first_submitted                          source  \
# 0  NCT02776787           May 5, 2016        University of Washington
# 1  NCT00797472     November 24, 2008  American Scitech International
# 2  NCT03499821         April 9, 2018          Staar Surgical Company
# 3  NCT01224028      October 18, 2010             Astellas Pharma Inc
# 4  NCT02279680         June 23, 2014       University Hospital, Caen
#
#                                          brief_title          condition  \
# 0  DEBUT: Diverticulitis Evaluation of Patient Bu...     Diverticulitis
# 1  Study Comparing R-mabHD and a Combination of A...  Hodgkin's Disease
# 2  Clinical Performance of a Phakic Intraocular L...         Presbyopia
# 3  A Study to Evaluate the Efficacy and Safety of...    IgA Nephropathy
# 4  Associative Memory in Adults With an Autism Sp...  Autistic Disorder
#
#                       detailed_description/textblock  \
# 0  \n      This study will examine both clinical ...
# 1  \n      The primary objective is to compare th...
# 2  \n      This is a prospective, open-labeled, m...
# 3                                               None
# 4                                               None
#
#                              brief_summary/textblock      dates
# 0  \n      Half of all Americans over 60 years of... 2016-05-05
# 1  \n      120 subjects with Hodgkin's disease wi... 2008-11-24
# 2  \n      This study will evaluate the clinical ... 2018-04-09
# 3  \n      This study is to evaluate efficacy and... 2010-10-18
# 4  \n      The objective of this multidisciplinar... 2014-06-23
