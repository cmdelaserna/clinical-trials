# %% [markdown]
# # Clinical trials: Parse all XML files

# %%
#Data: clinicaltrials.gov

# %%
# reset variables and turn off autosave
# %reset
# %autosave 0
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import zipfile
import sys
import time
import json
import re
import os
import xml.etree.ElementTree as ET
import shutil
import pandas as pd
from collections import Counter

# %%
# Print messages to the terminal

sys.stdout = open('/dev/stdout', 'w')

# %% [markdown]
# ## Setup: create paths and folders

# %%
'''
Create paths and folders
'''

# Folders with xml files
path_to_all_xml_trials = os.path.abspath('../data/all_trials/')

# Test folder ~100 files
path_to_test_folder = os.path.abspath('../data/test/')

#Remove old files from test folder
try:
    shutil.rmtree(path_to_test_folder) 
except FileNotFoundError:
    pass

# Path for json folder
path_to_json_file = os.path.abspath('../data/json/')

# Variable for all parsed files
all_parsed_files = []

print('\nPaths and folders created\n')

# %%
# Create folders

create_folders_errors = []

def create_folders(paths=[]):
    for p in paths:
        try:
            os.mkdir(p)
            if p:
                print('{} created'.format(p))
        except IOError as e:
            create_folders_errors.append(e)
            pass

    print('\nSetup folders created with exceptions: {}\n'.format(create_folders_errors))
    
all_folders = [path_to_all_xml_trials, path_to_test_folder, path_to_json_file]
    
# create folders
create_folders(all_folders)

# %% [markdown]
# ### Create test folder with n random files

# %%
'''
Select n random files from all trials and save them in test folder
'''
files_for_test = 1000

import random

# Pending: If files in test folder, delete them
random_files = []
random_files = random.sample(os.listdir(path_to_all_xml_trials), files_for_test)
print('Random files: {}'.format(len(random_files)))

for f in random_files:
    src = os.path.join(path_to_all_xml_trials, f)
    shutil.copy(src, path_to_test_folder)

# %%
print(random_files[0:5])

# %% [markdown]
# ## Parse all xml files

# %%
'''
Parse all xml files and save them in a all_parsed_files variable.
Slow. Checks for xml files
'''

def parse_xml_files(path_to_folder):
    for filename in os.listdir(path_to_folder):
#         if not filename.endswith('.xml'): continue
        fullname = os.path.join(path_to_folder, filename)
        all_parsed_files.append(ET.parse(fullname).getroot())
        
        # Checking message to the terminal
        print("{} file parsed\n".format(fullname))

    print('Number of files parsed: {}\n'.format(len(all_parsed_files)))
        
    return all_parsed_files

# %%
# Run function
all_parsed_files.clear()
# %time parse_xml_files(path_to_test_folder)
# Out:
# [<Element 'clinical_study' at 0x10600c318>,
#  <Element 'clinical_study' at 0x11642eb38>,
#  <Element 'clinical_study' at 0x11643e638>,
#  <Element 'clinical_study' at 0x1164474a8>,
#  <Element 'clinical_study' at 0x116454138>,
#  <Element 'clinical_study' at 0x1164e3688>,
#  <Element 'clinical_study' at 0x1164e7d18>,
#  <Element 'clinical_study' at 0x1164fd408>,
#  <Element 'clinical_study' at 0x116506598>,
#  <Element 'clinical_study' at 0x116511138>,
#  <Element 'clinical_study' at 0x116514818>,
#  <Element 'clinical_study' at 0x11584ef98>,
#  <Element 'clinical_study' at 0x11585aae8>,
#  <Element 'clinical_study' at 0x11588d638>,
#  <Element 'clinical_study' at 0x11569d9a8>,
#  <Element 'clinical_study' at 0x1156a80e8>,
#  <Element 'clinical_study' at 0x1156af318>,
#  <Element 'clinical_study' at 0x1156b8188>,
#  <Element 'clinical_study' at 0x1156c15e8>,
#  <Element 'clinical_study' at 0x1156c9ae8>,
#  <Element 'clinical_study' at 0x1159ee598>,
#  <Element 'clinical_study' at 0x1159fa908>,
#  <Element 'clinical_study' at 0x1159ff408>,
#  <Element 'clinical_study' at 0x115a0b8b8>,
#  <Element 'clinical_study' at 0x115a1c688>,
#  <Element 'clinical_study' at 0x115fe3318>,
#  <Element 'clinical_study' at 0x115fefea8>,
#  <Element 'clinical_study' at 0x116006868>,
#  <Element 'clinical_study' at 0x1160148b8>,
#  <Element 'clinical_study' at 0x1169fa458>,
#  <Element 'clinical_study' at 0x116a00ea8>,
#  <Element 'clinical_study' at 0x116a108b8>,
#  <Element 'clinical_study' at 0x116a18598>,
#  <Element 'clinical_study' at 0x116a2aa98>,
#  <Element 'clinical_study' at 0x115af3318>,
#  <Element 'clinical_study' at 0x115afc688>,
#  <Element 'clinical_study' at 0x115b0dc28>,
#  <Element 'clinical_study' at 0x115b6f2c8>,
#  <Element 'clinical_study' at 0x115b77b88>,
#  <Element 'clinical_study' at 0x115b820e8>,
#  <Element 'clinical_study' at 0x1164713b8>,
#  <Element 'clinical_study' at 0x116324228>,
#  <Element 'clinical_study' at 0x1165acbd8>,
#  <Element 'clinical_study' at 0x1165b7408>,
#  <Element 'clinical_study' at 0x1165be6d8>,
#  <Element 'clinical_study' at 0x1165c9778>,
#  <Element 'clinical_study' at 0x1165d0c78>,
#  <Element 'clinical_study' at 0x116664598>,
#  <Element 'clinical_study' at 0x116669db8>,
#  <Element 'clinical_study' at 0x1166737c8>,
#  <Element 'clinical_study' at 0x116679368>,
#  <Element 'clinical_study' at 0x116692278>,
#  <Element 'clinical_study' at 0x116698ea8>,
#  <Element 'clinical_study' at 0x115db48b8>,
#  <Element 'clinical_study' at 0x115dbe728>,
#  <Element 'clinical_study' at 0x115dc6db8>,
#  <Element 'clinical_study' at 0x115dd9048>,
#  <Element 'clinical_study' at 0x115de1d18>,
#  <Element 'clinical_study' at 0x1163cdcc8>,
#  <Element 'clinical_study' at 0x1163d39a8>,
#  <Element 'clinical_study' at 0x1163dbef8>,
#  <Element 'clinical_study' at 0x1166022c8>,
#  <Element 'clinical_study' at 0x11660f0e8>,
#  <Element 'clinical_study' at 0x116616cc8>,
#  <Element 'clinical_study' at 0x116633188>,
#  <Element 'clinical_study' at 0x116646458>,
#  <Element 'clinical_study' at 0x115a63cc8>,
#  <Element 'clinical_study' at 0x104a1aea8>,
#  <Element 'clinical_study' at 0x104a253b8>,
#  <Element 'clinical_study' at 0x104a28a48>,
#  <Element 'clinical_study' at 0x115c28e08>,
#  <Element 'clinical_study' at 0x115f2dc28>,
#  <Element 'clinical_study' at 0x115f38598>,
#  <Element 'clinical_study' at 0x115f41188>,
#  <Element 'clinical_study' at 0x115e269a8>,
#  <Element 'clinical_study' at 0x115e37188>,
#  <Element 'clinical_study' at 0x115e42908>,
#  <Element 'clinical_study' at 0x115e4bd68>,
#  <Element 'clinical_study' at 0x115e579f8>,
#  <Element 'clinical_study' at 0x1162ca458>,
#  <Element 'clinical_study' at 0x1162d5548>,
#  <Element 'clinical_study' at 0x1162e66d8>,
#  <Element 'clinical_study' at 0x1162ef818>,
#  <Element 'clinical_study' at 0x1162f6ea8>,
#  <Element 'clinical_study' at 0x116303818>,
#  <Element 'clinical_study' at 0x1167330e8>,
#  <Element 'clinical_study' at 0x11673ad18>,
#  <Element 'clinical_study' at 0x115722bd8>,
#  <Element 'clinical_study' at 0x115730318>,
#  <Element 'clinical_study' at 0x11573f4f8>,
#  <Element 'clinical_study' at 0x11574ac28>,
#  <Element 'clinical_study' at 0x1159ceb88>,
#  <Element 'clinical_study' at 0x1159df8b8>,
#  <Element 'clinical_study' at 0x115a75408>,
#  <Element 'clinical_study' at 0x115a7aef8>,
#  <Element 'clinical_study' at 0x115a91458>,
#  <Element 'clinical_study' at 0x115a9c7c8>,
#  <Element 'clinical_study' at 0x115aad598>,
#  <Element 'clinical_study' at 0x115ac3278>,
#  <Element 'clinical_study' at 0x115ad8548>,
#  <Element 'clinical_study' at 0x1164d5f98>,
#  <Element 'clinical_study' at 0x116525278>,
#  <Element 'clinical_study' at 0x116544728>,
#  <Element 'clinical_study' at 0x116555048>,
#  <Element 'clinical_study' at 0x116354598>,
#  <Element 'clinical_study' at 0x11636a2c8>,
#  <Element 'clinical_study' at 0x116374ae8>,
#  <Element 'clinical_study' at 0x1163833b8>,
#  <Element 'clinical_study' at 0x1157dae58>,
#  <Element 'clinical_study' at 0x1157f5f98>,
#  <Element 'clinical_study' at 0x1157fde08>,
#  <Element 'clinical_study' at 0x115c5c0e8>,
#  <Element 'clinical_study' at 0x115c67098>,
#  <Element 'clinical_study' at 0x115c7a368>,
#  <Element 'clinical_study' at 0x115ca51d8>,
#  <Element 'clinical_study' at 0x115cb4728>,
#  <Element 'clinical_study' at 0x115cbdc28>,
#  <Element 'clinical_study' at 0x115cecf48>,
#  <Element 'clinical_study' at 0x115d07318>,
#  <Element 'clinical_study' at 0x115d19958>,
#  <Element 'clinical_study' at 0x115f00db8>,
#  <Element 'clinical_study' at 0x115f0f0e8>,
#  <Element 'clinical_study' at 0x115f1bc78>,
#  <Element 'clinical_study' at 0x115f6a4a8>,
#  <Element 'clinical_study' at 0x115f786d8>,
#  <Element 'clinical_study' at 0x115f8a9a8>,
#  <Element 'clinical_study' at 0x115f99818>,
#  <Element 'clinical_study' at 0x1160699a8>,
#  <Element 'clinical_study' at 0x11607bd68>,
#  <Element 'clinical_study' at 0x1160944a8>,
#  <Element 'clinical_study' at 0x1160a0db8>,
#  <Element 'clinical_study' at 0x116190778>,
#  <Element 'clinical_study' at 0x1161a9c78>,
#  <Element 'clinical_study' at 0x1161b4db8>,
#  <Element 'clinical_study' at 0x1166a09a8>,
#  <Element 'clinical_study' at 0x1166ad458>,
#  <Element 'clinical_study' at 0x1166b84a8>,
#  <Element 'clinical_study' at 0x1166c3048>,
#  <Element 'clinical_study' at 0x1166d2408>,
#  <Element 'clinical_study' at 0x1166e49f8>,
#  <Element 'clinical_study' at 0x1166f8868>,
#  <Element 'clinical_study' at 0x116705908>,
#  <Element 'clinical_study' at 0x1167129a8>,
#  <Element 'clinical_study' at 0x115d6c548>,
#  <Element 'clinical_study' at 0x1160cbea8>,
#  <Element 'clinical_study' at 0x1160fe368>,
#  <Element 'clinical_study' at 0x1158d8688>,
#  <Element 'clinical_study' at 0x1158e4278>,
#  <Element 'clinical_study' at 0x1158ee098>,
#  <Element 'clinical_study' at 0x1158fc3b8>,
#  <Element 'clinical_study' at 0x115897908>,
#  <Element 'clinical_study' at 0x1158a8408>,
#  <Element 'clinical_study' at 0x115d2c728>,
#  <Element 'clinical_study' at 0x115d4cb38>,
#  <Element 'clinical_study' at 0x115d58138>,
#  <Element 'clinical_study' at 0x115fb5c28>,
#  <Element 'clinical_study' at 0x115fc6458>,
#  <Element 'clinical_study' at 0x115fd66d8>,
#  <Element 'clinical_study' at 0x115fe19a8>,
#  <Element 'clinical_study' at 0x1161d62c8>,
#  <Element 'clinical_study' at 0x1161f5048>,
#  <Element 'clinical_study' at 0x116206e08>,
#  <Element 'clinical_study' at 0x116217958>,
#  <Element 'clinical_study' at 0x116b0ae58>,
#  <Element 'clinical_study' at 0x116b1a7c8>,
#  <Element 'clinical_study' at 0x116b2a7c8>,
#  <Element 'clinical_study' at 0x116776728>,
#  <Element 'clinical_study' at 0x11677c868>,
#  <Element 'clinical_study' at 0x116784f48>,
#  <Element 'clinical_study' at 0x11678ca98>,
#  <Element 'clinical_study' at 0x116799688>,
#  <Element 'clinical_study' at 0x11679fd18>,
#  <Element 'clinical_study' at 0x1167afbd8>,
#  <Element 'clinical_study' at 0x1167bb548>,
#  <Element 'clinical_study' at 0x1167f4908>,
#  <Element 'clinical_study' at 0x1167ffb88>,
#  <Element 'clinical_study' at 0x11681b408>,
#  <Element 'clinical_study' at 0x116825318>,
#  <Element 'clinical_study' at 0x11685a3b8>,
#  <Element 'clinical_study' at 0x116865818>,
#  <Element 'clinical_study' at 0x11686dea8>,
#  <Element 'clinical_study' at 0x116876e58>,
#  <Element 'clinical_study' at 0x116886408>,
#  <Element 'clinical_study' at 0x116893868>,
#  <Element 'clinical_study' at 0x11689d458>,
#  <Element 'clinical_study' at 0x1168b1598>,
#  <Element 'clinical_study' at 0x1168f1db8>,
#  <Element 'clinical_study' at 0x116903138>,
#  <Element 'clinical_study' at 0x11690fbd8>,
#  <Element 'clinical_study' at 0x116918868>,
#  <Element 'clinical_study' at 0x1169279a8>,
#  <Element 'clinical_study' at 0x116935188>,
#  <Element 'clinical_study' at 0x11693de58>,
#  <Element 'clinical_study' at 0x11694c228>,
#  <Element 'clinical_study' at 0x1169569a8>,
#  <Element 'clinical_study' at 0x116987a98>,
#  <Element 'clinical_study' at 0x116994db8>,
#  <Element 'clinical_study' at 0x11699de58>,
#  <Element 'clinical_study' at 0x116b33db8>,
#  <Element 'clinical_study' at 0x116b3cf48>,
#  <Element 'clinical_study' at 0x116b52408>,
#  <Element 'clinical_study' at 0x116b5c408>,
#  <Element 'clinical_study' at 0x116b7e598>,
#  <Element 'clinical_study' at 0x116b89818>,
#  <Element 'clinical_study' at 0x116bb34a8>,
#  <Element 'clinical_study' at 0x116bca9a8>,
#  <Element 'clinical_study' at 0x116bd3868>,
#  <Element 'clinical_study' at 0x116bdd908>,
#  <Element 'clinical_study' at 0x116bf34f8>,
#  <Element 'clinical_study' at 0x116bfb3b8>,
#  <Element 'clinical_study' at 0x116c06228>,
#  <Element 'clinical_study' at 0x116c2f1d8>,
#  <Element 'clinical_study' at 0x116c38bd8>,
#  <Element 'clinical_study' at 0x116c493b8>,
#  <Element 'clinical_study' at 0x116c4ee58>,
#  <Element 'clinical_study' at 0x116c75188>,
#  <Element 'clinical_study' at 0x116c7f728>,
#  <Element 'clinical_study' at 0x116c8a368>,
#  <Element 'clinical_study' at 0x116c91bd8>,
#  <Element 'clinical_study' at 0x116ca2868>,
#  <Element 'clinical_study' at 0x116caa9a8>,
#  <Element 'clinical_study' at 0x116cbb4a8>,
#  <Element 'clinical_study' at 0x116cc5a98>,
#  <Element 'clinical_study' at 0x116cd6408>,
#  <Element 'clinical_study' at 0x116ce1ea8>,
#  <Element 'clinical_study' at 0x116cf0458>,
#  <Element 'clinical_study' at 0x116cfe138>,
#  <Element 'clinical_study' at 0x116d09138>,
#  <Element 'clinical_study' at 0x116d139a8>,
#  <Element 'clinical_study' at 0x116d20d18>,
#  <Element 'clinical_study' at 0x116d339f8>,
#  <Element 'clinical_study' at 0x116d3f778>,
#  <Element 'clinical_study' at 0x116d49458>,
#  <Element 'clinical_study' at 0x116db7368>,
#  <Element 'clinical_study' at 0x116dc39f8>,
#  <Element 'clinical_study' at 0x116dd24f8>,
#  <Element 'clinical_study' at 0x116dff9f8>,
#  <Element 'clinical_study' at 0x116e0fbd8>,
#  <Element 'clinical_study' at 0x116e1bb38>,
#  <Element 'clinical_study' at 0x116fe19f8>,
#  <Element 'clinical_study' at 0x116fef9f8>,
#  <Element 'clinical_study' at 0x116ff9ae8>,
#  <Element 'clinical_study' at 0x116fffe08>,
#  <Element 'clinical_study' at 0x117060778>,
#  <Element 'clinical_study' at 0x11706a368>,
#  <Element 'clinical_study' at 0x117072a48>,
#  <Element 'clinical_study' at 0x117083138>,
#  <Element 'clinical_study' at 0x11709a5e8>,
#  <Element 'clinical_study' at 0x1170a5408>,
#  <Element 'clinical_study' at 0x1170b3868>,
#  <Element 'clinical_study' at 0x1170c4098>,
#  <Element 'clinical_study' at 0x1170cbe08>,
#  <Element 'clinical_study' at 0x1170fb908>,
#  <Element 'clinical_study' at 0x1171099a8>,
#  <Element 'clinical_study' at 0x1171112c8>,
#  <Element 'clinical_study' at 0x117114b38>,
#  <Element 'clinical_study' at 0x117120688>,
#  <Element 'clinical_study' at 0x11713bef8>,
#  <Element 'clinical_study' at 0x1171476d8>,
#  <Element 'clinical_study' at 0x117150a98>,
#  <Element 'clinical_study' at 0x117163e58>,
#  <Element 'clinical_study' at 0x11716d228>,
#  <Element 'clinical_study' at 0x1171774a8>,
#  <Element 'clinical_study' at 0x117189f98>,
#  <Element 'clinical_study' at 0x11719c0e8>,
#  <Element 'clinical_study' at 0x1171aa0e8>,
#  <Element 'clinical_study' at 0x1171b7cc8>,
#  <Element 'clinical_study' at 0x1171c6958>,
#  <Element 'clinical_study' at 0x1171cfea8>,
#  <Element 'clinical_study' at 0x1171fc1d8>,
#  <Element 'clinical_study' at 0x11720c098>,
#  <Element 'clinical_study' at 0x1172150e8>,
#  <Element 'clinical_study' at 0x11723ae58>,
#  <Element 'clinical_study' at 0x117243cc8>,
#  <Element 'clinical_study' at 0x117255908>,
#  <Element 'clinical_study' at 0x11725e048>,
#  <Element 'clinical_study' at 0x1172e7bd8>,
#  <Element 'clinical_study' at 0x1172fa6d8>,
#  <Element 'clinical_study' at 0x1173067c8>,
#  <Element 'clinical_study' at 0x117315728>,
#  <Element 'clinical_study' at 0x117319d18>,
#  <Element 'clinical_study' at 0x117328d68>,
#  <Element 'clinical_study' at 0x117336ae8>,
#  <Element 'clinical_study' at 0x117347b88>,
#  <Element 'clinical_study' at 0x11735d228>,
#  <Element 'clinical_study' at 0x117366bd8>,
#  <Element 'clinical_study' at 0x11737a278>,
#  <Element 'clinical_study' at 0x11738d368>,
#  <Element 'clinical_study' at 0x1173994f8>,
#  <Element 'clinical_study' at 0x1174410e8>,
#  <Element 'clinical_study' at 0x117449408>,
#  <Element 'clinical_study' at 0x117456c28>,
#  <Element 'clinical_study' at 0x117496408>,
#  <Element 'clinical_study' at 0x11749cc78>,
#  <Element 'clinical_study' at 0x1174b18b8>,
#  <Element 'clinical_study' at 0x1174ba868>,
#  <Element 'clinical_study' at 0x1174cc818>,
#  <Element 'clinical_study' at 0x1174f14a8>,
#  <Element 'clinical_study' at 0x1174faa48>,
#  <Element 'clinical_study' at 0x117509548>,
#  <Element 'clinical_study' at 0x117519228>,
#  <Element 'clinical_study' at 0x117525778>,
#  <Element 'clinical_study' at 0x11752ce08>,
#  <Element 'clinical_study' at 0x11753a908>,
#  <Element 'clinical_study' at 0x117545cc8>,
#  <Element 'clinical_study' at 0x1175546d8>,
#  <Element 'clinical_study' at 0x1175604f8>,
#  <Element 'clinical_study' at 0x117576f48>,
#  <Element 'clinical_study' at 0x117586a48>,
#  <Element 'clinical_study' at 0x1175b1638>,
#  <Element 'clinical_study' at 0x1175c25e8>,
#  <Element 'clinical_study' at 0x1175d4c78>,
#  <Element 'clinical_study' at 0x1175e6138>,
#  <Element 'clinical_study' at 0x1175e9f48>,
#  <Element 'clinical_study' at 0x117618228>,
#  <Element 'clinical_study' at 0x117620548>,
#  <Element 'clinical_study' at 0x11762e778>,
#  <Element 'clinical_study' at 0x11763e188>,
#  <Element 'clinical_study' at 0x117647908>,
#  <Element 'clinical_study' at 0x1176c46d8>,
#  <Element 'clinical_study' at 0x1176d4728>,
#  <Element 'clinical_study' at 0x1176dbae8>,
#  <Element 'clinical_study' at 0x1176f3188>,
#  <Element 'clinical_study' at 0x117704408>,
#  <Element 'clinical_study' at 0x11770c688>,
#  <Element 'clinical_study' at 0x11773d9f8>,
#  <Element 'clinical_study' at 0x117755f48>,
#  <Element 'clinical_study' at 0x11775ce58>,
#  <Element 'clinical_study' at 0x11776af98>,
#  <Element 'clinical_study' at 0x11777b228>,
#  <Element 'clinical_study' at 0x117788778>,
#  <Element 'clinical_study' at 0x117861c78>,
#  <Element 'clinical_study' at 0x117872548>,
#  <Element 'clinical_study' at 0x117879db8>,
#  <Element 'clinical_study' at 0x11788f548>,
#  <Element 'clinical_study' at 0x1178a11d8>,
#  <Element 'clinical_study' at 0x1178a5e58>,
#  <Element 'clinical_study' at 0x1178b73b8>,
#  <Element 'clinical_study' at 0x1178c0548>,
#  <Element 'clinical_study' at 0x1178d4f48>,
#  <Element 'clinical_study' at 0x1178e47c8>,
#  <Element 'clinical_study' at 0x1178f5818>,
#  <Element 'clinical_study' at 0x1179111d8>,
#  <Element 'clinical_study' at 0x11791e5e8>,
#  <Element 'clinical_study' at 0x11796f0e8>,
#  <Element 'clinical_study' at 0x11797ae08>,
#  <Element 'clinical_study' at 0x11798e4f8>,
#  <Element 'clinical_study' at 0x117997f48>,
#  <Element 'clinical_study' at 0x1179a9048>,
#  <Element 'clinical_study' at 0x1179b6408>,
#  <Element 'clinical_study' at 0x1179beef8>,
#  <Element 'clinical_study' at 0x1179cc048>,
#  <Element 'clinical_study' at 0x1179d7098>,
#  <Element 'clinical_study' at 0x117a0f958>,
#  <Element 'clinical_study' at 0x117a18638>,
#  <Element 'clinical_study' at 0x117a21138>,
#  <Element 'clinical_study' at 0x117a3c048>,
#  <Element 'clinical_study' at 0x117afca48>,
#  <Element 'clinical_study' at 0x117b146d8>,
#  <Element 'clinical_study' at 0x117b1e8b8>,
#  <Element 'clinical_study' at 0x117b29f98>,
#  <Element 'clinical_study' at 0x117b3c868>,
#  <Element 'clinical_study' at 0x117b44ef8>,
#  <Element 'clinical_study' at 0x117b5c1d8>,
#  <Element 'clinical_study' at 0x117b7f8b8>,
#  <Element 'clinical_study' at 0x117b8d598>,
#  <Element 'clinical_study' at 0x117b9b368>,
#  <Element 'clinical_study' at 0x117c101d8>,
#  <Element 'clinical_study' at 0x117c1c598>,
#  <Element 'clinical_study' at 0x117c27318>,
#  <Element 'clinical_study' at 0x117c325e8>,
#  <Element 'clinical_study' at 0x117c46818>,
#  <Element 'clinical_study' at 0x117cbf9f8>,
#  <Element 'clinical_study' at 0x117cc8db8>,
#  <Element 'clinical_study' at 0x117cd86d8>,
#  <Element 'clinical_study' at 0x117ce6638>,
#  <Element 'clinical_study' at 0x117cede58>,
#  <Element 'clinical_study' at 0x117d01f48>,
#  <Element 'clinical_study' at 0x117d0ef48>,
#  <Element 'clinical_study' at 0x117d31a48>,
#  <Element 'clinical_study' at 0x117d3df48>,
#  <Element 'clinical_study' at 0x117d4d2c8>,
#  <Element 'clinical_study' at 0x117dbb778>,
#  <Element 'clinical_study' at 0x117dca548>,
#  <Element 'clinical_study' at 0x117dd2bd8>,
#  <Element 'clinical_study' at 0x117de1f48>,
#  <Element 'clinical_study' at 0x117df4ea8>,
#  <Element 'clinical_study' at 0x117dfc6d8>,
#  <Element 'clinical_study' at 0x117e0c4a8>,
#  <Element 'clinical_study' at 0x117eb69a8>,
#  <Element 'clinical_study' at 0x117ec78b8>,
#  <Element 'clinical_study' at 0x117ed5bd8>,
#  <Element 'clinical_study' at 0x117eebae8>,
#  <Element 'clinical_study' at 0x117ef7688>,
#  <Element 'clinical_study' at 0x117f01b88>,
#  <Element 'clinical_study' at 0x117f14d18>,
#  <Element 'clinical_study' at 0x117f1cae8>,
#  <Element 'clinical_study' at 0x117f274a8>,
#  <Element 'clinical_study' at 0x117f55688>,
#  <Element 'clinical_study' at 0x117f6b638>,
#  <Element 'clinical_study' at 0x117f70c78>,
#  <Element 'clinical_study' at 0x117f7e0e8>,
#  <Element 'clinical_study' at 0x117f8d278>,
#  <Element 'clinical_study' at 0x117f92b38>,
#  <Element 'clinical_study' at 0x117fa42c8>,
#  <Element 'clinical_study' at 0x117fa8ae8>,
#  <Element 'clinical_study' at 0x117fb88b8>,
#  <Element 'clinical_study' at 0x117fd40e8>,
#  <Element 'clinical_study' at 0x117fe2368>,
#  <Element 'clinical_study' at 0x117fe9b38>,
#  <Element 'clinical_study' at 0x117ff4e58>,
#  <Element 'clinical_study' at 0x118007b38>,
#  <Element 'clinical_study' at 0x118014368>,
#  <Element 'clinical_study' at 0x11803e458>,
#  <Element 'clinical_study' at 0x1180538b8>,
#  <Element 'clinical_study' at 0x11805ca48>,
#  <Element 'clinical_study' at 0x118066e08>,
#  <Element 'clinical_study' at 0x118074e08>,
#  <Element 'clinical_study' at 0x11808e778>,
#  <Element 'clinical_study' at 0x1180ce458>,
#  <Element 'clinical_study' at 0x1180d5958>,
#  <Element 'clinical_study' at 0x1180de6d8>,
#  <Element 'clinical_study' at 0x1180e9c78>,
#  <Element 'clinical_study' at 0x1180faf98>,
#  <Element 'clinical_study' at 0x118113c28>,
#  <Element 'clinical_study' at 0x11816fea8>,
#  <Element 'clinical_study' at 0x118179138>,
#  <Element 'clinical_study' at 0x118188818>,
#  <Element 'clinical_study' at 0x118198a98>,
#  <Element 'clinical_study' at 0x11838ebd8>,
#  <Element 'clinical_study' at 0x1183a0f98>,
#  <Element 'clinical_study' at 0x1183ad098>,
#  <Element 'clinical_study' at 0x1183b7458>,
#  <Element 'clinical_study' at 0x1183c3408>,
#  <Element 'clinical_study' at 0x1183d3318>,
#  <Element 'clinical_study' at 0x1183e9638>,
#  <Element 'clinical_study' at 0x1183f34a8>,
#  <Element 'clinical_study' at 0x1183fd048>,
#  <Element 'clinical_study' at 0x11840e048>,
#  <Element 'clinical_study' at 0x118477688>,
#  <Element 'clinical_study' at 0x11847abd8>,
#  <Element 'clinical_study' at 0x118489a48>,
#  <Element 'clinical_study' at 0x118495b88>,
#  <Element 'clinical_study' at 0x1184aa3b8>,
#  <Element 'clinical_study' at 0x1184b2b88>,
#  <Element 'clinical_study' at 0x1184bdd18>,
#  <Element 'clinical_study' at 0x1184cdd68>,
#  <Element 'clinical_study' at 0x1184e3e08>,
#  <Element 'clinical_study' at 0x1184f9e58>,
#  <Element 'clinical_study' at 0x11850a228>,
#  <Element 'clinical_study' at 0x118513d18>,
#  <Element 'clinical_study' at 0x11851ca48>,
#  <Element 'clinical_study' at 0x11852dcc8>,
#  <Element 'clinical_study' at 0x118541188>,
#  <Element 'clinical_study' at 0x118551868>,
#  <Element 'clinical_study' at 0x118577868>,
#  <Element 'clinical_study' at 0x118594368>,
#  <Element 'clinical_study' at 0x11859ecc8>,
#  <Element 'clinical_study' at 0x1185b7228>,
#  <Element 'clinical_study' at 0x1185c1778>,
#  <Element 'clinical_study' at 0x1185cca48>,
#  <Element 'clinical_study' at 0x1185d6908>,
#  <Element 'clinical_study' at 0x1185de868>,
#  <Element 'clinical_study' at 0x11860d1d8>,
#  <Element 'clinical_study' at 0x118613cc8>,
#  <Element 'clinical_study' at 0x118620db8>,
#  <Element 'clinical_study' at 0x11862eb38>,
#  <Element 'clinical_study' at 0x118638ef8>,
#  <Element 'clinical_study' at 0x118654098>,
#  <Element 'clinical_study' at 0x118654958>,
#  <Element 'clinical_study' at 0x11865c818>,
#  <Element 'clinical_study' at 0x11868d4f8>,
#  <Element 'clinical_study' at 0x1187fa2c8>,
#  <Element 'clinical_study' at 0x1188029f8>,
#  <Element 'clinical_study' at 0x11880c9f8>,
#  <Element 'clinical_study' at 0x11881cae8>,
#  <Element 'clinical_study' at 0x118829278>,
#  <Element 'clinical_study' at 0x11884fe58>,
#  <Element 'clinical_study' at 0x118894b38>,
#  <Element 'clinical_study' at 0x1188a46d8>,
#  <Element 'clinical_study' at 0x1188b61d8>,
#  <Element 'clinical_study' at 0x1188cb368>,
#  <Element 'clinical_study' at 0x1188d48b8>,
#  <Element 'clinical_study' at 0x1188dc138>,
#  <Element 'clinical_study' at 0x1188e0ea8>,
#  <Element 'clinical_study' at 0x1189074f8>,
#  <Element 'clinical_study' at 0x118927908>,
#  <Element 'clinical_study' at 0x118934d18>,
#  <Element 'clinical_study' at 0x118946368>,
#  <Element 'clinical_study' at 0x11894ddb8>,
#  <Element 'clinical_study' at 0x118961a48>,
#  <Element 'clinical_study' at 0x118973c78>,
#  <Element 'clinical_study' at 0x118982958>,
#  <Element 'clinical_study' at 0x11898dd18>,
#  <Element 'clinical_study' at 0x11899e5e8>,
#  <Element 'clinical_study' at 0x1189e3278>,
#  <Element 'clinical_study' at 0x1189ef548>,
#  <Element 'clinical_study' at 0x1189f7958>,
#  <Element 'clinical_study' at 0x1189fcb38>,
#  <Element 'clinical_study' at 0x118a0b0e8>,
#  <Element 'clinical_study' at 0x118a1f318>,
#  <Element 'clinical_study' at 0x118a40188>,
#  <Element 'clinical_study' at 0x118a49228>,
#  <Element 'clinical_study' at 0x118a4da98>,
#  <Element 'clinical_study' at 0x118a5dea8>,
#  <Element 'clinical_study' at 0x118a77458>,
#  <Element 'clinical_study' at 0x118a79ea8>,
#  <Element 'clinical_study' at 0x118b6ae58>,
#  <Element 'clinical_study' at 0x118b96778>,
#  <Element 'clinical_study' at 0x118b9e868>,
#  <Element 'clinical_study' at 0x118baad68>,
#  <Element 'clinical_study' at 0x118d9fae8>,
#  <Element 'clinical_study' at 0x118daf9a8>,
#  <Element 'clinical_study' at 0x118dbbae8>,
#  <Element 'clinical_study' at 0x118dc53b8>,
#  <Element 'clinical_study' at 0x118dd04f8>,
#  <Element 'clinical_study' at 0x118dd5e58>,
#  <Element 'clinical_study' at 0x118dea188>,
#  <Element 'clinical_study' at 0x118df3db8>,
#  <Element 'clinical_study' at 0x118e04228>,
#  <Element 'clinical_study' at 0x118e13638>,
#  <Element 'clinical_study' at 0x118e23c78>,
#  <Element 'clinical_study' at 0x118e36818>,
#  <Element 'clinical_study' at 0x118ecf3b8>,
#  <Element 'clinical_study' at 0x118eda1d8>,
#  <Element 'clinical_study' at 0x118ee35e8>,
#  <Element 'clinical_study' at 0x118eede58>,
#  <Element 'clinical_study' at 0x118f7f868>,
#  <Element 'clinical_study' at 0x118f89188>,
#  <Element 'clinical_study' at 0x118f95908>,
#  <Element 'clinical_study' at 0x118f9c868>,
#  <Element 'clinical_study' at 0x118fac7c8>,
#  <Element 'clinical_study' at 0x118fe5458>,
#  <Element 'clinical_study' at 0x1190124a8>,
#  <Element 'clinical_study' at 0x1190215e8>,
#  <Element 'clinical_study' at 0x11902d1d8>,
#  <Element 'clinical_study' at 0x119033458>,
#  <Element 'clinical_study' at 0x1190a49f8>,
#  <Element 'clinical_study' at 0x1192fd3b8>,
#  <Element 'clinical_study' at 0x11933ce08>,
#  <Element 'clinical_study' at 0x11937e138>,
#  <Element 'clinical_study' at 0x11938e868>,
#  <Element 'clinical_study' at 0x119398f48>,
#  <Element 'clinical_study' at 0x1193a8188>,
#  <Element 'clinical_study' at 0x1193b08b8>,
#  <Element 'clinical_study' at 0x1193c0cc8>,
#  <Element 'clinical_study' at 0x1193e3ef8>,
#  <Element 'clinical_study' at 0x1193fe098>,
#  <Element 'clinical_study' at 0x119443908>,
#  <Element 'clinical_study' at 0x119455188>,
#  <Element 'clinical_study' at 0x119491c28>,
#  <Element 'clinical_study' at 0x1194a5098>,
#  <Element 'clinical_study' at 0x1194b2048>,
#  <Element 'clinical_study' at 0x1194d1958>,
#  <Element 'clinical_study' at 0x1194dd048>,
#  <Element 'clinical_study' at 0x1194fad68>,
#  <Element 'clinical_study' at 0x119505408>,
#  <Element 'clinical_study' at 0x119513138>,
#  <Element 'clinical_study' at 0x119557d68>,
#  <Element 'clinical_study' at 0x11956d548>,
#  <Element 'clinical_study' at 0x119571d68>,
#  <Element 'clinical_study' at 0x1197e2c78>,
#  <Element 'clinical_study' at 0x1197f94a8>,
#  <Element 'clinical_study' at 0x119804a98>,
#  <Element 'clinical_study' at 0x119816b88>,
#  <Element 'clinical_study' at 0x11983ad68>,
#  <Element 'clinical_study' at 0x119842f48>,
#  <Element 'clinical_study' at 0x1198559f8>,
#  <Element 'clinical_study' at 0x119860318>,
#  <Element 'clinical_study' at 0x11986cb88>,
#  <Element 'clinical_study' at 0x119879ae8>,
#  <Element 'clinical_study' at 0x11988a2c8>,
#  <Element 'clinical_study' at 0x11988dea8>,
#  <Element 'clinical_study' at 0x119895f98>,
#  <Element 'clinical_study' at 0x1198d67c8>,
#  <Element 'clinical_study' at 0x119917d18>,
#  <Element 'clinical_study' at 0x11992a318>,
#  <Element 'clinical_study' at 0x119934688>,
#  <Element 'clinical_study' at 0x119946728>,
#  <Element 'clinical_study' at 0x119954278>,
#  <Element 'clinical_study' at 0x11995f908>,
#  <Element 'clinical_study' at 0x119968728>,
#  <Element 'clinical_study' at 0x11997a4f8>,
#  <Element 'clinical_study' at 0x1199865e8>,
#  <Element 'clinical_study' at 0x11999a458>,
#  <Element 'clinical_study' at 0x1199a3688>,
#  <Element 'clinical_study' at 0x1199b4818>,
#  <Element 'clinical_study' at 0x119a098b8>,
#  <Element 'clinical_study' at 0x119a135e8>,
#  <Element 'clinical_study' at 0x119a55868>,
#  <Element 'clinical_study' at 0x119a65b88>,
#  <Element 'clinical_study' at 0x119a73d68>,
#  <Element 'clinical_study' at 0x119a9b228>,
#  <Element 'clinical_study' at 0x119aa4818>,
#  <Element 'clinical_study' at 0x119aade08>,
#  <Element 'clinical_study' at 0x119ab8a98>,
#  <Element 'clinical_study' at 0x119bd8688>,
#  <Element 'clinical_study' at 0x119bfa138>,
#  <Element 'clinical_study' at 0x119c05188>,
#  <Element 'clinical_study' at 0x119c15638>,
#  <Element 'clinical_study' at 0x119c39408>,
#  <Element 'clinical_study' at 0x119dbdae8>,
#  <Element 'clinical_study' at 0x119dc8b88>,
#  <Element 'clinical_study' at 0x119dd2f98>,
#  <Element 'clinical_study' at 0x119e02818>,
#  <Element 'clinical_study' at 0x119e11868>,
#  <Element 'clinical_study' at 0x119e1ee58>,
#  <Element 'clinical_study' at 0x119e26e58>,
#  <Element 'clinical_study' at 0x119e34188>,
#  <Element 'clinical_study' at 0x119ed40e8>,
#  <Element 'clinical_study' at 0x119efddb8>,
#  <Element 'clinical_study' at 0x119f17cc8>,
#  <Element 'clinical_study' at 0x119f37458>,
#  <Element 'clinical_study' at 0x119f3ecc8>,
#  <Element 'clinical_study' at 0x119f50228>,
#  <Element 'clinical_study' at 0x119f573b8>,
#  <Element 'clinical_study' at 0x119f660e8>,
#  <Element 'clinical_study' at 0x119f6bea8>,
#  <Element 'clinical_study' at 0x119f7e908>,
#  <Element 'clinical_study' at 0x119fa28b8>,
#  <Element 'clinical_study' at 0x119facea8>,
#  <Element 'clinical_study' at 0x119fb7598>,
#  <Element 'clinical_study' at 0x11a005638>,
#  <Element 'clinical_study' at 0x11a011958>,
#  <Element 'clinical_study' at 0x11a024278>,
#  <Element 'clinical_study' at 0x11a0302c8>,
#  <Element 'clinical_study' at 0x11a03e5e8>,
#  <Element 'clinical_study' at 0x11a04e098>,
#  <Element 'clinical_study' at 0x11a058188>,
#  <Element 'clinical_study' at 0x11a062688>,
#  <Element 'clinical_study' at 0x11a06e818>,
#  <Element 'clinical_study' at 0x11a078ae8>,
#  <Element 'clinical_study' at 0x11a08ae08>,
#  <Element 'clinical_study' at 0x11a091688>,
#  <Element 'clinical_study' at 0x11a0a3368>,
#  <Element 'clinical_study' at 0x11a0ade58>,
#  <Element 'clinical_study' at 0x11a0e9ae8>,
#  <Element 'clinical_study' at 0x11a0f2b88>,
#  <Element 'clinical_study' at 0x11a126f98>,
#  <Element 'clinical_study' at 0x11a138a48>,
#  <Element 'clinical_study' at 0x11a1471d8>,
#  <Element 'clinical_study' at 0x11a152778>,
#  <Element 'clinical_study' at 0x11a15d1d8>,
#  <Element 'clinical_study' at 0x11a1647c8>,
#  <Element 'clinical_study' at 0x11a21ee08>,
#  <Element 'clinical_study' at 0x11a226d68>,
#  <Element 'clinical_study' at 0x11a2376d8>,
#  <Element 'clinical_study' at 0x11a23f688>,
#  <Element 'clinical_study' at 0x11a249778>,
#  <Element 'clinical_study' at 0x11a257f48>,
#  <Element 'clinical_study' at 0x11a261ea8>,
#  <Element 'clinical_study' at 0x11a2721d8>,
#  <Element 'clinical_study' at 0x11a27a9a8>,
#  <Element 'clinical_study' at 0x11a281d18>,
#  <Element 'clinical_study' at 0x11a2940e8>,
#  <Element 'clinical_study' at 0x11a2be098>,
#  <Element 'clinical_study' at 0x11a2cba98>,
#  <Element 'clinical_study' at 0x11a2d9e08>,
#  <Element 'clinical_study' at 0x11a2f3958>,
#  <Element 'clinical_study' at 0x11a2f4228>,
#  <Element 'clinical_study' at 0x11a36b228>,
#  <Element 'clinical_study' at 0x11a373408>,
#  <Element 'clinical_study' at 0x11a382818>,
#  <Element 'clinical_study' at 0x11a38da48>,
#  <Element 'clinical_study' at 0x11a3df778>,
#  <Element 'clinical_study' at 0x11a3e6048>,
#  <Element 'clinical_study' at 0x11a3f0548>,
#  <Element 'clinical_study' at 0x11a401638>,
#  <Element 'clinical_study' at 0x11a40aae8>,
#  <Element 'clinical_study' at 0x11a41c228>,
#  <Element 'clinical_study' at 0x11a426ef8>,
#  <Element 'clinical_study' at 0x11a49fc28>,
#  <Element 'clinical_study' at 0x11a4ad4a8>,
#  <Element 'clinical_study' at 0x11a4bc408>,
#  <Element 'clinical_study' at 0x11a4e1818>,
#  <Element 'clinical_study' at 0x11a509a48>,
#  <Element 'clinical_study' at 0x11a519ef8>,
#  <Element 'clinical_study' at 0x11a531b88>,
#  <Element 'clinical_study' at 0x11a54a778>,
#  <Element 'clinical_study' at 0x11a55eae8>,
#  <Element 'clinical_study' at 0x11a575188>,
#  <Element 'clinical_study' at 0x11a5797c8>,
#  <Element 'clinical_study' at 0x11a586bd8>,
#  <Element 'clinical_study' at 0x11a596408>,
#  <Element 'clinical_study' at 0x11a59fae8>,
#  <Element 'clinical_study' at 0x11a5c64a8>,
#  <Element 'clinical_study' at 0x11a5cf4f8>,
#  <Element 'clinical_study' at 0x11a5db8b8>,
#  <Element 'clinical_study' at 0x11a5ff1d8>,
#  <Element 'clinical_study' at 0x11a60f0e8>,
#  <Element 'clinical_study' at 0x11a625bd8>,
#  <Element 'clinical_study' at 0x11a636048>,
#  <Element 'clinical_study' at 0x11a64af48>,
#  <Element 'clinical_study' at 0x11a6592c8>,
#  <Element 'clinical_study' at 0x11a66c2c8>,
#  <Element 'clinical_study' at 0x11a672c78>,
#  <Element 'clinical_study' at 0x11a680db8>,
#  <Element 'clinical_study' at 0x11a68f318>,
#  <Element 'clinical_study' at 0x11a6987c8>,
#  <Element 'clinical_study' at 0x11a6a9ae8>,
#  <Element 'clinical_study' at 0x11a6b1bd8>,
#  <Element 'clinical_study' at 0x11a6c9bd8>,
#  <Element 'clinical_study' at 0x11a6df0e8>,
#  <Element 'clinical_study' at 0x11a6e72c8>,
#  <Element 'clinical_study' at 0x11a6f1318>,
#  <Element 'clinical_study' at 0x11a6fb548>,
#  <Element 'clinical_study' at 0x11a7066d8>,
#  <Element 'clinical_study' at 0x11a70ddb8>,
#  <Element 'clinical_study' at 0x11a71f2c8>,
#  <Element 'clinical_study' at 0x11a72a638>,
#  <Element 'clinical_study' at 0x11a7314f8>,
#  <Element 'clinical_study' at 0x11a73c8b8>,
#  <Element 'clinical_study' at 0x11a740ef8>,
#  <Element 'clinical_study' at 0x11a7515e8>,
#  <Element 'clinical_study' at 0x11a75b688>,
#  <Element 'clinical_study' at 0x11a762228>,
#  <Element 'clinical_study' at 0x11a76d688>,
#  <Element 'clinical_study' at 0x11a77d548>,
#  <Element 'clinical_study' at 0x11a78b4a8>,
#  <Element 'clinical_study' at 0x11a794a48>,
#  <Element 'clinical_study' at 0x11a7a52c8>,
#  <Element 'clinical_study' at 0x11a7ae368>,
#  <Element 'clinical_study' at 0x11a7babd8>,
#  <Element 'clinical_study' at 0x11a7cb908>,
#  <Element 'clinical_study' at 0x11a7dc278>,
#  <Element 'clinical_study' at 0x11a7e4228>,
#  <Element 'clinical_study' at 0x11a7f1368>,
#  <Element 'clinical_study' at 0x11a7fe598>,
#  <Element 'clinical_study' at 0x11a82fe58>,
#  <Element 'clinical_study' at 0x11a934818>,
#  <Element 'clinical_study' at 0x11a93e9f8>,
#  <Element 'clinical_study' at 0x11a9910e8>,
#  <Element 'clinical_study' at 0x11a99a2c8>,
#  <Element 'clinical_study' at 0x11a9a4b38>,
#  <Element 'clinical_study' at 0x11a9c2278>,
#  <Element 'clinical_study' at 0x11a9e4e58>,
#  <Element 'clinical_study' at 0x11a9f7958>,
#  <Element 'clinical_study' at 0x11a9fe728>,
#  <Element 'clinical_study' at 0x11aa25638>,
#  <Element 'clinical_study' at 0x11aa2fe08>,
#  <Element 'clinical_study' at 0x11aa3ae08>,
#  <Element 'clinical_study' at 0x11aa42958>,
#  <Element 'clinical_study' at 0x11aa566d8>,
#  <Element 'clinical_study' at 0x11aa64958>,
#  <Element 'clinical_study' at 0x11aa7e9a8>,
#  <Element 'clinical_study' at 0x11aa86e58>,
#  <Element 'clinical_study' at 0x11aafb2c8>,
#  <Element 'clinical_study' at 0x11aaffd18>,
#  <Element 'clinical_study' at 0x11ab14728>,
#  <Element 'clinical_study' at 0x11ab1cb88>,
#  <Element 'clinical_study' at 0x11ab2f4a8>,
#  <Element 'clinical_study' at 0x11ab36728>,
#  <Element 'clinical_study' at 0x11ab3cef8>,
#  <Element 'clinical_study' at 0x11ab4a7c8>,
#  <Element 'clinical_study' at 0x11ab53818>,
#  <Element 'clinical_study' at 0x11ab5e9f8>,
#  <Element 'clinical_study' at 0x11ab68b88>,
#  <Element 'clinical_study' at 0x11ab7b1d8>,
#  <Element 'clinical_study' at 0x11abd64f8>,
#  <Element 'clinical_study' at 0x11abe1098>,
#  <Element 'clinical_study' at 0x11abeec28>,
#  <Element 'clinical_study' at 0x11abfe098>,
#  <Element 'clinical_study' at 0x11ac052c8>,
#  <Element 'clinical_study' at 0x11ac10d68>,
#  <Element 'clinical_study' at 0x11ac19c28>,
#  <Element 'clinical_study' at 0x11ac99cc8>,
#  <Element 'clinical_study' at 0x11aca3e58>,
#  <Element 'clinical_study' at 0x11acb1818>,
#  <Element 'clinical_study' at 0x11acc6098>,
#  <Element 'clinical_study' at 0x11acce548>,
#  <Element 'clinical_study' at 0x11acd2ef8>,
#  <Element 'clinical_study' at 0x11adbf2c8>,
#  <Element 'clinical_study' at 0x11adc6f48>,
#  <Element 'clinical_study' at 0x11ae03ea8>,
#  <Element 'clinical_study' at 0x11ae0f4f8>,
#  <Element 'clinical_study' at 0x11ae1b138>,
#  <Element 'clinical_study' at 0x11ae21d18>,
#  <Element 'clinical_study' at 0x11ae2df98>,
#  <Element 'clinical_study' at 0x11ae43598>,
#  <Element 'clinical_study' at 0x11ae4ee08>,
#  <Element 'clinical_study' at 0x11ae58a48>,
#  <Element 'clinical_study' at 0x11ae704a8>,
#  <Element 'clinical_study' at 0x11ae79f98>,
#  <Element 'clinical_study' at 0x11ae8e598>,
#  <Element 'clinical_study' at 0x11ae9f318>,
#  <Element 'clinical_study' at 0x11aeaf228>,
#  <Element 'clinical_study' at 0x11aebf688>,
#  <Element 'clinical_study' at 0x11aecf0e8>,
#  <Element 'clinical_study' at 0x11aed3cc8>,
#  <Element 'clinical_study' at 0x11aedd5e8>,
#  <Element 'clinical_study' at 0x11aeef2c8>,
#  <Element 'clinical_study' at 0x11aeffa98>,
#  <Element 'clinical_study' at 0x11af08ae8>,
#  <Element 'clinical_study' at 0x11af1b958>,
#  <Element 'clinical_study' at 0x11af23b38>,
#  <Element 'clinical_study' at 0x11af5d458>,
#  <Element 'clinical_study' at 0x11af62f98>,
#  <Element 'clinical_study' at 0x11af7d728>,
#  <Element 'clinical_study' at 0x11af85d18>,
#  <Element 'clinical_study' at 0x11af98598>,
#  <Element 'clinical_study' at 0x11afa2688>,
#  <Element 'clinical_study' at 0x11afa7f98>,
#  <Element 'clinical_study' at 0x11afbdf48>,
#  <Element 'clinical_study' at 0x11aff2cc8>,
#  <Element 'clinical_study' at 0x11b004f48>,
#  <Element 'clinical_study' at 0x11b018598>,
#  <Element 'clinical_study' at 0x11b020368>,
#  <Element 'clinical_study' at 0x11b02a0e8>,
#  <Element 'clinical_study' at 0x11b03abd8>,
#  <Element 'clinical_study' at 0x11b04be08>,
#  <Element 'clinical_study' at 0x11b055b38>,
#  <Element 'clinical_study' at 0x11b060688>,
#  <Element 'clinical_study' at 0x11b073098>,
#  <Element 'clinical_study' at 0x11b07ca98>,
#  <Element 'clinical_study' at 0x11b088048>,
#  <Element 'clinical_study' at 0x11b096408>,
#  <Element 'clinical_study' at 0x11b0a7048>,
#  <Element 'clinical_study' at 0x11b0bc598>,
#  <Element 'clinical_study' at 0x11b0c4868>,
#  <Element 'clinical_study' at 0x11b0d4318>,
#  <Element 'clinical_study' at 0x11b0e9d18>,
#  <Element 'clinical_study' at 0x11b0f3e08>,
#  <Element 'clinical_study' at 0x11b102958>,
#  <Element 'clinical_study' at 0x11b10f138>,
#  <Element 'clinical_study' at 0x11b119a98>,
#  <Element 'clinical_study' at 0x11b124228>,
#  <Element 'clinical_study' at 0x11b142098>,
#  <Element 'clinical_study' at 0x11b1488b8>,
#  <Element 'clinical_study' at 0x11b192818>,
#  <Element 'clinical_study' at 0x11b1f8188>,
#  <Element 'clinical_study' at 0x11b20d9f8>,
#  <Element 'clinical_study' at 0x11b216a98>,
#  <Element 'clinical_study' at 0x11b22b9f8>,
#  <Element 'clinical_study' at 0x11b23c228>,
#  <Element 'clinical_study' at 0x11b2520e8>,
#  <Element 'clinical_study' at 0x11b27abd8>,
#  <Element 'clinical_study' at 0x11b2880e8>,
#  <Element 'clinical_study' at 0x11b28dae8>,
#  <Element 'clinical_study' at 0x11b2a4368>,
#  <Element 'clinical_study' at 0x11b2ae048>,
#  <Element 'clinical_study' at 0x11b2e73b8>,
#  <Element 'clinical_study' at 0x11b2f0ea8>,
#  <Element 'clinical_study' at 0x11b3001d8>,
#  <Element 'clinical_study' at 0x11b3089a8>,
#  <Element 'clinical_study' at 0x11b3171d8>,
#  <Element 'clinical_study' at 0x11b32d688>,
#  <Element 'clinical_study' at 0x11b3394f8>,
#  <Element 'clinical_study' at 0x11b343a98>,
#  <Element 'clinical_study' at 0x11b351a48>,
#  <Element 'clinical_study' at 0x11b35ce58>,
#  <Element 'clinical_study' at 0x11b3638b8>,
#  <Element 'clinical_study' at 0x11b378cc8>,
#  <Element 'clinical_study' at 0x11b3c33b8>,
#  <Element 'clinical_study' at 0x11b3cc2c8>,
#  <Element 'clinical_study' at 0x11b440b88>,
#  <Element 'clinical_study' at 0x11b44a868>,
#  <Element 'clinical_study' at 0x11b45d048>,
#  <Element 'clinical_study' at 0x11b480e08>,
#  <Element 'clinical_study' at 0x11b490ae8>,
#  <Element 'clinical_study' at 0x11b4a5548>,
#  <Element 'clinical_study' at 0x11b4b4098>,
#  <Element 'clinical_study' at 0x11b4c0c78>,
#  <Element 'clinical_study' at 0x11b4c8d68>,
#  <Element 'clinical_study' at 0x11b4e5b88>,
#  <Element 'clinical_study' at 0x11b4f39a8>,
#  <Element 'clinical_study' at 0x11b532bd8>,
#  <Element 'clinical_study' at 0x11b542b38>,
#  <Element 'clinical_study' at 0x11b54ca48>,
#  <Element 'clinical_study' at 0x11b55b7c8>,
#  <Element 'clinical_study' at 0x11b565408>,
#  <Element 'clinical_study' at 0x11b56db38>,
#  <Element 'clinical_study' at 0x11b576b38>,
#  <Element 'clinical_study' at 0x11b585e58>,
#  <Element 'clinical_study' at 0x11b595c28>,
#  <Element 'clinical_study' at 0x11b5aa5e8>,
#  <Element 'clinical_study' at 0x11b5b5778>,
#  <Element 'clinical_study' at 0x11b649728>,
#  <Element 'clinical_study' at 0x11b6551d8>,
#  <Element 'clinical_study' at 0x11b66b598>,
#  <Element 'clinical_study' at 0x11b678278>,
#  <Element 'clinical_study' at 0x11b6850e8>,
#  <Element 'clinical_study' at 0x11b6a3318>,
#  <Element 'clinical_study' at 0x11b6af598>,
#  <Element 'clinical_study' at 0x11b6bb3b8>,
#  <Element 'clinical_study' at 0x11b6c3ef8>,
#  <Element 'clinical_study' at 0x11b6d15e8>,
#  <Element 'clinical_study' at 0x11b6e19f8>,
#  <Element 'clinical_study' at 0x11b6e9868>,
#  <Element 'clinical_study' at 0x11b6f3f98>,
#  <Element 'clinical_study' at 0x11b842138>,
#  <Element 'clinical_study' at 0x11b84c188>,
#  <Element 'clinical_study' at 0x11b877098>,
#  <Element 'clinical_study' at 0x11b882458>,
#  <Element 'clinical_study' at 0x11b88d598>,
#  <Element 'clinical_study' at 0x11b89e048>,
#  <Element 'clinical_study' at 0x11b948048>,
#  <Element 'clinical_study' at 0x11b9544a8>,
#  <Element 'clinical_study' at 0x11b95e318>,
#  <Element 'clinical_study' at 0x11b96b228>,
#  <Element 'clinical_study' at 0x11ba03098>,
#  <Element 'clinical_study' at 0x11ba9bc28>,
#  <Element 'clinical_study' at 0x11baaddb8>,
#  <Element 'clinical_study' at 0x11bad5598>,
#  <Element 'clinical_study' at 0x11bae1958>,
#  <Element 'clinical_study' at 0x11bae9638>,
#  <Element 'clinical_study' at 0x11bced318>,
#  <Element 'clinical_study' at 0x11bcf7688>,
#  <Element 'clinical_study' at 0x11bd0f868>,
#  <Element 'clinical_study' at 0x11bd23d18>,
#  <Element 'clinical_study' at 0x11bd2ef48>,
#  <Element 'clinical_study' at 0x11bd41188>,
#  <Element 'clinical_study' at 0x11bd52908>,
#  <Element 'clinical_study' at 0x11bd67cc8>,
#  <Element 'clinical_study' at 0x11bd72c28>,
#  <Element 'clinical_study' at 0x11bdc5368>,
#  <Element 'clinical_study' at 0x11bdd4048>,
#  <Element 'clinical_study' at 0x11bdfe188>,
#  <Element 'clinical_study' at 0x11be06368>,
#  <Element 'clinical_study' at 0x11be10d18>,
#  <Element 'clinical_study' at 0x11be20228>,
#  <Element 'clinical_study' at 0x11be2b8b8>,
#  <Element 'clinical_study' at 0x11be3be08>,
#  <Element 'clinical_study' at 0x11be49d68>,
#  <Element 'clinical_study' at 0x11be52d68>,
#  <Element 'clinical_study' at 0x11be68408>,
#  <Element 'clinical_study' at 0x11be6cd68>,
#  <Element 'clinical_study' at 0x11be7a048>,
#  <Element 'clinical_study' at 0x11beb9138>,
#  <Element 'clinical_study' at 0x11bee7368>,
#  <Element 'clinical_study' at 0x11bef2728>,
#  <Element 'clinical_study' at 0x11befa5e8>,
#  <Element 'clinical_study' at 0x11bf0b688>,
#  <Element 'clinical_study' at 0x11bf16048>,
#  <Element 'clinical_study' at 0x11bf25368>,
#  <Element 'clinical_study' at 0x11bf2ea98>,
#  <Element 'clinical_study' at 0x11bf35a48>,
#  <Element 'clinical_study' at 0x11bf49458>,
#  <Element 'clinical_study' at 0x11c2aaef8>,
#  <Element 'clinical_study' at 0x11c2b59f8>,
#  <Element 'clinical_study' at 0x11c2c4ea8>,
#  <Element 'clinical_study' at 0x11c2cf598>,
#  <Element 'clinical_study' at 0x11c2db9f8>,
#  <Element 'clinical_study' at 0x11c2f3228>,
#  <Element 'clinical_study' at 0x11c2f8d18>,
#  <Element 'clinical_study' at 0x11c302d18>,
#  <Element 'clinical_study' at 0x11c325548>,
#  <Element 'clinical_study' at 0x11c332958>,
#  <Element 'clinical_study' at 0x11c33a548>,
#  <Element 'clinical_study' at 0x11c3469a8>,
#  <Element 'clinical_study' at 0x11c3567c8>,
#  <Element 'clinical_study' at 0x11c368778>,
#  <Element 'clinical_study' at 0x11c370f98>,
#  <Element 'clinical_study' at 0x11c380228>,
#  <Element 'clinical_study' at 0x11c39bb88>,
#  <Element 'clinical_study' at 0x11c3a4c78>,
#  <Element 'clinical_study' at 0x11c3b4e58>,
#  <Element 'clinical_study' at 0x11c3c74a8>,
#  <Element 'clinical_study' at 0x11c3e3e08>,
#  <Element 'clinical_study' at 0x11c3f7688>,
#  <Element 'clinical_study' at 0x11c4045e8>,
#  <Element 'clinical_study' at 0x11c42b3b8>,
#  <Element 'clinical_study' at 0x11c4364f8>,
#  <Element 'clinical_study' at 0x11c43aae8>,
#  <Element 'clinical_study' at 0x11c444688>,
#  <Element 'clinical_study' at 0x11c44e278>,
#  <Element 'clinical_study' at 0x11c458e58>,
#  <Element 'clinical_study' at 0x11c484f98>,
#  <Element 'clinical_study' at 0x11c4934f8>,
#  <Element 'clinical_study' at 0x11c49e408>,
#  <Element 'clinical_study' at 0x11c4ad638>,
#  <Element 'clinical_study' at 0x11c4c96d8>,
#  <Element 'clinical_study' at 0x11c4d2e58>,
#  <Element 'clinical_study' at 0x11c4dfb88>,
#  <Element 'clinical_study' at 0x11c4eaae8>,
#  <Element 'clinical_study' at 0x11c537188>,
#  <Element 'clinical_study' at 0x11c541818>,
#  <Element 'clinical_study' at 0x11c54b228>,
#  <Element 'clinical_study' at 0x11c557ae8>,
#  <Element 'clinical_study' at 0x11c575278>,
#  <Element 'clinical_study' at 0x11c58f318>,
#  <Element 'clinical_study' at 0x11c598ea8>,
#  <Element 'clinical_study' at 0x11c5da548>,
#  <Element 'clinical_study' at 0x11c612688>,
#  <Element 'clinical_study' at 0x11c62a408>,
#  <Element 'clinical_study' at 0x11c633b88>,
#  <Element 'clinical_study' at 0x11c63b868>,
#  <Element 'clinical_study' at 0x11c6487c8>,
#  <Element 'clinical_study' at 0x11c6574a8>,
#  <Element 'clinical_study' at 0x11c659ea8>,
#  <Element 'clinical_study' at 0x11c669ea8>,
#  <Element 'clinical_study' at 0x11c67def8>,
#  <Element 'clinical_study' at 0x11c689a98>,
#  <Element 'clinical_study' at 0x11c6b4b38>,
#  <Element 'clinical_study' at 0x11c6bca48>,
#  <Element 'clinical_study' at 0x11c70ebd8>,
#  <Element 'clinical_study' at 0x11c717c28>,
#  <Element 'clinical_study' at 0x11c72a318>,
#  <Element 'clinical_study' at 0x11c73b9f8>,
#  <Element 'clinical_study' at 0x11c74c4f8>,
#  <Element 'clinical_study' at 0x11c75dc78>]

# %%
print(len(all_parsed_files))

# %% [markdown]
# ## Extract tags from parsed trials

# %%
# Dictionary to hold all data
all_data_dictionary = {}

# Final json file
json_file = '/all_trials_json' #name json file  

print('\nCreated dictionary and path to json file\n')

# %% [markdown]
# ### Parse tags in files

# %%
'''
Find values by unique tags in XML files 
Save them in a dictionary 
Export them to a json file
'''

def create_dictionary_from_tag(tag, parsed_files = all_parsed_files, name_dictionary = all_data_dictionary):
    
    # Variable to store values
    keys = []
    values = []
    
    # Iterate through all xml parsed files and tags, and append data to values
    for n in parsed_files:
        for i in n.iter(tag):
            if i.text != 0:
                values.append(i.text)
            else:
                values.append('nan') #get values
                # Checking message to the terminal
            print("{} file parsed\n".format(i.text))
    
    # Create dictionary and set tags as keys
    name_dictionary.setdefault(tag, [])
    
    # Append values to dictionary
    for i in values:
        name_dictionary[tag].append(i)
        print("{} file added to the dictionary\n".format(i))
        
        
# Execute function only with unique values
# %time create_dictionary_from_tag('nct_id')
# %time create_dictionary_from_tag('study_first_submitted')
# %time create_dictionary_from_tag('source')
# %time create_dictionary_from_tag('brief_title')

print('Dictionary created')

# %%
'''
Check number of values for each key before creating a dataframe
'''

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))

# %%
# Function for adding new tag

def add_new_tags(new_key):
    all_data_dictionary.setdefault(new_key, [])

    for n in all_parsed_files:
            value_conditions = n.find(new_key)
            if n.find(new_key) is not None:
                all_data_dictionary[new_key].append(value_conditions.text)
            else:
                all_data_dictionary[new_key].append('None')

    print('{} tag added'.format(new_key))

# %%
add_new_tags('condition')
add_new_tags('detailed_description/textblock')
add_new_tags('brief_summary/textblock')

# %%
'''
Check keys and number of values for each one
'''

print(all_data_dictionary.keys())

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))

# %% [markdown]
# ## Dump results in a json file

# %%
# Dump dictionary into a JSON file
with open('{}{}.json'.format(path_to_json_file, json_file), 'w') as fp:
    json.dump(all_data_dictionary, fp)
    print('\nJSON file created\n')

    json_size = round(os.path.getsize(path_to_json_file + json_file + '.json') / 1000000, 2)
    print("JSON file: {} Mb".format(json_size))

# %% [markdown]
# ## Import json file in a dataframe

# %%
# Import json into a dataframe
file = '{}{}.json'.format(path_to_json_file, json_file)

df = pd.read_json(file)

# %%
df.head()
# Out:
#         nct_id study_first_submitted                          source  \
# 0  NCT02776787           May 5, 2016        University of Washington
# 1  NCT00797472     November 24, 2008  American Scitech International
# 2  NCT03499821         April 9, 2018          Staar Surgical Company
# 3  NCT01224028      October 18, 2010             Astellas Pharma Inc
# 4  NCT02279680         June 23, 2014       University Hospital, Caen
#
#                                          brief_title          condition  \
# 0  DEBUT: Diverticulitis Evaluation of Patient Bu...     Diverticulitis
# 1  Study Comparing R-mabHD and a Combination of A...  Hodgkin's Disease
# 2  Clinical Performance of a Phakic Intraocular L...         Presbyopia
# 3  A Study to Evaluate the Efficacy and Safety of...    IgA Nephropathy
# 4  Associative Memory in Adults With an Autism Sp...  Autistic Disorder
#
#                       detailed_description/textblock  \
# 0  \n      This study will examine both clinical ...
# 1  \n      The primary objective is to compare th...
# 2  \n      This is a prospective, open-labeled, m...
# 3                                               None
# 4                                               None
#
#                              brief_summary/textblock
# 0  \n      Half of all Americans over 60 years of...
# 1  \n      120 subjects with Hodgkin's disease wi...
# 2  \n      This study will evaluate the clinical ...
# 3  \n      This study is to evaluate efficacy and...
# 4  \n      The objective of this multidisciplinar...

# %%
# rename columns & delete \n values

# %%
df['detailed_description/textblock'][0]
# Out:
# "\n      This study will examine both clinical and non-clinical reasons for pursuing surgery, taking\n      into account previously unexplored areas in surgical decision-making including the\n      comprehensive impact of this disease, as well as factors that impact a surgeon's willingness\n      to recommend surgery. Ultimately, this patient-centered research approach will help us\n      understand the impact of treatment decisions on a patient's quality of life, work, and\n      clinical symptoms, and will ultimately help to inform our recommendations for the treatment\n      of patients with diverticulitis.\n\n      The DEBUT study was developed from questions raised by our Washington State Surgical\n      Collaborative, (SCOAP Colon and Rectal Surgery Work Group) and will be carried out in clinics\n      and hospitals across Washington State, Oregon, and California. The investigators invite\n      patients to participate in research activities designed to identify the impact of\n      diverticulitis and treatment options, in order to better understand the outcomes that matter\n      most to patients. Patients who are considering surgery or who have received treatment for\n      their diverticulitis will be recruited for study participation. Participants will complete a\n      baseline survey via a convenient electronic platform, and follow-up surveys will be sent\n      quarterly for up to four years. These surveys will examine quality of life, overall health,\n      and clinical symptoms to understand what drives patients and surgeons to an operation, as\n      well as how that decision impacts quality of life and recurrent events in patients that\n      choose to have surgery compared to those that do not have surgery. Participating surgeons\n      will complete surveys that examine their indications for surgery and surgical outcomes.\n    "

# %%
# Create a new column: study_first_submitted as dates

df['dates'] = pd.to_datetime(df['study_first_submitted'])

# %%
df.head()
# Out:
#         nct_id study_first_submitted                          source  \
# 0  NCT02776787           May 5, 2016        University of Washington
# 1  NCT00797472     November 24, 2008  American Scitech International
# 2  NCT03499821         April 9, 2018          Staar Surgical Company
# 3  NCT01224028      October 18, 2010             Astellas Pharma Inc
# 4  NCT02279680         June 23, 2014       University Hospital, Caen
#
#                                          brief_title          condition  \
# 0  DEBUT: Diverticulitis Evaluation of Patient Bu...     Diverticulitis
# 1  Study Comparing R-mabHD and a Combination of A...  Hodgkin's Disease
# 2  Clinical Performance of a Phakic Intraocular L...         Presbyopia
# 3  A Study to Evaluate the Efficacy and Safety of...    IgA Nephropathy
# 4  Associative Memory in Adults With an Autism Sp...  Autistic Disorder
#
#                       detailed_description/textblock  \
# 0  \n      This study will examine both clinical ...
# 1  \n      The primary objective is to compare th...
# 2  \n      This is a prospective, open-labeled, m...
# 3                                               None
# 4                                               None
#
#                              brief_summary/textblock      dates
# 0  \n      Half of all Americans over 60 years of... 2016-05-05
# 1  \n      120 subjects with Hodgkin's disease wi... 2008-11-24
# 2  \n      This study will evaluate the clinical ... 2018-04-09
# 3  \n      This study is to evaluate efficacy and... 2010-10-18
# 4  \n      The objective of this multidisciplinar... 2014-06-23
