# %% [markdown]
# # Clinical trials: Parse all XML files

# %%
#Data: clinicaltrials.gov

# %%
# reset variables and turn off autosave
# %reset
# %autosave 0
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?
# Nothing done.
# Autosave disabled

# %%
import zipfile
import sys
import time
import json
import re
import os
import xml.etree.ElementTree as ET
import shutil
import pandas as pd
from collections import Counter

# %%
# Print messages to the terminal

# sys.stdout = open('/dev/stdout', 'w')

# %% [markdown]
# ## Setup: create paths and folders

# %%
'''
Create paths and folders
'''

# Folders with xml files
path_to_all_xml_trials = os.path.abspath('../data/all_trials/')

# Test folder ~100 files
path_to_test_folder = os.path.abspath('../data/test/')

#Remove old files from test folder
try:
    shutil.rmtree(path_to_test_folder) 
except FileNotFoundError:
    pass

# Path for json folder
path_to_json_file = os.path.abspath('../data/json/')

# Variable for all parsed files
all_parsed_files = []

print('\nPaths and folders created\n')
# Out:
# Paths and folders created

# %%
# Create folders

create_folders_errors = []

def create_folders(paths=[]):
    for p in paths:
        try:
            os.mkdir(p)
            if p:
                print('{} created'.format(p))
        except IOError as e:
            create_folders_errors.append(e)
            pass

    print('\nSetup folders created with exceptions: {}\n'.format(create_folders_errors))
    
all_folders = [path_to_all_xml_trials, path_to_test_folder, path_to_json_file]
    
# create folders
create_folders(all_folders)
# Out:
# /Users/cmserna/Sites/clinical trials/mvp/data/test created
#
# Setup folders created with exceptions: [FileExistsError(17, 'File exists'), FileExistsError(17, 'File exists')]

# %% [markdown]
# ### Create test folder with n random files

# %%
'''
Select n random files from all trials and save them in test folder
'''
files_for_test = 50

import random

# Pending: If files in test folder, delete them
random_files = []
random_files = random.sample(os.listdir(path_to_all_xml_trials), files_for_test)
print('Random files: {}'.format(len(random_files)))

for f in random_files:
    src = os.path.join(path_to_all_xml_trials, f)
    shutil.copy(src, path_to_test_folder)
# Out:
# Random files: 50

# %%
print(random_files[0:5])
# Out:
# ['NCT03717584.xml', 'NCT02796625.xml', 'NCT03531125.xml', 'NCT02405351.xml', 'NCT00038025.xml']

# %% [markdown]
# ## Parse xml files

# %%
'''
Parse all xml files and save them in a all_parsed_files variable.
Slow. Checks for xml files
'''

def parse_xml_files(path_to_folder):
    for filename in os.listdir(path_to_folder):
#         if not filename.endswith('.xml'): continue
        fullname = os.path.join(path_to_folder, filename)
        all_parsed_files.append(ET.parse(fullname).getroot())
        
        # Checking message to the terminal
        print("{} file parsed\n".format(fullname))

    print('Number of files parsed: {}\n'.format(len(all_parsed_files)))
        
    return all_parsed_files

# %%
# Run function
all_parsed_files.clear()
# %time parse_xml_files(path_to_test_folder)
# Out:
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02750033.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01587092.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01813695.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03647059.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00038025.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00976976.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02946996.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00934011.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03377725.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03559907.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02178631.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00677040.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00781729.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00954928.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00740415.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03623347.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00023504.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03745404.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03418181.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03651713.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00002734.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01916772.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03717584.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02796625.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03531125.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02667756.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01265745.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01289301.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00253292.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03614078.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02862392.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03494946.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03608527.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02405351.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02506894.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT01267045.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03348436.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03364725.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02430012.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00919711.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03588338.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02370485.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00711191.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00646581.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT03094247.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00631046.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02981134.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00011284.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT02653287.xml file parsed
#
# /Users/cmserna/Sites/clinical trials/mvp/data/test/NCT00854763.xml file parsed
#
# Number of files parsed: 50
#
# CPU times: user 53.4 ms, sys: 10.6 ms, total: 64 ms
# Wall time: 58.5 ms
# [<Element 'clinical_study' at 0x1167d36d8>,
#  <Element 'clinical_study' at 0x1167e20e8>,
#  <Element 'clinical_study' at 0x1167ec098>,
#  <Element 'clinical_study' at 0x1167d3688>,
#  <Element 'clinical_study' at 0x1175d49f8>,
#  <Element 'clinical_study' at 0x1175dd048>,
#  <Element 'clinical_study' at 0x1175e1f98>,
#  <Element 'clinical_study' at 0x1175ee138>,
#  <Element 'clinical_study' at 0x1175f9688>,
#  <Element 'clinical_study' at 0x1177894a8>,
#  <Element 'clinical_study' at 0x117790a48>,
#  <Element 'clinical_study' at 0x11779a548>,
#  <Element 'clinical_study' at 0x1177be8b8>,
#  <Element 'clinical_study' at 0x1177c7ae8>,
#  <Element 'clinical_study' at 0x10c698e58>,
#  <Element 'clinical_study' at 0x10c6aa8b8>,
#  <Element 'clinical_study' at 0x10c6b6688>,
#  <Element 'clinical_study' at 0x10c6c1408>,
#  <Element 'clinical_study' at 0x116d729a8>,
#  <Element 'clinical_study' at 0x116d81868>,
#  <Element 'clinical_study' at 0x116d97368>,
#  <Element 'clinical_study' at 0x116da4b38>,
#  <Element 'clinical_study' at 0x116e8ef48>,
#  <Element 'clinical_study' at 0x116ea0778>,
#  <Element 'clinical_study' at 0x116ea9818>,
#  <Element 'clinical_study' at 0x116eb6598>,
#  <Element 'clinical_study' at 0x116ec4138>,
#  <Element 'clinical_study' at 0x116ece6d8>,
#  <Element 'clinical_study' at 0x116ee2f48>,
#  <Element 'clinical_study' at 0x116eef958>,
#  <Element 'clinical_study' at 0x116deb4a8>,
#  <Element 'clinical_study' at 0x116e01b88>,
#  <Element 'clinical_study' at 0x116e0f9a8>,
#  <Element 'clinical_study' at 0x116e19c78>,
#  <Element 'clinical_study' at 0x1174309f8>,
#  <Element 'clinical_study' at 0x11743cc78>,
#  <Element 'clinical_study' at 0x117713818>,
#  <Element 'clinical_study' at 0x1177219f8>,
#  <Element 'clinical_study' at 0x11772f6d8>,
#  <Element 'clinical_study' at 0x117741778>,
#  <Element 'clinical_study' at 0x10c0791d8>,
#  <Element 'clinical_study' at 0x10c0848b8>,
#  <Element 'clinical_study' at 0x10c08e958>,
#  <Element 'clinical_study' at 0x116c1dc78>,
#  <Element 'clinical_study' at 0x116c52ea8>,
#  <Element 'clinical_study' at 0x116c66958>,
#  <Element 'clinical_study' at 0x116c74908>,
#  <Element 'clinical_study' at 0x116c82138>,
#  <Element 'clinical_study' at 0x116c87598>,
#  <Element 'clinical_study' at 0x116c97a48>]

# %%
print(len(all_parsed_files))
# Out:
# 50

# %% [markdown]
# ## Extract tags from parsed trials

# %%
# Dictionary to hold all data
all_data_dictionary = {}

# Final json file
json_file = '/all_trials_json' #name json file  

print('\nCreated dictionary and path to json file\n')
# Out:
# Created dictionary and path to json file

# %% [markdown]
# ### Parse tags in files

# %%
'''
Find values by unique tags in XML files 
Save them in a dictionary 
Export them to a json file
'''

def create_dictionary_from_tag(tag, parsed_files = all_parsed_files, name_dictionary = all_data_dictionary):
    
    # Variable to store values
    keys = []
    values = []
    
    # Iterate through all xml parsed files and tags, and append data to values
    for n in parsed_files:
        for i in n.iter(tag):
            if i.text != 0:
                values.append(i.text)
            else:
                values.append('nan') #get values
                # Checking message to the terminal
            print("{} file parsed\n".format(i.text))
    
    # Create dictionary and set tags as keys
    name_dictionary.setdefault(tag, [])
    
    # Append values to dictionary
    for i in values:
        name_dictionary[tag].append(i)
        print("{} file added to the dictionary\n".format(i))
        
        
# Execute function only with unique values
# %time create_dictionary_from_tag('nct_id')
# %time create_dictionary_from_tag('study_first_submitted')
# %time create_dictionary_from_tag('source')
# %time create_dictionary_from_tag('brief_title')

print('Dictionary created')
# Out:
# NCT02750033 file parsed
#
# NCT01587092 file parsed
#
# NCT01813695 file parsed
#
# NCT03647059 file parsed
#
# NCT00038025 file parsed
#
# NCT00976976 file parsed
#
# NCT02946996 file parsed
#
# NCT00934011 file parsed
#
# NCT03377725 file parsed
#
# NCT03559907 file parsed
#
# NCT02178631 file parsed
#
# NCT00677040 file parsed
#
# NCT00781729 file parsed
#
# NCT00954928 file parsed
#
# NCT00740415 file parsed
#
# NCT03623347 file parsed
#
# NCT00023504 file parsed
#
# NCT03745404 file parsed
#
# NCT03418181 file parsed
#
# NCT03651713 file parsed
#
# NCT00002734 file parsed
#
# NCT01916772 file parsed
#
# NCT03717584 file parsed
#
# NCT02796625 file parsed
#
# NCT03531125 file parsed
#
# NCT02667756 file parsed
#
# NCT01265745 file parsed
#
# NCT01289301 file parsed
#
# NCT00253292 file parsed
#
# NCT03614078 file parsed
#
# NCT02862392 file parsed
#
# NCT03494946 file parsed
#
# NCT03608527 file parsed
#
# NCT02405351 file parsed
#
# NCT02506894 file parsed
#
# NCT01267045 file parsed
#
# NCT03348436 file parsed
#
# NCT03364725 file parsed
#
# NCT02430012 file parsed
#
# NCT00919711 file parsed
#
# NCT03588338 file parsed
#
# NCT02370485 file parsed
#
# NCT00711191 file parsed
#
# NCT00646581 file parsed
#
# NCT03094247 file parsed
#
# NCT00631046 file parsed
#
# NCT02981134 file parsed
#
# NCT00011284 file parsed
#
# NCT02653287 file parsed
#
# NCT00854763 file parsed
#
# NCT02750033 file added to the dictionary
#
# NCT01587092 file added to the dictionary
#
# NCT01813695 file added to the dictionary
#
# NCT03647059 file added to the dictionary
#
# NCT00038025 file added to the dictionary
#
# NCT00976976 file added to the dictionary
#
# NCT02946996 file added to the dictionary
#
# NCT00934011 file added to the dictionary
#
# NCT03377725 file added to the dictionary
#
# NCT03559907 file added to the dictionary
#
# NCT02178631 file added to the dictionary
#
# NCT00677040 file added to the dictionary
#
# NCT00781729 file added to the dictionary
#
# NCT00954928 file added to the dictionary
#
# NCT00740415 file added to the dictionary
#
# NCT03623347 file added to the dictionary
#
# NCT00023504 file added to the dictionary
#
# NCT03745404 file added to the dictionary
#
# NCT03418181 file added to the dictionary
#
# NCT03651713 file added to the dictionary
#
# NCT00002734 file added to the dictionary
#
# NCT01916772 file added to the dictionary
#
# NCT03717584 file added to the dictionary
#
# NCT02796625 file added to the dictionary
#
# NCT03531125 file added to the dictionary
#
# NCT02667756 file added to the dictionary
#
# NCT01265745 file added to the dictionary
#
# NCT01289301 file added to the dictionary
#
# NCT00253292 file added to the dictionary
#
# NCT03614078 file added to the dictionary
#
# NCT02862392 file added to the dictionary
#
# NCT03494946 file added to the dictionary
#
# NCT03608527 file added to the dictionary
#
# NCT02405351 file added to the dictionary
#
# NCT02506894 file added to the dictionary
#
# NCT01267045 file added to the dictionary
#
# NCT03348436 file added to the dictionary
#
# NCT03364725 file added to the dictionary
#
# NCT02430012 file added to the dictionary
#
# NCT00919711 file added to the dictionary
#
# NCT03588338 file added to the dictionary
#
# NCT02370485 file added to the dictionary
#
# NCT00711191 file added to the dictionary
#
# NCT00646581 file added to the dictionary
#
# NCT03094247 file added to the dictionary
#
# NCT00631046 file added to the dictionary
#
# NCT02981134 file added to the dictionary
#
# NCT00011284 file added to the dictionary
#
# NCT02653287 file added to the dictionary
#
# NCT00854763 file added to the dictionary
#
# CPU times: user 2.76 ms, sys: 826 µs, total: 3.59 ms
# Wall time: 2.7 ms
# April 20, 2016 file parsed
#
# April 25, 2012 file parsed
#
# March 11, 2013 file parsed
#
# August 9, 2018 file parsed
#
# May 24, 2002 file parsed
#
# September 14, 2009 file parsed
#
# October 18, 2016 file parsed
#
# July 7, 2009 file parsed
#
# December 13, 2017 file parsed
#
# May 15, 2018 file parsed
#
# June 25, 2014 file parsed
#
# May 9, 2008 file parsed
#
# October 28, 2008 file parsed
#
# August 5, 2009 file parsed
#
# August 22, 2008 file parsed
#
# August 6, 2018 file parsed
#
# September 7, 2001 file parsed
#
# November 15, 2018 file parsed
#
# September 20, 2017 file parsed
#
# August 22, 2018 file parsed
#
# November 1, 1999 file parsed
#
# July 25, 2013 file parsed
#
# July 10, 2018 file parsed
#
# May 25, 2016 file parsed
#
# May 8, 2018 file parsed
#
# January 20, 2016 file parsed
#
# December 17, 2010 file parsed
#
# February 2, 2011 file parsed
#
# November 11, 2005 file parsed
#
# July 30, 2018 file parsed
#
# August 1, 2016 file parsed
#
# April 4, 2018 file parsed
#
# July 13, 2018 file parsed
#
# November 17, 2014 file parsed
#
# July 21, 2015 file parsed
#
# December 23, 2010 file parsed
#
# November 16, 2017 file parsed
#
# December 1, 2017 file parsed
#
# April 25, 2015 file parsed
#
# June 11, 2009 file parsed
#
# July 5, 2018 file parsed
#
# February 23, 2015 file parsed
#
# June 26, 2008 file parsed
#
# January 31, 2008 file parsed
#
# March 23, 2017 file parsed
#
# February 28, 2008 file parsed
#
# November 30, 2016 file parsed
#
# February 15, 2001 file parsed
#
# January 7, 2016 file parsed
#
# March 1, 2009 file parsed
#
# April 20, 2016 file added to the dictionary
#
# April 25, 2012 file added to the dictionary
#
# March 11, 2013 file added to the dictionary
#
# August 9, 2018 file added to the dictionary
#
# May 24, 2002 file added to the dictionary
#
# September 14, 2009 file added to the dictionary
#
# October 18, 2016 file added to the dictionary
#
# July 7, 2009 file added to the dictionary
#
# December 13, 2017 file added to the dictionary
#
# May 15, 2018 file added to the dictionary
#
# June 25, 2014 file added to the dictionary
#
# May 9, 2008 file added to the dictionary
#
# October 28, 2008 file added to the dictionary
#
# August 5, 2009 file added to the dictionary
#
# August 22, 2008 file added to the dictionary
#
# August 6, 2018 file added to the dictionary
#
# September 7, 2001 file added to the dictionary
#
# November 15, 2018 file added to the dictionary
#
# September 20, 2017 file added to the dictionary
#
# August 22, 2018 file added to the dictionary
#
# November 1, 1999 file added to the dictionary
#
# July 25, 2013 file added to the dictionary
#
# July 10, 2018 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 8, 2018 file added to the dictionary
#
# January 20, 2016 file added to the dictionary
#
# December 17, 2010 file added to the dictionary
#
# February 2, 2011 file added to the dictionary
#
# November 11, 2005 file added to the dictionary
#
# July 30, 2018 file added to the dictionary
#
# August 1, 2016 file added to the dictionary
#
# April 4, 2018 file added to the dictionary
#
# July 13, 2018 file added to the dictionary
#
# November 17, 2014 file added to the dictionary
#
# July 21, 2015 file added to the dictionary
#
# December 23, 2010 file added to the dictionary
#
# November 16, 2017 file added to the dictionary
#
# December 1, 2017 file added to the dictionary
#
# April 25, 2015 file added to the dictionary
#
# June 11, 2009 file added to the dictionary
#
# July 5, 2018 file added to the dictionary
#
# February 23, 2015 file added to the dictionary
#
# June 26, 2008 file added to the dictionary
#
# January 31, 2008 file added to the dictionary
#
# March 23, 2017 file added to the dictionary
#
# February 28, 2008 file added to the dictionary
#
# November 30, 2016 file added to the dictionary
#
# February 15, 2001 file added to the dictionary
#
# January 7, 2016 file added to the dictionary
#
# March 1, 2009 file added to the dictionary
#
# CPU times: user 2.55 ms, sys: 787 µs, total: 3.34 ms
# Wall time: 2.51 ms
# Seton Healthcare Family file parsed
#
# Pennington Biomedical Research Center file parsed
#
# Children's Hospital Medical Center, Cincinnati file parsed
#
# Shanghai General Hospital, Shanghai Jiao Tong University School of Medicine file parsed
#
# M.D. Anderson Cancer Center file parsed
#
# Asan Medical Center file parsed
#
# Medical University of South Carolina file parsed
#
# Federal University of Minas Gerais file parsed
#
# Ruijin Hospital file parsed
#
# University of Pittsburgh file parsed
#
# University of Luebeck file parsed
#
# Essentia Health file parsed
#
# Eunice Kennedy Shriver National Institute of Child Health and Human Development (NICHD) file parsed
#
# Washington University School of Medicine file parsed
#
# French Innovative Leukemia Organisation file parsed
#
# Centre Hospitalier Universitaire, Amiens file parsed
#
# National Institutes of Health Clinical Center (CC) file parsed
#
# Grünenthal GmbH file parsed
#
# East and North Hertfordshire NHS Trust file parsed
#
# University of Iowa file parsed
#
# National Cancer Institute (NCI) file parsed
#
# The Cleveland Clinic file parsed
#
# University of California, Davis file parsed
#
# University of Maryland Baltimore Dental School file parsed
#
# University of Oxford file parsed
#
# University of Oxford file parsed
#
# PharmAthene, Inc. file parsed
#
# Hannover Medical School file parsed
#
# Massachusetts General Hospital file parsed
#
# PRCL Research Inc. file parsed
#
# Lille Catholic University file parsed
#
# Oslo University Hospital file parsed
#
# Fondazione Italiana Sclerosi Multipla file parsed
#
# Nova Scotia Health Authority file parsed
#
# Cairo University file parsed
#
# VA Office of Research and Development file parsed
#
# The Second Hospital of Hebei Medical University file parsed
#
# Id Care file parsed
#
# China National Center for Cardiovascular Diseases file parsed
#
# Amgen file parsed
#
# Adnan Menderes University file parsed
#
# Eli Lilly and Company file parsed
#
# Hoffmann-La Roche file parsed
#
# University of Massachusetts, Worcester file parsed
#
# Washington University School of Medicine file parsed
#
# University of Copenhagen file parsed
#
# Asan Medical Center file parsed
#
# National Institute of Environmental Health Sciences (NIEHS) file parsed
#
# Northwestern University file parsed
#
# National Taiwan University Hospital file parsed
#
# Seton Healthcare Family file added to the dictionary
#
# Pennington Biomedical Research Center file added to the dictionary
#
# Children's Hospital Medical Center, Cincinnati file added to the dictionary
#
# Shanghai General Hospital, Shanghai Jiao Tong University School of Medicine file added to the dictionary
#
# M.D. Anderson Cancer Center file added to the dictionary
#
# Asan Medical Center file added to the dictionary
#
# Medical University of South Carolina file added to the dictionary
#
# Federal University of Minas Gerais file added to the dictionary
#
# Ruijin Hospital file added to the dictionary
#
# University of Pittsburgh file added to the dictionary
#
# University of Luebeck file added to the dictionary
#
# Essentia Health file added to the dictionary
#
# Eunice Kennedy Shriver National Institute of Child Health and Human Development (NICHD) file added to the dictionary
#
# Washington University School of Medicine file added to the dictionary
#
# French Innovative Leukemia Organisation file added to the dictionary
#
# Centre Hospitalier Universitaire, Amiens file added to the dictionary
#
# National Institutes of Health Clinical Center (CC) file added to the dictionary
#
# Grünenthal GmbH file added to the dictionary
#
# East and North Hertfordshire NHS Trust file added to the dictionary
#
# University of Iowa file added to the dictionary
#
# National Cancer Institute (NCI) file added to the dictionary
#
# The Cleveland Clinic file added to the dictionary
#
# University of California, Davis file added to the dictionary
#
# University of Maryland Baltimore Dental School file added to the dictionary
#
# University of Oxford file added to the dictionary
#
# University of Oxford file added to the dictionary
#
# PharmAthene, Inc. file added to the dictionary
#
# Hannover Medical School file added to the dictionary
#
# Massachusetts General Hospital file added to the dictionary
#
# PRCL Research Inc. file added to the dictionary
#
# Lille Catholic University file added to the dictionary
#
# Oslo University Hospital file added to the dictionary
#
# Fondazione Italiana Sclerosi Multipla file added to the dictionary
#
# Nova Scotia Health Authority file added to the dictionary
#
# Cairo University file added to the dictionary
#
# VA Office of Research and Development file added to the dictionary
#
# The Second Hospital of Hebei Medical University file added to the dictionary
#
# Id Care file added to the dictionary
#
# China National Center for Cardiovascular Diseases file added to the dictionary
#
# Amgen file added to the dictionary
#
# Adnan Menderes University file added to the dictionary
#
# Eli Lilly and Company file added to the dictionary
#
# Hoffmann-La Roche file added to the dictionary
#
# University of Massachusetts, Worcester file added to the dictionary
#
# Washington University School of Medicine file added to the dictionary
#
# University of Copenhagen file added to the dictionary
#
# Asan Medical Center file added to the dictionary
#
# National Institute of Environmental Health Sciences (NIEHS) file added to the dictionary
#
# Northwestern University file added to the dictionary
#
# National Taiwan University Hospital file added to the dictionary
#
# CPU times: user 3.67 ms, sys: 2.54 ms, total: 6.2 ms
# Wall time: 4.08 ms
# Intraoperative Margin Assessment During Mohs Surgery file parsed
#
# Workstation Pilot Study file parsed
#
# Preemptive Genotyping and Pain Management file parsed
#
# Rapid Assessment of Donor Liver Quality file parsed
#
# A Study Of Deoxycoformycin(DCF)/Pentostatin In Lymphoid Malignancies file parsed
#
# Adjuvant Chemotherapy With Docetaxel, Capecitabine and Cisplatin in Patients With Advanced Gastric Cancer file parsed
#
# Study of Pharmacologic Manipulation of AGE (Advanced Glycation Endproducts) Levels in Prostate Cancer Patients Receiving Androgen Deprivation Therapy file parsed
#
# Use of Inflammatory Biomarkers to Guide Antibiotic Therapy in Patients With Severe Infections file parsed
#
# Decitabine and Arsenic Trioxide for Myelodysplastic Syndrome(MDS) file parsed
#
# Partnering for Prevention: Building Healthy Habits in Underserved Communities file parsed
#
# Effectiveness of Internet-based Depression Treatment (EVIDENT) in Severe Depression file parsed
#
# Normal Tissue Oxygenation Following Radiotherapy file parsed
#
# Yoga for Kyphosis Trial file parsed
#
# The Safety of Hand Surgery in the Anticoagulated Patient file parsed
#
# Rituximab, Bortezomib,Bendamustine , Dexamethasone, Patients With Mantle Cell Lymphoma file parsed
#
# Upfront Bevacizumab/témozolomide for Gliomastomas With Neurological Impairment file parsed
#
# Antibody Production in Immune Disorders file parsed
#
# A Study With Lido-Patch and Placebo Plaster in Patients Suffering From Postherpetic Neuralgia (PHN) file parsed
#
# Does Incremental Initiation of Haemodialysis Preserve Native Kidney Function? file parsed
#
# Hyperglycemia, Exercise, and Endothelial Function file parsed
#
# Radiolabeled Monoclonal Antibody, Paclitaxel, and Interferon Alfa in Treating Patients With Recurrent Ovarian Cancer file parsed
#
# Natural History of Cherubism Observational Study file parsed
#
# A Cohort Study of the Intestinal Microbiota of Premature Infants file parsed
#
# Alpha as a Predictive Biomarker file parsed
#
# Gene Expression in Resectable Pancreatic Cancer file parsed
#
# Predicting Osteoarthritis Risk Following Knee Injury. file parsed
#
# Dose Escalation Study of Valortim® (MDX-1303) Administered Intravenously (IV) in Healthy, Normal Subjects file parsed
#
# Studying the Effect of Changing Immunosuppression in Case of Polyoma BK Virus Infection of the Renal Transplant file parsed
#
# Psychometric Study of Outcomes Instruments file parsed
#
# A Study of PRCL-02 in Moderate to Severe Chronic Plaque Psoriasis file parsed
#
# Predictive Progressive Factors of Adolescent Idiopathic Scoliosis file parsed
#
# Liver Transplantation Compared to Chemotherapy in Patients With ColoRectal Cancer file parsed
#
# Adaptive Plasticity Following Rehabilitation in Multiple Sclerosis file parsed
#
# Telerehabilitation for Attention and Memory in Stroke file parsed
#
# Fetal Middle Cerebral Artery Doppler in Preterm Births Receiving Magnesium Sulfate for Neuroprotection file parsed
#
# Mindfulness-Based Stress Reduction for Gulf War Syndrome file parsed
#
# Study on Left Atrial Function of Paroxysmal Supraventricular Tachycardia After Radiofrequency Ablation file parsed
#
# Toward Elimination of Hepatitis C Virus (HCV): A Pilot Study file parsed
#
# Quality Measurement and Improvement Study of Surgical Coronary Revascularization: Secondary Prevention file parsed
#
# Study to Evaluate the Safety and Efficacy of Denosumab and Actonel® in Post Menopausal Women Transitioned From Alendronate Therapy file parsed
#
# Paracetamol vs Metoclopramide on Postoperative Nausea and Vomiting file parsed
#
# A Study of LY2801653 in Healthy Participants Who Are Not Able to Have Children file parsed
#
# A Study On An Immunostimulant Antibody In Combination With Chemotherapy For Advanced Cancer Of The Pancreas file parsed
#
# Effect of Single Dose Intranasal Insulin On Cognitive Function file parsed
#
# Feeding Malnourished Children Different Types of Fatty Acids to Promote Neurocognitive Development file parsed
#
# Essential Fatty Acids During Complementary Feeding file parsed
#
# The Usefulness of Coronary CT Scan After Everolimus-eluting Bioabsorbable Scaffold Implantation for Coronary Artery Disease file parsed
#
# Mechanisms of Inflammatory Liver Injury file parsed
#
# Lupus Intervention for Fatigue Trial file parsed
#
# Olmesartan on Ambulatory Blood Pressure Change file parsed
#
# Intraoperative Margin Assessment During Mohs Surgery file added to the dictionary
#
# Workstation Pilot Study file added to the dictionary
#
# Preemptive Genotyping and Pain Management file added to the dictionary
#
# Rapid Assessment of Donor Liver Quality file added to the dictionary
#
# A Study Of Deoxycoformycin(DCF)/Pentostatin In Lymphoid Malignancies file added to the dictionary
#
# Adjuvant Chemotherapy With Docetaxel, Capecitabine and Cisplatin in Patients With Advanced Gastric Cancer file added to the dictionary
#
# Study of Pharmacologic Manipulation of AGE (Advanced Glycation Endproducts) Levels in Prostate Cancer Patients Receiving Androgen Deprivation Therapy file added to the dictionary
#
# Use of Inflammatory Biomarkers to Guide Antibiotic Therapy in Patients With Severe Infections file added to the dictionary
#
# Decitabine and Arsenic Trioxide for Myelodysplastic Syndrome(MDS) file added to the dictionary
#
# Partnering for Prevention: Building Healthy Habits in Underserved Communities file added to the dictionary
#
# Effectiveness of Internet-based Depression Treatment (EVIDENT) in Severe Depression file added to the dictionary
#
# Normal Tissue Oxygenation Following Radiotherapy file added to the dictionary
#
# Yoga for Kyphosis Trial file added to the dictionary
#
# The Safety of Hand Surgery in the Anticoagulated Patient file added to the dictionary
#
# Rituximab, Bortezomib,Bendamustine , Dexamethasone, Patients With Mantle Cell Lymphoma file added to the dictionary
#
# Upfront Bevacizumab/témozolomide for Gliomastomas With Neurological Impairment file added to the dictionary
#
# Antibody Production in Immune Disorders file added to the dictionary
#
# A Study With Lido-Patch and Placebo Plaster in Patients Suffering From Postherpetic Neuralgia (PHN) file added to the dictionary
#
# Does Incremental Initiation of Haemodialysis Preserve Native Kidney Function? file added to the dictionary
#
# Hyperglycemia, Exercise, and Endothelial Function file added to the dictionary
#
# Radiolabeled Monoclonal Antibody, Paclitaxel, and Interferon Alfa in Treating Patients With Recurrent Ovarian Cancer file added to the dictionary
#
# Natural History of Cherubism Observational Study file added to the dictionary
#
# A Cohort Study of the Intestinal Microbiota of Premature Infants file added to the dictionary
#
# Alpha as a Predictive Biomarker file added to the dictionary
#
# Gene Expression in Resectable Pancreatic Cancer file added to the dictionary
#
# Predicting Osteoarthritis Risk Following Knee Injury. file added to the dictionary
#
# Dose Escalation Study of Valortim® (MDX-1303) Administered Intravenously (IV) in Healthy, Normal Subjects file added to the dictionary
#
# Studying the Effect of Changing Immunosuppression in Case of Polyoma BK Virus Infection of the Renal Transplant file added to the dictionary
#
# Psychometric Study of Outcomes Instruments file added to the dictionary
#
# A Study of PRCL-02 in Moderate to Severe Chronic Plaque Psoriasis file added to the dictionary
#
# Predictive Progressive Factors of Adolescent Idiopathic Scoliosis file added to the dictionary
#
# Liver Transplantation Compared to Chemotherapy in Patients With ColoRectal Cancer file added to the dictionary
#
# Adaptive Plasticity Following Rehabilitation in Multiple Sclerosis file added to the dictionary
#
# Telerehabilitation for Attention and Memory in Stroke file added to the dictionary
#
# Fetal Middle Cerebral Artery Doppler in Preterm Births Receiving Magnesium Sulfate for Neuroprotection file added to the dictionary
#
# Mindfulness-Based Stress Reduction for Gulf War Syndrome file added to the dictionary
#
# Study on Left Atrial Function of Paroxysmal Supraventricular Tachycardia After Radiofrequency Ablation file added to the dictionary
#
# Toward Elimination of Hepatitis C Virus (HCV): A Pilot Study file added to the dictionary
#
# Quality Measurement and Improvement Study of Surgical Coronary Revascularization: Secondary Prevention file added to the dictionary
#
# Study to Evaluate the Safety and Efficacy of Denosumab and Actonel® in Post Menopausal Women Transitioned From Alendronate Therapy file added to the dictionary
#
# Paracetamol vs Metoclopramide on Postoperative Nausea and Vomiting file added to the dictionary
#
# A Study of LY2801653 in Healthy Participants Who Are Not Able to Have Children file added to the dictionary
#
# A Study On An Immunostimulant Antibody In Combination With Chemotherapy For Advanced Cancer Of The Pancreas file added to the dictionary
#
# Effect of Single Dose Intranasal Insulin On Cognitive Function file added to the dictionary
#
# Feeding Malnourished Children Different Types of Fatty Acids to Promote Neurocognitive Development file added to the dictionary
#
# Essential Fatty Acids During Complementary Feeding file added to the dictionary
#
# The Usefulness of Coronary CT Scan After Everolimus-eluting Bioabsorbable Scaffold Implantation for Coronary Artery Disease file added to the dictionary
#
# Mechanisms of Inflammatory Liver Injury file added to the dictionary
#
# Lupus Intervention for Fatigue Trial file added to the dictionary
#
# Olmesartan on Ambulatory Blood Pressure Change file added to the dictionary
#
# CPU times: user 2.46 ms, sys: 791 µs, total: 3.25 ms
# Wall time: 2.48 ms
# Dictionary created

# %%
'''
Check number of values for each key before creating a dataframe
'''

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))
# Out:
# nct_id 50
# study_first_submitted 50
# source 50
# brief_title 50

# %%
# Function for adding new tag

def add_new_tags(new_key):
    all_data_dictionary.setdefault(new_key, [])

    for n in all_parsed_files:
            value_conditions = n.find(new_key)
            if n.find(new_key) is not None:
                all_data_dictionary[new_key].append(value_conditions.text)
            else:
                all_data_dictionary[new_key].append('None')

    print('{} tag added'.format(new_key))

# %%
add_new_tags('condition')
add_new_tags('detailed_description/textblock')
add_new_tags('brief_summary/textblock')
# Out:
# condition tag added
# detailed_description/textblock tag added
# brief_summary/textblock tag added

# %%
'''
Check keys and number of values for each one
'''

print(all_data_dictionary.keys())

for key, value in all_data_dictionary.items():
    print(key, len(list(filter(bool, value))))
# Out:
# dict_keys(['nct_id', 'study_first_submitted', 'source', 'brief_title', 'condition', 'detailed_description/textblock', 'brief_summary/textblock'])
# nct_id 50
# study_first_submitted 50
# source 50
# brief_title 50
# condition 50
# detailed_description/textblock 50
# brief_summary/textblock 50

# %% [markdown]
# ## Dump results in a json file

# %%
# Dump dictionary into a JSON file
with open('{}{}.json'.format(path_to_json_file, json_file), 'w') as fp:
    json.dump(all_data_dictionary, fp)
    print('\nJSON file created\n')

    json_size = round(os.path.getsize(path_to_json_file + json_file + '.json') / 1000000, 2)
    print("JSON file: {} Mb".format(json_size))
# Out:
# JSON file created
#
# JSON file: 0.08 Mb

# %% [markdown]
# ## Test: Import json file in a dataframe

# %%
# Import json into a dataframe
file = '{}{}.json'.format(path_to_json_file, json_file)

df = pd.read_json(file)

# %%
df.head()
# Out:
#         nct_id study_first_submitted  \
# 0  NCT02750033        April 20, 2016
# 1  NCT01587092        April 25, 2012
# 2  NCT01813695        March 11, 2013
# 3  NCT03647059        August 9, 2018
# 4  NCT00038025          May 24, 2002
#
#                                               source  \
# 0                            Seton Healthcare Family
# 1              Pennington Biomedical Research Center
# 2     Children's Hospital Medical Center, Cincinnati
# 3  Shanghai General Hospital, Shanghai Jiao Tong ...
# 4                        M.D. Anderson Cancer Center
#
#                                          brief_title  \
# 0  Intraoperative Margin Assessment During Mohs S...
# 1                            Workstation Pilot Study
# 2          Preemptive Genotyping and Pain Management
# 3            Rapid Assessment of Donor Liver Quality
# 4  A Study Of Deoxycoformycin(DCF)/Pentostatin In...
#
#                        condition  \
# 0  Squamous Cell Carcinoma (SCC)
# 1                        Obesity
# 2                           Pain
# 3     Transplant; Failure, Liver
# 4     Peripheral T-cell Lymphoma
#
#                       detailed_description/textblock  \
# 0  \n      Acquire intraoperative MMS measurement...
# 1  \n      Eligible participants will be randomiz...
# 2  \n      Purpose: To determine the feasibility ...
# 3                                               None
# 4  \n      Deoxycoformycin(DCF)/Pentostatin is a ...
#
#                              brief_summary/textblock
# 0  \n      The research team will develop an intr...
# 1  \n      This is a pilot study to assess the fe...
# 2  \n      The purpose of this study is to see if...
# 3  \n      Aims：\n\n        1. Conduct multi-cent...
# 4  \n      The purpose of this study is to determ...

# %%
# rename columns & delete \n values

# %%
df['detailed_description/textblock'][0]
# Out:
# '\n      Acquire intraoperative MMS measurements in vivo. After assessing this approach on excised\n      tissues, MMS measurements will be aquired directly on the patient from the NMSC excision\n      site. MMS data will be acquired on patients being treated for NMSC at the Austin Dermatologic\n      Surgery Center, the surgical site for the dermatology practice of Seton/University of Texas\n      Physicians group. Similar to the measurements on freshly excised tissues, MMS data will be\n      acquired in a grid pattern on the excision site. The site will be blotted with gauze to\n      remove residual blood prior to the measurement, and continuously blotted as needed until all\n      measurements have been taken. The handheld probe of the MMS enables assessment of both the\n      wound periphery and deeper layers of tissue to determine if any tumor is remaining. For this\n      initial pilot study, we plan to take measurements on 10 patients (5 BCC, 5 SCC), along with\n      corresponding normal tissue measurements.\n\n      Retrospective analysis of MMS sensitivity and specificity. The MMS technique is an\n      information rich modality providing both morphological and functional parameters of the\n      interrogated tissue that could be correlated to known tumor pathology. However, this\n      extracted information will require development of sophisticated spectral analysis models\n      which would be beyond the scope of the current study. Therefore, for the purpose of this\n      study, standard statistical techniques will be used to determine the classification power of\n      MMS for tumor margin detection. While this approach does not fully elucidate the underlying\n      pathology responsible for the classification, these types of models have been shown to\n      perform at or better than those based on a morphological approach. This approach has been\n      previously employed to classify skin cancer with high diagnostic accuracy. The final outcome\n      of this study will result in the sensitivity and specificity of MMS compared to\n      histopathology during Mohs surgery. These results will allow for the estimation of the\n      potential benefit of an intraoperative margin assessment technique. This type of\n      retrospective study will provide a proof of concept that would warrant further development\n      and prospective studies of the MMS approach.\n    '

# %%
# Create a new column: study_first_submitted as dates

df['dates'] = pd.to_datetime(df['study_first_submitted'])

# %%
df.head()
# Out:
#         nct_id study_first_submitted  \
# 0  NCT02750033        April 20, 2016
# 1  NCT01587092        April 25, 2012
# 2  NCT01813695        March 11, 2013
# 3  NCT03647059        August 9, 2018
# 4  NCT00038025          May 24, 2002
#
#                                               source  \
# 0                            Seton Healthcare Family
# 1              Pennington Biomedical Research Center
# 2     Children's Hospital Medical Center, Cincinnati
# 3  Shanghai General Hospital, Shanghai Jiao Tong ...
# 4                        M.D. Anderson Cancer Center
#
#                                          brief_title  \
# 0  Intraoperative Margin Assessment During Mohs S...
# 1                            Workstation Pilot Study
# 2          Preemptive Genotyping and Pain Management
# 3            Rapid Assessment of Donor Liver Quality
# 4  A Study Of Deoxycoformycin(DCF)/Pentostatin In...
#
#                        condition  \
# 0  Squamous Cell Carcinoma (SCC)
# 1                        Obesity
# 2                           Pain
# 3     Transplant; Failure, Liver
# 4     Peripheral T-cell Lymphoma
#
#                       detailed_description/textblock  \
# 0  \n      Acquire intraoperative MMS measurement...
# 1  \n      Eligible participants will be randomiz...
# 2  \n      Purpose: To determine the feasibility ...
# 3                                               None
# 4  \n      Deoxycoformycin(DCF)/Pentostatin is a ...
#
#                              brief_summary/textblock      dates
# 0  \n      The research team will develop an intr... 2016-04-20
# 1  \n      This is a pilot study to assess the fe... 2012-04-25
# 2  \n      The purpose of this study is to see if... 2013-03-11
# 3  \n      Aims：\n\n        1. Conduct multi-cent... 2018-08-09
# 4  \n      The purpose of this study is to determ... 2002-05-24
