# %%
import json
import os
import xml.etree.ElementTree as ET
import shutil
import sys
import pandas as pd

# %%
'''
Create paths and folders
'''

# Folders with xml files
# path_to_all_xml_trials = os.path.abspath('../data/all_trials/')

# Folders with sample xml files for testing and debugging
path_to_sample_of_xml_trials = os.path.abspath('../data/sample_trials/')

# Path for json folder
path_to_json_file = os.path.abspath('../data/json/')

# Variable for all parsed files
all_parsed_files = []

#substitute first file with main xml folder
all_folders = [path_to_sample_of_xml_trials, path_to_json_file]

print('\n-------------------------\n')
print('\nPaths and folders created\n')
# Out:
# -------------------------
#
#
# Paths and folders created

# %%
#Function for creating folders

create_folders_errors = []

def create_folders(paths=[]):
    for p in paths:
        try:
            os.mkdir(p)
            if p:
                print('{} created'.format(p))
        except IOError as e:
            create_folders_errors.append(e)
            pass

        print('\n-------------------------\n')
        print('\nFolders created. Except: {}\n'.format(create_folders_errors))

# %%
create_folders(all_folders)
# Out:
# -------------------------
#
#
# Folders created. Except: [FileExistsError(17, 'File exists')]
#
#
# -------------------------
#
#
# Folders created. Except: [FileExistsError(17, 'File exists'), FileExistsError(17, 'File exists')]

# %%
'''
Parse all xml files and save them in all_parsed_files.
Slow. Checks for xml files
'''

def parse_xml_files(path_to_folder):
    for filename in os.listdir(path_to_folder):
        # if not filename.endswith('.xml'): continue
        fullname = os.path.join(path_to_folder, filename)
        all_parsed_files.append(ET.parse(fullname).getroot())

        # Checking message to the terminal
        print("{} file parsed\n".format(fullname))

    print('Number of files parsed: {}\n'.format(len(all_parsed_files)))

    return all_parsed_files

# %%
#substitute argument with main xml folder with all trials
parse_xml_files(path_to_sample_of_xml_trials)
# Out:
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000145.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000151.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000179.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000187.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000178.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000150.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000144.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000152.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000146.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785744.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786264.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786927.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000190.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000147.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000153.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786472.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000157.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000143.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000180.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785796.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785783.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000142.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000156.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786498.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786329.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786459.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786303.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786667.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000168.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000140.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000154.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786511.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786277.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785965.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785757.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000155.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786706.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000169.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786316.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786615.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786173.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000126.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000132.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786563.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786589.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785731.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786238.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786576.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786953.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000133.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000127.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786199.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786628.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785874.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785848.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786602.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000131.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786004.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000125.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000119.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786979.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786212.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785900.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000118.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000124.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000130.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785861.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000108.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000134.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000120.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786940.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785939.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000121.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000135.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786160.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786823.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786758.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000123.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000137.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785913.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000136.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786771.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786017.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000122.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786836.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786407.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000107.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000113.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786797.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786225.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786966.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000112.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000106.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786147.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786186.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786810.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000110.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000104.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000138.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000139.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000105.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000111.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786030.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786420.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786342.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785887.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786381.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000129.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000115.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786550.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786784.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000114.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000128.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786394.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786433.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786355.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000102.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000116.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785926.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000117.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786368.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785835.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785809.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786680.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000170.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000158.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786290.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000159.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000171.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785822.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786654.xml file parsed
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000173.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000167.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785770.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786537.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786251.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000172.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786641.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786862.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786719.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000176.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786043.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000162.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000189.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785952.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785991.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786095.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000188.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000163.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000177.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786056.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786693.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786888.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786485.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786446.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786108.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786134.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786875.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786849.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000149.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000161.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786732.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000175.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786901.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786524.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02785978.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786082.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786914.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000174.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000160.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786069.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT00000148.xml file parsed
#
# /Users/cms/Sites/clinical-trials/mvp/data/sample_trials/NCT02786121.xml file parsed
#
# Number of files parsed: 173
# [<Element 'clinical_study' at 0x116933ef8>,
#  <Element 'clinical_study' at 0x116933f98>,
#  <Element 'clinical_study' at 0x116986a98>,
#  <Element 'clinical_study' at 0x116996b88>,
#  <Element 'clinical_study' at 0x1169a19f8>,
#  <Element 'clinical_study' at 0x1169b7138>,
#  <Element 'clinical_study' at 0x1169bd548>,
#  <Element 'clinical_study' at 0x1169c0ea8>,
#  <Element 'clinical_study' at 0x1169cb228>,
#  <Element 'clinical_study' at 0x1169e74f8>,
#  <Element 'clinical_study' at 0x1169f3958>,
#  <Element 'clinical_study' at 0x116a016d8>,
#  <Element 'clinical_study' at 0x116a3fc28>,
#  <Element 'clinical_study' at 0x116a49818>,
#  <Element 'clinical_study' at 0x116a5e8b8>,
#  <Element 'clinical_study' at 0x116a68048>,
#  <Element 'clinical_study' at 0x116a7b778>,
#  <Element 'clinical_study' at 0x116a7ef48>,
#  <Element 'clinical_study' at 0x116aadf48>,
#  <Element 'clinical_study' at 0x116ab6d68>,
#  <Element 'clinical_study' at 0x116ac0368>,
#  <Element 'clinical_study' at 0x116acde08>,
#  <Element 'clinical_study' at 0x116afbd18>,
#  <Element 'clinical_study' at 0x116b069a8>,
#  <Element 'clinical_study' at 0x116b20cc8>,
#  <Element 'clinical_study' at 0x116b363b8>,
#  <Element 'clinical_study' at 0x116b3de58>,
#  <Element 'clinical_study' at 0x116b484a8>,
#  <Element 'clinical_study' at 0x116b53688>,
#  <Element 'clinical_study' at 0x116b79778>,
#  <Element 'clinical_study' at 0x116b83228>,
#  <Element 'clinical_study' at 0x116b87908>,
#  <Element 'clinical_study' at 0x116b9a098>,
#  <Element 'clinical_study' at 0x116ba1b88>,
#  <Element 'clinical_study' at 0x116bb59a8>,
#  <Element 'clinical_study' at 0x116bbed18>,
#  <Element 'clinical_study' at 0x116bcf548>,
#  <Element 'clinical_study' at 0x116bdf958>,
#  <Element 'clinical_study' at 0x116bee548>,
#  <Element 'clinical_study' at 0x116bfcd68>,
#  <Element 'clinical_study' at 0x116c0ea98>,
#  <Element 'clinical_study' at 0x116c1cf98>,
#  <Element 'clinical_study' at 0x116c31958>,
#  <Element 'clinical_study' at 0x116c3b1d8>,
#  <Element 'clinical_study' at 0x116c4b3b8>,
#  <Element 'clinical_study' at 0x116c5c7c8>,
#  <Element 'clinical_study' at 0x116c76278>,
#  <Element 'clinical_study' at 0x116c82368>,
#  <Element 'clinical_study' at 0x116cbd548>,
#  <Element 'clinical_study' at 0x116cc8b38>,
#  <Element 'clinical_study' at 0x116ce8598>,
#  <Element 'clinical_study' at 0x116ceff48>,
#  <Element 'clinical_study' at 0x116d001d8>,
#  <Element 'clinical_study' at 0x116d08e08>,
#  <Element 'clinical_study' at 0x116d14cc8>,
#  <Element 'clinical_study' at 0x116d1dea8>,
#  <Element 'clinical_study' at 0x116d29318>,
#  <Element 'clinical_study' at 0x116d329a8>,
#  <Element 'clinical_study' at 0x116d5c2c8>,
#  <Element 'clinical_study' at 0x116d93278>,
#  <Element 'clinical_study' at 0x116d98778>,
#  <Element 'clinical_study' at 0x116dab458>,
#  <Element 'clinical_study' at 0x116dba368>,
#  <Element 'clinical_study' at 0x116f16ea8>,
#  <Element 'clinical_study' at 0x116f1f4a8>,
#  <Element 'clinical_study' at 0x116f29db8>,
#  <Element 'clinical_study' at 0x116f3adb8>,
#  <Element 'clinical_study' at 0x116f4b278>,
#  <Element 'clinical_study' at 0x116f47688>,
#  <Element 'clinical_study' at 0x116f7c818>,
#  <Element 'clinical_study' at 0x116f81e08>,
#  <Element 'clinical_study' at 0x116f96b38>,
#  <Element 'clinical_study' at 0x1172719a8>,
#  <Element 'clinical_study' at 0x11727ac78>,
#  <Element 'clinical_study' at 0x11729aa98>,
#  <Element 'clinical_study' at 0x1172a9728>,
#  <Element 'clinical_study' at 0x1172b22c8>,
#  <Element 'clinical_study' at 0x1172c7188>,
#  <Element 'clinical_study' at 0x1172d2868>,
#  <Element 'clinical_study' at 0x1172db278>,
#  <Element 'clinical_study' at 0x117630548>,
#  <Element 'clinical_study' at 0x11765e0e8>,
#  <Element 'clinical_study' at 0x117696598>,
#  <Element 'clinical_study' at 0x1176a30e8>,
#  <Element 'clinical_study' at 0x1176a86d8>,
#  <Element 'clinical_study' at 0x1176ce228>,
#  <Element 'clinical_study' at 0x1176d8a48>,
#  <Element 'clinical_study' at 0x1176dcdb8>,
#  <Element 'clinical_study' at 0x1176ec9a8>,
#  <Element 'clinical_study' at 0x117703138>,
#  <Element 'clinical_study' at 0x117711e58>,
#  <Element 'clinical_study' at 0x117722c78>,
#  <Element 'clinical_study' at 0x11772c188>,
#  <Element 'clinical_study' at 0x11772e5e8>,
#  <Element 'clinical_study' at 0x117741688>,
#  <Element 'clinical_study' at 0x11775def8>,
#  <Element 'clinical_study' at 0x11777df48>,
#  <Element 'clinical_study' at 0x1177874a8>,
#  <Element 'clinical_study' at 0x11778c8b8>,
#  <Element 'clinical_study' at 0x117797728>,
#  <Element 'clinical_study' at 0x1177a7138>,
#  <Element 'clinical_study' at 0x1177b2a98>,
#  <Element 'clinical_study' at 0x1177b7b88>,
#  <Element 'clinical_study' at 0x1177cf098>,
#  <Element 'clinical_study' at 0x1177f41d8>,
#  <Element 'clinical_study' at 0x117804138>,
#  <Element 'clinical_study' at 0x117814188>,
#  <Element 'clinical_study' at 0x11781cdb8>,
#  <Element 'clinical_study' at 0x11782e138>,
#  <Element 'clinical_study' at 0x1178353b8>,
#  <Element 'clinical_study' at 0x117847318>,
#  <Element 'clinical_study' at 0x11785b4f8>,
#  <Element 'clinical_study' at 0x117860e58>,
#  <Element 'clinical_study' at 0x11786c2c8>,
#  <Element 'clinical_study' at 0x117874e08>,
#  <Element 'clinical_study' at 0x11787ebd8>,
#  <Element 'clinical_study' at 0x11789e188>,
#  <Element 'clinical_study' at 0x117888778>,
#  <Element 'clinical_study' at 0x1178ae1d8>,
#  <Element 'clinical_study' at 0x1178b2f98>,
#  <Element 'clinical_study' at 0x1178c07c8>,
#  <Element 'clinical_study' at 0x1178d29a8>,
#  <Element 'clinical_study' at 0x1178fba48>,
#  <Element 'clinical_study' at 0x11790a8b8>,
#  <Element 'clinical_study' at 0x117918778>,
#  <Element 'clinical_study' at 0x117928ae8>,
#  <Element 'clinical_study' at 0x11793c188>,
#  <Element 'clinical_study' at 0x117950368>,
#  <Element 'clinical_study' at 0x117948728>,
#  <Element 'clinical_study' at 0x117974098>,
#  <Element 'clinical_study' at 0x11797e368>,
#  <Element 'clinical_study' at 0x117987278>,
#  <Element 'clinical_study' at 0x1179c6368>,
#  <Element 'clinical_study' at 0x1179c8098>,
#  <Element 'clinical_study' at 0x117afee58>,
#  <Element 'clinical_study' at 0x117b2d728>,
#  <Element 'clinical_study' at 0x117b36db8>,
#  <Element 'clinical_study' at 0x117b66368>,
#  <Element 'clinical_study' at 0x117b76458>,
#  <Element 'clinical_study' at 0x117b81908>,
#  <Element 'clinical_study' at 0x117b957c8>,
#  <Element 'clinical_study' at 0x117ba9d68>,
#  <Element 'clinical_study' at 0x117bb0a98>,
#  <Element 'clinical_study' at 0x117bbe188>,
#  <Element 'clinical_study' at 0x117bc2ea8>,
#  <Element 'clinical_study' at 0x117f5f0e8>,
#  <Element 'clinical_study' at 0x117f7dea8>,
#  <Element 'clinical_study' at 0x117f86c78>,
#  <Element 'clinical_study' at 0x117f8fa48>,
#  <Element 'clinical_study' at 0x117f938b8>,
#  <Element 'clinical_study' at 0x117faf278>,
#  <Element 'clinical_study' at 0x117fba368>,
#  <Element 'clinical_study' at 0x117fc4e08>,
#  <Element 'clinical_study' at 0x117fcfe58>,
#  <Element 'clinical_study' at 0x117fdd728>,
#  <Element 'clinical_study' at 0x117fe6a98>,
#  <Element 'clinical_study' at 0x117ff7958>,
#  <Element 'clinical_study' at 0x11800a5e8>,
#  <Element 'clinical_study' at 0x11801b908>,
#  <Element 'clinical_study' at 0x11802e278>,
#  <Element 'clinical_study' at 0x118033cc8>,
#  <Element 'clinical_study' at 0x11803d408>,
#  <Element 'clinical_study' at 0x118048ef8>,
#  <Element 'clinical_study' at 0x118053c78>,
#  <Element 'clinical_study' at 0x118068458>,
#  <Element 'clinical_study' at 0x1180785e8>,
#  <Element 'clinical_study' at 0x118085a98>,
#  <Element 'clinical_study' at 0x11808f6d8>,
#  <Element 'clinical_study' at 0x11809f548>,
#  <Element 'clinical_study' at 0x1180b12c8>,
#  <Element 'clinical_study' at 0x1180ba408>,
#  <Element 'clinical_study' at 0x1180c81d8>,
#  <Element 'clinical_study' at 0x1180d67c8>]

# %%
'''
Find values by unique tags in XML files
Save them in a dictionary
Export them to a json file
'''

all_data_dictionary = {}
print('\n-------------------------\n')
print('\nCreated all_data_dictionary\n')
# Out:
# -------------------------
#
#
# Created all_data_dictionary

# %%
#function to create dictionary from tags
def create_dictionary_from_tag(tag, parsed_files = all_parsed_files, name_dictionary = all_data_dictionary):

    # Variable to store values
    # keys = []
    values = []

    # Iterate through all xml parsed files and tags, and append data to values
    for n in parsed_files:
        for i in n.iter(tag):
            if i.text != 0:
                values.append(i.text)
            else:
                values.append('nan')
            print("{} file parsed\n".format(i.text))

    # Create dictionary and set tags as keys
    name_dictionary.setdefault(tag, [])

    # Append values to dictionary
    for i in values:
        name_dictionary[tag].append(i)
        print("{} file added to the dictionary\n".format(i))

# %%
#First batch
create_dictionary_from_tag('nct_id')
create_dictionary_from_tag('study_first_submitted')
create_dictionary_from_tag('source')
create_dictionary_from_tag('brief_title')
create_dictionary_from_tag('overall_status')
create_dictionary_from_tag('verification_date')
create_dictionary_from_tag('study_type')
create_dictionary_from_tag('study_first_posted')
create_dictionary_from_tag('last_update_submitted')
create_dictionary_from_tag('last_update_posted')
create_dictionary_from_tag('phase')
# Out:
# NCT00000145 file parsed
#
# NCT00000151 file parsed
#
# NCT00000179 file parsed
#
# NCT00000187 file parsed
#
# NCT00000178 file parsed
#
# NCT00000150 file parsed
#
# NCT00000144 file parsed
#
# NCT00000152 file parsed
#
# NCT00000146 file parsed
#
# NCT02785744 file parsed
#
# NCT02786264 file parsed
#
# NCT02786927 file parsed
#
# NCT00000190 file parsed
#
# NCT00000147 file parsed
#
# NCT00000153 file parsed
#
# NCT02786472 file parsed
#
# NCT00000157 file parsed
#
# NCT00000143 file parsed
#
# NCT00000180 file parsed
#
# NCT02785796 file parsed
#
# NCT02785783 file parsed
#
# NCT00000142 file parsed
#
# NCT00000156 file parsed
#
# NCT02786498 file parsed
#
# NCT02786329 file parsed
#
# NCT02786459 file parsed
#
# NCT02786303 file parsed
#
# NCT02786667 file parsed
#
# NCT00000168 file parsed
#
# NCT00000140 file parsed
#
# NCT00000154 file parsed
#
# NCT02786511 file parsed
#
# NCT02786277 file parsed
#
# NCT02785965 file parsed
#
# NCT02785757 file parsed
#
# NCT00000155 file parsed
#
# NCT02786706 file parsed
#
# NCT00000169 file parsed
#
# NCT02786316 file parsed
#
# NCT02786615 file parsed
#
# NCT02786173 file parsed
#
# NCT00000126 file parsed
#
# NCT00000132 file parsed
#
# NCT02786563 file parsed
#
# NCT02786589 file parsed
#
# NCT02785731 file parsed
#
# NCT02786238 file parsed
#
# NCT02786576 file parsed
#
# NCT02786953 file parsed
#
# NCT00000133 file parsed
#
# NCT00000127 file parsed
#
# NCT02786199 file parsed
#
# NCT02786628 file parsed
#
# NCT02785874 file parsed
#
# NCT02785848 file parsed
#
# NCT02786602 file parsed
#
# NCT00000131 file parsed
#
# NCT02786004 file parsed
#
# NCT00000125 file parsed
#
# NCT00000119 file parsed
#
# NCT02786979 file parsed
#
# NCT02786212 file parsed
#
# NCT02785900 file parsed
#
# NCT00000118 file parsed
#
# NCT00000124 file parsed
#
# NCT00000130 file parsed
#
# NCT02785861 file parsed
#
# NCT00000108 file parsed
#
# NCT00000134 file parsed
#
# NCT00000120 file parsed
#
# NCT02786940 file parsed
#
# NCT02785939 file parsed
#
# NCT00000121 file parsed
#
# NCT00000135 file parsed
#
# NCT02786160 file parsed
#
# NCT02786823 file parsed
#
# NCT02786758 file parsed
#
# NCT00000123 file parsed
#
# NCT00000137 file parsed
#
# NCT02785913 file parsed
#
# NCT00000136 file parsed
#
# NCT02786771 file parsed
#
# NCT02786017 file parsed
#
# NCT00000122 file parsed
#
# NCT02786836 file parsed
#
# NCT02786407 file parsed
#
# NCT00000107 file parsed
#
# NCT00000113 file parsed
#
# NCT02786797 file parsed
#
# NCT02786225 file parsed
#
# NCT02786966 file parsed
#
# NCT00000112 file parsed
#
# NCT00000106 file parsed
#
# NCT02786147 file parsed
#
# NCT02786186 file parsed
#
# NCT02786810 file parsed
#
# NCT00000110 file parsed
#
# NCT00000104 file parsed
#
# NCT00000138 file parsed
#
# NCT00000139 file parsed
#
# NCT00000105 file parsed
#
# NCT00000111 file parsed
#
# NCT02786030 file parsed
#
# NCT02786420 file parsed
#
# NCT02786342 file parsed
#
# NCT02785887 file parsed
#
# NCT02786381 file parsed
#
# NCT00000129 file parsed
#
# NCT00000115 file parsed
#
# NCT02786550 file parsed
#
# NCT02786784 file parsed
#
# NCT00000114 file parsed
#
# NCT00000128 file parsed
#
# NCT02786394 file parsed
#
# NCT02786433 file parsed
#
# NCT02786355 file parsed
#
# NCT00000102 file parsed
#
# NCT00000116 file parsed
#
# NCT02785926 file parsed
#
# NCT00000117 file parsed
#
# NCT02786368 file parsed
#
# NCT02785835 file parsed
#
# NCT02785809 file parsed
#
# NCT02786680 file parsed
#
# NCT00000170 file parsed
#
# NCT00000158 file parsed
#
# NCT02786290 file parsed
#
# NCT00000159 file parsed
#
# NCT00000171 file parsed
#
# NCT02785822 file parsed
#
# NCT02786654 file parsed
#
# NCT00000173 file parsed
#
# NCT00000167 file parsed
#
# NCT02785770 file parsed
#
# NCT02786537 file parsed
#
# NCT02786251 file parsed
#
# NCT00000172 file parsed
#
# NCT02786641 file parsed
#
# NCT02786862 file parsed
#
# NCT02786719 file parsed
#
# NCT00000176 file parsed
#
# NCT02786043 file parsed
#
# NCT00000162 file parsed
#
# NCT00000189 file parsed
#
# NCT02785952 file parsed
#
# NCT02785991 file parsed
#
# NCT02786095 file parsed
#
# NCT00000188 file parsed
#
# NCT00000163 file parsed
#
# NCT00000177 file parsed
#
# NCT02786056 file parsed
#
# NCT02786693 file parsed
#
# NCT02786888 file parsed
#
# NCT02786485 file parsed
#
# NCT02786446 file parsed
#
# NCT02786108 file parsed
#
# NCT02786134 file parsed
#
# NCT02786875 file parsed
#
# NCT02786849 file parsed
#
# NCT00000149 file parsed
#
# NCT00000161 file parsed
#
# NCT02786732 file parsed
#
# NCT00000175 file parsed
#
# NCT02786901 file parsed
#
# NCT02786524 file parsed
#
# NCT02785978 file parsed
#
# NCT02786082 file parsed
#
# NCT02786914 file parsed
#
# NCT00000174 file parsed
#
# NCT00000160 file parsed
#
# NCT02786069 file parsed
#
# NCT00000148 file parsed
#
# NCT02786121 file parsed
#
# NCT00000145 file added to the dictionary
#
# NCT00000151 file added to the dictionary
#
# NCT00000179 file added to the dictionary
#
# NCT00000187 file added to the dictionary
#
# NCT00000178 file added to the dictionary
#
# NCT00000150 file added to the dictionary
#
# NCT00000144 file added to the dictionary
#
# NCT00000152 file added to the dictionary
#
# NCT00000146 file added to the dictionary
#
# NCT02785744 file added to the dictionary
#
# NCT02786264 file added to the dictionary
#
# NCT02786927 file added to the dictionary
#
# NCT00000190 file added to the dictionary
#
# NCT00000147 file added to the dictionary
#
# NCT00000153 file added to the dictionary
#
# NCT02786472 file added to the dictionary
#
# NCT00000157 file added to the dictionary
#
# NCT00000143 file added to the dictionary
#
# NCT00000180 file added to the dictionary
#
# NCT02785796 file added to the dictionary
#
# NCT02785783 file added to the dictionary
#
# NCT00000142 file added to the dictionary
#
# NCT00000156 file added to the dictionary
#
# NCT02786498 file added to the dictionary
#
# NCT02786329 file added to the dictionary
#
# NCT02786459 file added to the dictionary
#
# NCT02786303 file added to the dictionary
#
# NCT02786667 file added to the dictionary
#
# NCT00000168 file added to the dictionary
#
# NCT00000140 file added to the dictionary
#
# NCT00000154 file added to the dictionary
#
# NCT02786511 file added to the dictionary
#
# NCT02786277 file added to the dictionary
#
# NCT02785965 file added to the dictionary
#
# NCT02785757 file added to the dictionary
#
# NCT00000155 file added to the dictionary
#
# NCT02786706 file added to the dictionary
#
# NCT00000169 file added to the dictionary
#
# NCT02786316 file added to the dictionary
#
# NCT02786615 file added to the dictionary
#
# NCT02786173 file added to the dictionary
#
# NCT00000126 file added to the dictionary
#
# NCT00000132 file added to the dictionary
#
# NCT02786563 file added to the dictionary
#
# NCT02786589 file added to the dictionary
#
# NCT02785731 file added to the dictionary
#
# NCT02786238 file added to the dictionary
#
# NCT02786576 file added to the dictionary
#
# NCT02786953 file added to the dictionary
#
# NCT00000133 file added to the dictionary
#
# NCT00000127 file added to the dictionary
#
# NCT02786199 file added to the dictionary
#
# NCT02786628 file added to the dictionary
#
# NCT02785874 file added to the dictionary
#
# NCT02785848 file added to the dictionary
#
# NCT02786602 file added to the dictionary
#
# NCT00000131 file added to the dictionary
#
# NCT02786004 file added to the dictionary
#
# NCT00000125 file added to the dictionary
#
# NCT00000119 file added to the dictionary
#
# NCT02786979 file added to the dictionary
#
# NCT02786212 file added to the dictionary
#
# NCT02785900 file added to the dictionary
#
# NCT00000118 file added to the dictionary
#
# NCT00000124 file added to the dictionary
#
# NCT00000130 file added to the dictionary
#
# NCT02785861 file added to the dictionary
#
# NCT00000108 file added to the dictionary
#
# NCT00000134 file added to the dictionary
#
# NCT00000120 file added to the dictionary
#
# NCT02786940 file added to the dictionary
#
# NCT02785939 file added to the dictionary
#
# NCT00000121 file added to the dictionary
#
# NCT00000135 file added to the dictionary
#
# NCT02786160 file added to the dictionary
#
# NCT02786823 file added to the dictionary
#
# NCT02786758 file added to the dictionary
#
# NCT00000123 file added to the dictionary
#
# NCT00000137 file added to the dictionary
#
# NCT02785913 file added to the dictionary
#
# NCT00000136 file added to the dictionary
#
# NCT02786771 file added to the dictionary
#
# NCT02786017 file added to the dictionary
#
# NCT00000122 file added to the dictionary
#
# NCT02786836 file added to the dictionary
#
# NCT02786407 file added to the dictionary
#
# NCT00000107 file added to the dictionary
#
# NCT00000113 file added to the dictionary
#
# NCT02786797 file added to the dictionary
#
# NCT02786225 file added to the dictionary
#
# NCT02786966 file added to the dictionary
#
# NCT00000112 file added to the dictionary
#
# NCT00000106 file added to the dictionary
#
# NCT02786147 file added to the dictionary
#
# NCT02786186 file added to the dictionary
#
# NCT02786810 file added to the dictionary
#
# NCT00000110 file added to the dictionary
#
# NCT00000104 file added to the dictionary
#
# NCT00000138 file added to the dictionary
#
# NCT00000139 file added to the dictionary
#
# NCT00000105 file added to the dictionary
#
# NCT00000111 file added to the dictionary
#
# NCT02786030 file added to the dictionary
#
# NCT02786420 file added to the dictionary
#
# NCT02786342 file added to the dictionary
#
# NCT02785887 file added to the dictionary
#
# NCT02786381 file added to the dictionary
#
# NCT00000129 file added to the dictionary
#
# NCT00000115 file added to the dictionary
#
# NCT02786550 file added to the dictionary
#
# NCT02786784 file added to the dictionary
#
# NCT00000114 file added to the dictionary
#
# NCT00000128 file added to the dictionary
#
# NCT02786394 file added to the dictionary
#
# NCT02786433 file added to the dictionary
#
# NCT02786355 file added to the dictionary
#
# NCT00000102 file added to the dictionary
#
# NCT00000116 file added to the dictionary
#
# NCT02785926 file added to the dictionary
#
# NCT00000117 file added to the dictionary
#
# NCT02786368 file added to the dictionary
#
# NCT02785835 file added to the dictionary
#
# NCT02785809 file added to the dictionary
#
# NCT02786680 file added to the dictionary
#
# NCT00000170 file added to the dictionary
#
# NCT00000158 file added to the dictionary
#
# NCT02786290 file added to the dictionary
#
# NCT00000159 file added to the dictionary
#
# NCT00000171 file added to the dictionary
#
# NCT02785822 file added to the dictionary
#
# NCT02786654 file added to the dictionary
#
# NCT00000173 file added to the dictionary
#
# NCT00000167 file added to the dictionary
#
# NCT02785770 file added to the dictionary
#
# NCT02786537 file added to the dictionary
#
# NCT02786251 file added to the dictionary
#
# NCT00000172 file added to the dictionary
#
# NCT02786641 file added to the dictionary
#
# NCT02786862 file added to the dictionary
#
# NCT02786719 file added to the dictionary
#
# NCT00000176 file added to the dictionary
#
# NCT02786043 file added to the dictionary
#
# NCT00000162 file added to the dictionary
#
# NCT00000189 file added to the dictionary
#
# NCT02785952 file added to the dictionary
#
# NCT02785991 file added to the dictionary
#
# NCT02786095 file added to the dictionary
#
# NCT00000188 file added to the dictionary
#
# NCT00000163 file added to the dictionary
#
# NCT00000177 file added to the dictionary
#
# NCT02786056 file added to the dictionary
#
# NCT02786693 file added to the dictionary
#
# NCT02786888 file added to the dictionary
#
# NCT02786485 file added to the dictionary
#
# NCT02786446 file added to the dictionary
#
# NCT02786108 file added to the dictionary
#
# NCT02786134 file added to the dictionary
#
# NCT02786875 file added to the dictionary
#
# NCT02786849 file added to the dictionary
#
# NCT00000149 file added to the dictionary
#
# NCT00000161 file added to the dictionary
#
# NCT02786732 file added to the dictionary
#
# NCT00000175 file added to the dictionary
#
# NCT02786901 file added to the dictionary
#
# NCT02786524 file added to the dictionary
#
# NCT02785978 file added to the dictionary
#
# NCT02786082 file added to the dictionary
#
# NCT02786914 file added to the dictionary
#
# NCT00000174 file added to the dictionary
#
# NCT00000160 file added to the dictionary
#
# NCT02786069 file added to the dictionary
#
# NCT00000148 file added to the dictionary
#
# NCT02786121 file added to the dictionary
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# October 29, 1999 file parsed
#
# September 20, 1999 file parsed
#
# October 29, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 25, 2016 file parsed
#
# May 11, 2016 file parsed
#
# May 26, 2016 file parsed
#
# September 20, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 20, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# October 29, 1999 file parsed
#
# May 19, 2016 file parsed
#
# May 25, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 11, 2016 file parsed
#
# May 23, 2016 file parsed
#
# May 4, 2016 file parsed
#
# May 12, 2016 file parsed
#
# May 18, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 26, 2016 file parsed
#
# May 13, 2016 file parsed
#
# May 23, 2016 file parsed
#
# May 25, 2016 file parsed
#
# September 23, 1999 file parsed
#
# May 26, 2016 file parsed
#
# September 23, 1999 file parsed
#
# May 19, 2016 file parsed
#
# May 26, 2016 file parsed
#
# May 17, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 26, 2016 file parsed
#
# May 26, 2016 file parsed
#
# May 25, 2016 file parsed
#
# April 12, 2016 file parsed
#
# May 26, 2016 file parsed
#
# May 18, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# April 5, 2016 file parsed
#
# May 23, 2016 file parsed
#
# May 25, 2016 file parsed
#
# May 25, 2016 file parsed
#
# May 26, 2016 file parsed
#
# September 23, 1999 file parsed
#
# May 24, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 26, 2016 file parsed
#
# May 18, 2016 file parsed
#
# May 25, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 23, 2016 file parsed
#
# January 18, 2000 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# March 21, 2016 file parsed
#
# May 25, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 23, 2016 file parsed
#
# May 25, 2016 file parsed
#
# May 3, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 25, 2016 file parsed
#
# September 23, 1999 file parsed
#
# May 23, 2016 file parsed
#
# May 25, 2016 file parsed
#
# September 23, 1999 file parsed
#
# May 6, 2016 file parsed
#
# May 17, 2016 file parsed
#
# January 18, 2000 file parsed
#
# September 23, 1999 file parsed
#
# May 13, 2016 file parsed
#
# May 18, 2016 file parsed
#
# May 18, 2016 file parsed
#
# January 18, 2000 file parsed
#
# January 18, 2000 file parsed
#
# May 6, 2016 file parsed
#
# May 6, 2016 file parsed
#
# May 17, 2016 file parsed
#
# January 18, 2000 file parsed
#
# November 3, 1999 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# November 3, 1999 file parsed
#
# January 18, 2000 file parsed
#
# May 25, 2016 file parsed
#
# April 14, 2016 file parsed
#
# May 20, 2016 file parsed
#
# March 26, 2014 file parsed
#
# December 4, 2015 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 26, 2016 file parsed
#
# May 23, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 18, 2016 file parsed
#
# May 23, 2016 file parsed
#
# January 27, 2016 file parsed
#
# November 3, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 23, 2016 file parsed
#
# September 23, 1999 file parsed
#
# May 18, 2016 file parsed
#
# May 25, 2016 file parsed
#
# May 25, 2016 file parsed
#
# March 8, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 9, 2016 file parsed
#
# September 23, 1999 file parsed
#
# October 29, 1999 file parsed
#
# May 25, 2016 file parsed
#
# May 26, 2016 file parsed
#
# October 29, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 25, 2016 file parsed
#
# May 17, 2016 file parsed
#
# May 20, 2016 file parsed
#
# October 29, 1999 file parsed
#
# May 26, 2016 file parsed
#
# April 11, 2016 file parsed
#
# May 23, 2016 file parsed
#
# October 29, 1999 file parsed
#
# May 24, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 20, 1999 file parsed
#
# May 25, 2016 file parsed
#
# May 25, 2016 file parsed
#
# May 25, 2016 file parsed
#
# September 20, 1999 file parsed
#
# September 23, 1999 file parsed
#
# October 29, 1999 file parsed
#
# May 25, 2016 file parsed
#
# January 8, 2016 file parsed
#
# May 17, 2016 file parsed
#
# May 26, 2016 file parsed
#
# May 26, 2016 file parsed
#
# May 25, 2016 file parsed
#
# May 20, 2016 file parsed
#
# May 6, 2016 file parsed
#
# May 5, 2016 file parsed
#
# September 23, 1999 file parsed
#
# September 23, 1999 file parsed
#
# June 23, 2014 file parsed
#
# October 29, 1999 file parsed
#
# May 23, 2016 file parsed
#
# May 10, 2016 file parsed
#
# May 11, 2016 file parsed
#
# May 24, 2016 file parsed
#
# May 5, 2016 file parsed
#
# October 29, 1999 file parsed
#
# September 23, 1999 file parsed
#
# May 24, 2016 file parsed
#
# September 23, 1999 file parsed
#
# April 15, 2016 file parsed
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# September 20, 1999 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 11, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# September 20, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 20, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# May 19, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 11, 2016 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# May 4, 2016 file added to the dictionary
#
# May 12, 2016 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 13, 2016 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 19, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 17, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# April 12, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# April 5, 2016 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 24, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# January 18, 2000 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# March 21, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 3, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 6, 2016 file added to the dictionary
#
# May 17, 2016 file added to the dictionary
#
# January 18, 2000 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 13, 2016 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# January 18, 2000 file added to the dictionary
#
# January 18, 2000 file added to the dictionary
#
# May 6, 2016 file added to the dictionary
#
# May 6, 2016 file added to the dictionary
#
# May 17, 2016 file added to the dictionary
#
# January 18, 2000 file added to the dictionary
#
# November 3, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# November 3, 1999 file added to the dictionary
#
# January 18, 2000 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# April 14, 2016 file added to the dictionary
#
# May 20, 2016 file added to the dictionary
#
# March 26, 2014 file added to the dictionary
#
# December 4, 2015 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# January 27, 2016 file added to the dictionary
#
# November 3, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 18, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# March 8, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 9, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 17, 2016 file added to the dictionary
#
# May 20, 2016 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# April 11, 2016 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# May 24, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 20, 1999 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# September 20, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# January 8, 2016 file added to the dictionary
#
# May 17, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 26, 2016 file added to the dictionary
#
# May 25, 2016 file added to the dictionary
#
# May 20, 2016 file added to the dictionary
#
# May 6, 2016 file added to the dictionary
#
# May 5, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# June 23, 2014 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# May 23, 2016 file added to the dictionary
#
# May 10, 2016 file added to the dictionary
#
# May 11, 2016 file added to the dictionary
#
# May 24, 2016 file added to the dictionary
#
# May 5, 2016 file added to the dictionary
#
# October 29, 1999 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# May 24, 2016 file added to the dictionary
#
# September 23, 1999 file added to the dictionary
#
# April 15, 2016 file added to the dictionary
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Institute on Aging (NIA) file parsed
#
# University of Pennsylvania file parsed
#
# National Institute on Aging (NIA) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# New York University School of Medicine file parsed
#
# Yale University file parsed
#
# GlaxoSmithKline file parsed
#
# University of Pennsylvania file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of Kentucky file parsed
#
# National Eye Institute (NEI) file parsed
#
# Johns Hopkins Bloomberg School of Public Health file parsed
#
# National Institute on Aging (NIA) file parsed
#
# Accademia Italiana Medicina Osteopatica file parsed
#
# Portsmouth Hospitals NHS Trust file parsed
#
# Johns Hopkins Bloomberg School of Public Health file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of Maryland file parsed
#
# Institutul Regional de Gastroenterologie & Hepatologie Prof. dr. Octavian Fodor file parsed
#
# University Health Network, Toronto file parsed
#
# CHU de Reims file parsed
#
# University Hospital, Grenoble file parsed
#
# Johns Hopkins Bloomberg School of Public Health file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Celgene file parsed
#
# Yale University file parsed
#
# Dongfang Hospital Beijing University of Chinese Medicine file parsed
#
# Hospices Civils de Lyon file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of Michigan file parsed
#
# National Eye Institute (NEI) file parsed
#
# Hasselt University file parsed
#
# Columbia University file parsed
#
# Metro Health, Michigan file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# AbbVie file parsed
#
# State Key Laboratory of Respiratory Disease file parsed
#
# Angle plc file parsed
#
# Oklahoma State University file parsed
#
# AbbVie file parsed
#
# Vanderbilt University Medical Center file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Taiwan University Hospital file parsed
#
# UNC Lineberger Comprehensive Cancer Center file parsed
#
# Taipei Medical University WanFang Hospital file parsed
#
# Vanderbilt University Medical Center file parsed
#
# CHU de Reims file parsed
#
# National Eye Institute (NEI) file parsed
#
# GE Healthcare file parsed
#
# Washington University School of Medicine file parsed
#
# National Eye Institute (NEI) file parsed
#
# Astellas Pharma Inc file parsed
#
# National Taiwan University Hospital file parsed
#
# Seattle Genetics, Inc. file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Centre Hospitalier Universitaire, Amiens file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# Johns Hopkins Bloomberg School of Public Health file parsed
#
# National Eye Institute (NEI) file parsed
#
# Ottawa Hospital Research Institute file parsed
#
# Southwest Oncology Group file parsed
#
# National Eye Institute (NEI) file parsed
#
# Johns Hopkins Bloomberg School of Public Health file parsed
#
# Glycom A/S file parsed
#
# All India Institute of Medical Sciences, Bhubaneswar file parsed
#
# Macfarlane Burnet Institute for Medical Research and Public Health Ltd file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Southwest Oncology Group file parsed
#
# Johns Hopkins Bloomberg School of Public Health file parsed
#
# Massachusetts General Hospital file parsed
#
# Chinese Academy of Sciences file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of Texas Southwestern Medical Center file parsed
#
# Lanzhou Institute of Biological Products Co., Ltd file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# Stony Brook University file parsed
#
# University of South Florida file parsed
#
# Vanderbilt University file parsed
#
# Ottawa Hospital Research Institute file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# Emory University file parsed
#
# Novartis file parsed
#
# University of Tennessee file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Masonic Cancer Center, University of Minnesota file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# University of Sao Paulo General Hospital file parsed
#
# University of California, Los Angeles file parsed
#
# Istituto Scientifico Romagnolo per lo Studio e la cura dei Tumori file parsed
#
# Azienda USL 4 Prato file parsed
#
# Janssen Pharmaceutica N.V., Belgium file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Chang Gung Memorial Hospital file parsed
#
# University of Salford file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of British Columbia file parsed
#
# Universidade Federal de Pernambuco file parsed
#
# University of British Columbia file parsed
#
# National Center for Research Resources (NCRR) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Centre Hospitalier Universitaire, Amiens file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of British Columbia file parsed
#
# Hospital Universitario de Valme file parsed
#
# Rigshospitalet, Denmark file parsed
#
# University Hospital, Grenoble file parsed
#
# Jaeb Center for Health Research file parsed
#
# National Eye Institute (NEI) file parsed
#
# Zenflow, Inc. file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Institute on Aging (NIA) file parsed
#
# Fundació Institut de Recerca de l'Hospital de la Santa Creu i Sant Pau file parsed
#
# University of Leeds file parsed
#
# National Institute on Aging (NIA) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Pfizer file parsed
#
# University of Florida file parsed
#
# Washington University School of Medicine file parsed
#
# National Institute on Aging (NIA) file parsed
#
# Sun Yat-sen University file parsed
#
# Medical University of Lublin file parsed
#
# Baylor College of Medicine file parsed
#
# National Institute on Aging (NIA) file parsed
#
# Lee's Pharmaceutical Limited file parsed
#
# National Eye Institute (NEI) file parsed
#
# University of Pennsylvania file parsed
#
# Southwest Oncology Group file parsed
#
# Medtronic Bakken Research Center file parsed
#
# Yonsei University file parsed
#
# University of Pennsylvania file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Institute on Aging (NIA) file parsed
#
# Centre Hospitalier Universitaire, Amiens file parsed
#
# University Hospital, Grenoble file parsed
#
# University of Utah file parsed
#
# Bellicum Pharmaceuticals file parsed
#
# Shifa International Hospital file parsed
#
# Zhongda Hospital file parsed
#
# Brigham and Women's Hospital file parsed
#
# National Cancer Institute, Naples file parsed
#
# University of the State of Santa Catarina file parsed
#
# National Eye Institute (NEI) file parsed
#
# National Eye Institute (NEI) file parsed
#
# MedDerm Associates file parsed
#
# National Institute on Aging (NIA) file parsed
#
# Bausch Health Americas, Inc. file parsed
#
# University of Michigan file parsed
#
# Institut de Myologie, France file parsed
#
# Lee's Pharmaceutical Limited file parsed
#
# Assaf-Harofeh Medical Center file parsed
#
# National Institute on Aging (NIA) file parsed
#
# National Eye Institute (NEI) file parsed
#
# Lee's Pharmaceutical Limited file parsed
#
# National Eye Institute (NEI) file parsed
#
# Istituto Ortopedico Rizzoli file parsed
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# University of Pennsylvania file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# New York University School of Medicine file added to the dictionary
#
# Yale University file added to the dictionary
#
# GlaxoSmithKline file added to the dictionary
#
# University of Pennsylvania file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of Kentucky file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Johns Hopkins Bloomberg School of Public Health file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# Accademia Italiana Medicina Osteopatica file added to the dictionary
#
# Portsmouth Hospitals NHS Trust file added to the dictionary
#
# Johns Hopkins Bloomberg School of Public Health file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of Maryland file added to the dictionary
#
# Institutul Regional de Gastroenterologie & Hepatologie Prof. dr. Octavian Fodor file added to the dictionary
#
# University Health Network, Toronto file added to the dictionary
#
# CHU de Reims file added to the dictionary
#
# University Hospital, Grenoble file added to the dictionary
#
# Johns Hopkins Bloomberg School of Public Health file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Celgene file added to the dictionary
#
# Yale University file added to the dictionary
#
# Dongfang Hospital Beijing University of Chinese Medicine file added to the dictionary
#
# Hospices Civils de Lyon file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of Michigan file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Hasselt University file added to the dictionary
#
# Columbia University file added to the dictionary
#
# Metro Health, Michigan file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# AbbVie file added to the dictionary
#
# State Key Laboratory of Respiratory Disease file added to the dictionary
#
# Angle plc file added to the dictionary
#
# Oklahoma State University file added to the dictionary
#
# AbbVie file added to the dictionary
#
# Vanderbilt University Medical Center file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Taiwan University Hospital file added to the dictionary
#
# UNC Lineberger Comprehensive Cancer Center file added to the dictionary
#
# Taipei Medical University WanFang Hospital file added to the dictionary
#
# Vanderbilt University Medical Center file added to the dictionary
#
# CHU de Reims file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# GE Healthcare file added to the dictionary
#
# Washington University School of Medicine file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Astellas Pharma Inc file added to the dictionary
#
# National Taiwan University Hospital file added to the dictionary
#
# Seattle Genetics, Inc. file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Centre Hospitalier Universitaire, Amiens file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# Johns Hopkins Bloomberg School of Public Health file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Ottawa Hospital Research Institute file added to the dictionary
#
# Southwest Oncology Group file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Johns Hopkins Bloomberg School of Public Health file added to the dictionary
#
# Glycom A/S file added to the dictionary
#
# All India Institute of Medical Sciences, Bhubaneswar file added to the dictionary
#
# Macfarlane Burnet Institute for Medical Research and Public Health Ltd file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Southwest Oncology Group file added to the dictionary
#
# Johns Hopkins Bloomberg School of Public Health file added to the dictionary
#
# Massachusetts General Hospital file added to the dictionary
#
# Chinese Academy of Sciences file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of Texas Southwestern Medical Center file added to the dictionary
#
# Lanzhou Institute of Biological Products Co., Ltd file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# Stony Brook University file added to the dictionary
#
# University of South Florida file added to the dictionary
#
# Vanderbilt University file added to the dictionary
#
# Ottawa Hospital Research Institute file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# Emory University file added to the dictionary
#
# Novartis file added to the dictionary
#
# University of Tennessee file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Masonic Cancer Center, University of Minnesota file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# University of Sao Paulo General Hospital file added to the dictionary
#
# University of California, Los Angeles file added to the dictionary
#
# Istituto Scientifico Romagnolo per lo Studio e la cura dei Tumori file added to the dictionary
#
# Azienda USL 4 Prato file added to the dictionary
#
# Janssen Pharmaceutica N.V., Belgium file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Chang Gung Memorial Hospital file added to the dictionary
#
# University of Salford file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of British Columbia file added to the dictionary
#
# Universidade Federal de Pernambuco file added to the dictionary
#
# University of British Columbia file added to the dictionary
#
# National Center for Research Resources (NCRR) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Centre Hospitalier Universitaire, Amiens file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of British Columbia file added to the dictionary
#
# Hospital Universitario de Valme file added to the dictionary
#
# Rigshospitalet, Denmark file added to the dictionary
#
# University Hospital, Grenoble file added to the dictionary
#
# Jaeb Center for Health Research file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Zenflow, Inc. file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# Fundació Institut de Recerca de l'Hospital de la Santa Creu i Sant Pau file added to the dictionary
#
# University of Leeds file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Pfizer file added to the dictionary
#
# University of Florida file added to the dictionary
#
# Washington University School of Medicine file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# Sun Yat-sen University file added to the dictionary
#
# Medical University of Lublin file added to the dictionary
#
# Baylor College of Medicine file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# Lee's Pharmaceutical Limited file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# University of Pennsylvania file added to the dictionary
#
# Southwest Oncology Group file added to the dictionary
#
# Medtronic Bakken Research Center file added to the dictionary
#
# Yonsei University file added to the dictionary
#
# University of Pennsylvania file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# Centre Hospitalier Universitaire, Amiens file added to the dictionary
#
# University Hospital, Grenoble file added to the dictionary
#
# University of Utah file added to the dictionary
#
# Bellicum Pharmaceuticals file added to the dictionary
#
# Shifa International Hospital file added to the dictionary
#
# Zhongda Hospital file added to the dictionary
#
# Brigham and Women's Hospital file added to the dictionary
#
# National Cancer Institute, Naples file added to the dictionary
#
# University of the State of Santa Catarina file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# MedDerm Associates file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# Bausch Health Americas, Inc. file added to the dictionary
#
# University of Michigan file added to the dictionary
#
# Institut de Myologie, France file added to the dictionary
#
# Lee's Pharmaceutical Limited file added to the dictionary
#
# Assaf-Harofeh Medical Center file added to the dictionary
#
# National Institute on Aging (NIA) file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Lee's Pharmaceutical Limited file added to the dictionary
#
# National Eye Institute (NEI) file added to the dictionary
#
# Istituto Ortopedico Rizzoli file added to the dictionary
#
# Age-Related Eye Disease Study (AREDS) file parsed
#
# Early Treatment Diabetic Retinopathy Study (ETDRS) file parsed
#
# Agitation in Alzheimer's Disease file parsed
#
# Ritanserin in Treatment of Cocaine Dependence - 1 file parsed
#
# Multicenter Trial of Prednisone in Alzheimer's Disease file parsed
#
# Submacular Surgery Trials (SST) file parsed
#
# Glaucoma Laser Trial (GLT) Glaucoma Laser Trial Followup Study (GLTFS) file parsed
#
# Randomized Trial of Beta-Carotene and Macular Degeneration file parsed
#
# Optic Neuritis Treatment Trial (ONTT) file parsed
#
# Genzyme Osteopenia/Osteoporosis Study file parsed
#
# Association of Type of Anesthetic and Outcomes in Transfemoral Aortic Valve Replacement file parsed
#
# Preference Attributes of ELLIPTA Dry Powder Inhaler (DPI) and HANDIHALER DPI in Subjects With Chronic Obstructive Pulmonary Disease (COPD) file parsed
#
# Cocaine in Parotid Saliva, Blood and Urine - 4 file parsed
#
# Longitudinal Optic Neuritis Study (LONS) file parsed
#
# Krypton-Argon Regression of Neovascularization Study (KARNS) file parsed
#
# ConnectEd: A Randomized Controlled Trial Connecting Through Educational Training file parsed
#
# Randomized Trial of Aspirin and Cataracts in U.S. Physicians file parsed
#
# Studies of Ocular Complications of AIDS (SOCA)--Ganciclovir-Cidofovir CMV Retinitis Trial (GCCRT) file parsed
#
# AIT-082 Phase 1B Study file parsed
#
# Effect of Cranial Manipulation on ANS Activity file parsed
#
# Endorings™ Assisted Colonoscopy Versus Standard Colonoscopy for Polyp Detection file parsed
#
# Studies of the Ocular Complications of AIDS (SOCA)--HPMPC Peripheral CMV Retinitis Trial (HPCRT) file parsed
#
# The Effects of Light Reduction on Retinopathy of Prematurity (Light-ROP) file parsed
#
# Optimal Vitamin D3 Supplementation Strategies for Acute Fracture Healing file parsed
#
# Anesthesia and Postoperative Outcome in Colorectal Cancer Patients file parsed
#
# Detection and Localization of Carcinoma Using High Resolution Transrectal Imaging - Proof of Concept Study file parsed
#
# Interest of Whole-body MRI Correlated to Spreading Sequences for Staging Neuroendocrine Tumors file parsed
#
# Non Motors Aspects in De Novo Parkinson's Disease file parsed
#
# Longitudinal Study of Ocular Complications of AIDS (LSOCA) file parsed
#
# The Silicone Study file parsed
#
# Diabetic Retinopathy Vitrectomy Study (DRVS) file parsed
#
# Longterm Follow-up of Subjects Treated With bb2121 file parsed
#
# Learning Alerts for Acute Kidney Injury file parsed
#
# Acupuncture in the Regulation of Dai Meridian for Polycystic Ovarian Syndrome Patients With Abdominal Obesity file parsed
#
# Cancer-related Thromboembolic Disease file parsed
#
# The Collaborative Longitudinal Evaluation of Keratoconus (CLEK) Study file parsed
#
# Automated Measurement of Optic Nerve Sheath Diameter file parsed
#
# The Collaborative Longitudinal Evaluation of Ethnicity and Refractive Error (CLEERE) Study file parsed
#
# High Intensity Training With Non-specific Chronic Low Back Pain file parsed
#
# Increasing MSM in the Continuum of Care in Kazakhstan file parsed
#
# Peripheral Registry of Endovascular Clinical Outcomes "The PRIME Registry" file parsed
#
# Ischemic Optic Neuropathy Decompression Trial Followup (IONDT Followup) file parsed
#
# Early Manifest Glaucoma Trial (EMGT) file parsed
#
# Changes in Ultrasonographic Assessment of Inflammation Upon Initiation of Adalimumab Combination Therapy in Chinese Rheumatoid Arthritis (RA) Patients With Inadequate Response to Methotrexate file parsed
#
# Plasmodium Immunotherapy for Lung Cancer file parsed
#
# Evaluation of Multiple Biomarkers to Estimate Risk of Ovarian Cancer in Patients With a Pelvic Mass. file parsed
#
# Cognitive and Self-regulatory Mechanisms Of Obesity Study file parsed
#
# Effectiveness of Adalimumab in Moderate to Severe HidrAdenitis SuppuRativa Patients - a Multi cOuNtry studY in Real Life Setting file parsed
#
# Sleep Promotion to Improve Diabetes Management in Adolescents With T1D file parsed
#
# Cryotherapy for Retinopathy of Prematurity (CRYO-ROP) - Outcome Study of Cryotherapy for Retinopathy of Prematurity file parsed
#
# Ischemic Optic Neuropathy Decompression Trial (IONDT) file parsed
#
# Histological Differentiation Grade Predicted by Ultrasound Backscatterer Imaging file parsed
#
# Assessing Physical Fitness in Cancer Patients With Cardiopulmonary Exercise Testing and Wearable Data Generation file parsed
#
# Statin With Palliative Therapy for HCC file parsed
#
# Identifying Barriers and Strategies to Support Self-efficacy for Medication Adherence With Text Messaging file parsed
#
# LRP1 Methylation and Colon Cancer file parsed
#
# Central Vein Occlusion Study (CVOS) file parsed
#
# Image Quality Assessment for Screening and Diagnostic Mammography file parsed
#
# Ocular Hypertension Treatment Study (OHTS) file parsed
#
# Safety and Efficacy of a Heparin-Coated Intraocular Lens in Uveitis file parsed
#
# Efficacy and Safety of Dorner Tablets and Aspirin for Prevention of Arteriosclerosis Progress in Type 2 Diabetes Mellitus Patients file parsed
#
# The Effects of Dexmedetomidine on Intestine and Other Organ Damages After Cardiac Surgeries file parsed
#
# Vadastuximab Talirine (SGN-CD33A; 33A) Combined With Azacitidine or Decitabine in Older Patients With Newly Diagnosed Acute Myeloid Leukemia file parsed
#
# Ganciclovir Implant Study for Cytomegalovirus Retinitis file parsed
#
# Collaborative Ocular Melanoma Study (COMS) file parsed
#
# Endophthalmitis Vitrectomy Study (EVS) file parsed
#
# ...
#
# October 10, 2017 file parsed
#
# September 5, 2018 file parsed
#
# January 17, 2018 file parsed
#
# December 9, 2005 file parsed
#
# June 2, 2006 file parsed
#
# May 30, 2016 file parsed
#
# June 5, 2006 file parsed
#
# August 7, 2017 file parsed
#
# January 23, 2009 file added to the dictionary
#
# September 4, 2006 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# May 28, 2015 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# June 5, 2006 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 5, 2006 file added to the dictionary
#
# January 29, 2019 file added to the dictionary
#
# October 26, 2016 file added to the dictionary
#
# October 15, 2018 file added to the dictionary
#
# May 28, 2015 file added to the dictionary
#
# May 29, 2006 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# March 14, 2019 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# March 14, 2016 file added to the dictionary
#
# December 11, 2009 file added to the dictionary
#
# January 26, 2017 file added to the dictionary
#
# February 4, 2019 file added to the dictionary
#
# November 17, 2015 file added to the dictionary
#
# June 5, 2006 file added to the dictionary
#
# March 4, 2019 file added to the dictionary
#
# August 8, 2018 file added to the dictionary
#
# February 28, 2018 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# October 26, 2017 file added to the dictionary
#
# June 12, 2015 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# August 31, 2018 file added to the dictionary
#
# June 26, 2018 file added to the dictionary
#
# September 12, 2017 file added to the dictionary
#
# January 17, 2019 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 5, 2018 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# September 19, 2016 file added to the dictionary
#
# February 7, 2017 file added to the dictionary
#
# March 29, 2019 file added to the dictionary
#
# May 26, 2006 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# November 26, 2018 file added to the dictionary
#
# March 19, 2018 file added to the dictionary
#
# November 9, 2018 file added to the dictionary
#
# May 15, 2018 file added to the dictionary
#
# January 16, 2019 file added to the dictionary
#
# April 5, 2019 file added to the dictionary
#
# February 4, 2014 file added to the dictionary
#
# March 24, 2010 file added to the dictionary
#
# May 30, 2016 file added to the dictionary
#
# March 22, 2018 file added to the dictionary
#
# April 19, 2017 file added to the dictionary
#
# August 8, 2018 file added to the dictionary
#
# March 3, 2017 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# November 7, 2018 file added to the dictionary
#
# June 6, 2018 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 21, 2016 file added to the dictionary
#
# November 4, 2016 file added to the dictionary
#
# December 12, 2018 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# June 2, 2006 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# September 14, 2015 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# April 28, 2017 file added to the dictionary
#
# January 4, 2019 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# November 17, 2015 file added to the dictionary
#
# December 13, 2018 file added to the dictionary
#
# September 19, 2017 file added to the dictionary
#
# September 21, 2017 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# March 6, 2019 file added to the dictionary
#
# October 22, 2015 file added to the dictionary
#
# May 16, 2018 file added to the dictionary
#
# January 25, 2019 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# January 28, 2019 file added to the dictionary
#
# January 3, 2018 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# April 15, 2016 file added to the dictionary
#
# May 13, 2019 file added to the dictionary
#
# April 30, 2019 file added to the dictionary
#
# September 7, 2018 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# April 20, 2018 file added to the dictionary
#
# December 21, 2018 file added to the dictionary
#
# May 10, 2018 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# March 24, 2010 file added to the dictionary
#
# November 29, 2017 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# April 27, 2018 file added to the dictionary
#
# October 11, 2018 file added to the dictionary
#
# November 9, 2018 file added to the dictionary
#
# February 15, 2019 file added to the dictionary
#
# November 22, 2016 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# June 23, 2016 file added to the dictionary
#
# September 26, 2016 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# May 16, 2017 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# December 28, 2018 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# August 3, 2016 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# May 11, 2017 file added to the dictionary
#
# May 22, 2018 file added to the dictionary
#
# May 30, 2016 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# March 6, 2014 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# February 6, 2019 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# February 25, 2019 file added to the dictionary
#
# June 6, 2016 file added to the dictionary
#
# December 11, 2009 file added to the dictionary
#
# March 24, 2010 file added to the dictionary
#
# December 28, 2018 file added to the dictionary
#
# April 29, 2019 file added to the dictionary
#
# January 4, 2019 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# July 12, 2018 file added to the dictionary
#
# February 22, 2018 file added to the dictionary
#
# November 5, 2010 file added to the dictionary
#
# May 30, 2016 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# May 28, 2015 file added to the dictionary
#
# August 31, 2018 file added to the dictionary
#
# September 5, 2018 file added to the dictionary
#
# June 20, 2018 file added to the dictionary
#
# May 28, 2015 file added to the dictionary
#
# September 17, 2009 file added to the dictionary
#
# December 11, 2009 file added to the dictionary
#
# August 10, 2018 file added to the dictionary
#
# October 10, 2018 file added to the dictionary
#
# October 26, 2017 file added to the dictionary
#
# February 1, 2019 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# June 7, 2016 file added to the dictionary
#
# May 8, 2018 file added to the dictionary
#
# October 9, 2017 file added to the dictionary
#
# September 22, 2016 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 24, 2005 file added to the dictionary
#
# June 1, 2016 file added to the dictionary
#
# December 11, 2009 file added to the dictionary
#
# April 11, 2018 file added to the dictionary
#
# March 21, 2019 file added to the dictionary
#
# October 10, 2017 file added to the dictionary
#
# September 5, 2018 file added to the dictionary
#
# January 17, 2018 file added to the dictionary
#
# December 9, 2005 file added to the dictionary
#
# June 2, 2006 file added to the dictionary
#
# May 30, 2016 file added to the dictionary
#
# June 5, 2006 file added to the dictionary
#
# August 7, 2017 file added to the dictionary
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 4 file parsed
#
# Phase 1 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 1 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 2/Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Early Phase 1 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 1/Phase 2 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Phase 4 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
# Phase 2/Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 2/Phase 3 file parsed
#
# N/A file parsed
#
# Phase 2/Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 1/Phase 2 file parsed
#
# Phase 3 file parsed
#
# Phase 2/Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 2 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 1 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Phase 4 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 1/Phase 2 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 4 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 1 file parsed
#
# Phase 4 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 1 file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Phase 3 file parsed
#
# Phase 2 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 1 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# Phase 3 file parsed
#
# N/A file parsed
#
# N/A file parsed
#
# Phase 1 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file parsed
#
# Phase 1 file parsed
#
# Phase 3 file parsed
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 4 file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 2/Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Early Phase 1 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 1/Phase 2 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Phase 4 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 2/Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2/Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 2/Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 1/Phase 2 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2/Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Phase 4 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 1/Phase 2 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 4 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# Phase 4 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 2 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# N/A file added to the dictionary
#
# N/A file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 3 file added to the dictionary
#
# Phase 1 file added to the dictionary
#
# Phase 3 file added to the dictionary

# %%
# Function for adding nested tags

def add_new_tags(new_key):
    all_data_dictionary.setdefault(new_key, [])

    for n in all_parsed_files:
            value_conditions = n.find(new_key)
            if n.find(new_key) is not None:
                all_data_dictionary[new_key].append(value_conditions.text)
            else:
                all_data_dictionary[new_key].append('None')

    print('{} tag added'.format(new_key))

# %%
add_new_tags('condition')
add_new_tags('condition_browse/mesh_term')
add_new_tags('intervention_browse/mesh_term')
add_new_tags('detailed_description/textblock')
add_new_tags('brief_summary/textblock')
add_new_tags('location/facility/address/city')
add_new_tags('location/facility/address/country')
add_new_tags('location/facility/address/zip')
add_new_tags('sponsors/lead_sponsor')
add_new_tags('sponsors/agency_class')
add_new_tags('collaborator/agency')
add_new_tags('collaborator/agency_class')
add_new_tags('study_design_info/allocation')
add_new_tags('study_design_info/intervention_model')
add_new_tags('study_design_info/primary_purpose')
# add_new_tags('reference/citation')
# Out:
# condition tag added
# condition_browse/mesh_term tag added
# intervention_browse/mesh_term tag added
# detailed_description/textblock tag added
# brief_summary/textblock tag added
# location/facility/address/city tag added
# location/facility/address/country tag added
# location/facility/address/zip tag added
# sponsors/lead_sponsor tag added
# sponsors/agency_class tag added
# collaborator/agency tag added
# collaborator/agency_class tag added
# study_design_info/allocation tag added
# study_design_info/intervention_model tag added
# study_design_info/primary_purpose tag added

# %%
def check_values_key():
    print('\nChecking values by key\n')

    # Check number of values by key
    for key, value in all_data_dictionary.items():
        print(key, len(list(filter(bool, value))))

# %%
#All values need to match for JSON file
check_values_key()
# Out:
# Checking values by key
#
# nct_id 173
# study_first_submitted 173
# source 173
# brief_title 173
# overall_status 173
# verification_date 173
# study_type 173
# study_first_posted 173
# last_update_submitted 173
# last_update_posted 173
# phase 137
# condition 173
# condition_browse/mesh_term 173
# intervention_browse/mesh_term 173
# detailed_description/textblock 173
# brief_summary/textblock 173
# location/facility/address/city 173
# location/facility/address/country 173
# location/facility/address/zip 173
# sponsors/lead_sponsor 173
# sponsors/agency_class 173
# collaborator/agency 173
# collaborator/agency_class 173
# study_design_info/allocation 173
# study_design_info/intervention_model 173
# study_design_info/primary_purpose 173

# %% [markdown]
# ### Put all data from dictionary in a Dataframe, fill none values

# %%
df = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in all_data_dictionary.items()]))

# %%
pd.set_option('display.max_columns', 500)
df.sample(10)
# Out:
#           nct_id study_first_submitted  \
# 28   NCT00000168    September 23, 1999
# 74   NCT02786160          May 23, 2016
# 18   NCT00000180      October 29, 1999
# 64   NCT00000124    September 23, 1999
# 165  NCT02785978          May 11, 2016
# 46   NCT02786238        April 12, 2016
# 91   NCT00000112      January 18, 2000
# 57   NCT02786004          May 24, 2016
# 148  NCT00000163    September 23, 1999
# 38   NCT02786316          May 19, 2016
#
#                                               source  \
# 28   Johns Hopkins Bloomberg School of Public Health
# 74                                        Glycom A/S
# 18                 National Institute on Aging (NIA)
# 64                      National Eye Institute (NEI)
# 165                     Institut de Myologie, France
# 46                         Oklahoma State University
# 91     National Center for Research Resources (NCRR)
# 57                                     GE Healthcare
# 148                     National Eye Institute (NEI)
# 38                                Hasselt University
#
#                                            brief_title  \
# 28   Longitudinal Study of Ocular Complications of ...
# 74   Effects of HMOs on the Faecal Microbiota and o...
# 18                              AIT-082 Phase 1B Study
# 64          Collaborative Ocular Melanoma Study (COMS)
# 165  Pilot Study to Evaluate ActiMyo Measured Activ...
# 46   Cognitive and Self-regulatory Mechanisms Of Ob...
# 91   Prevalence of Carbohydrate Intolerance in Lean...
# 57   Image Quality Assessment for Screening and Dia...
# 148    Congenital Esotropia Observational Study (CEOS)
# 38   High Intensity Training With Non-specific Chro...
#
#              overall_status verification_date      study_type  \
# 28                Completed         June 2015   Observational
# 74                Completed     December 2018  Interventional
# 18                Completed     February 2005  Interventional
# 64           Unknown status         June 2002  Interventional
# 165               Completed      October 2017  Interventional
# 46   Active, not recruiting          May 2018  Interventional
# 91           Unknown status     December 2003   Observational
# 57                Completed      October 2018  Interventional
# 148               Completed    September 2009   Observational
# 38                Completed    September 2016  Interventional
#
#      study_first_posted last_update_submitted  last_update_posted  \
# 28   September 24, 1999         June 10, 2015       June 12, 2015
# 74         May 30, 2016     December 11, 2018   December 13, 2018
# 18     November 1, 1999     December 10, 2009   December 11, 2009
# 64   September 24, 1999          June 1, 2006        June 2, 2006
# 165        May 30, 2016       October 9, 2017    October 10, 2017
# 46         May 30, 2016           May 9, 2018        May 15, 2018
# 91     January 19, 2000         June 23, 2005       June 24, 2005
# 57         May 30, 2016      October 10, 2018    November 7, 2018
# 148  September 24, 1999    September 16, 2009  September 17, 2009
# 38         June 1, 2016    September 16, 2016  September 19, 2016
#
#                phase          condition condition_browse/mesh_term  \
# 28               N/A     HIV Infections             HIV Infections
# 74               N/A            Obesity                       None
# 18               N/A   Memory Disorders           Memory Disorders
# 64           Phase 3  Choroid Neoplasms                    Uveitis
# 165              NaN  Parkinson Disease          Parkinson Disease
# 46               N/A            Obesity                    Obesity
# 91   Phase 1/Phase 2            Obesity        Glucose Intolerance
# 57           Phase 3      Breast Health                       None
# 148              NaN          Esotropia                  Esotropia
# 38               N/A      Low Back Pain                  Back Pain
#
#     intervention_browse/mesh_term  \
# 28                           None
# 74                           None
# 18                           None
# 64                           None
# 165                      Levodopa
# 46                           None
# 91                           None
# 57                           None
# 148                          None
# 38                           None
#
#                         detailed_description/textblock  \
# 28   \n      Ocular abnormalities in patients with ...
# 74                                                None
# 18                                                None
# 64   \n      For more than 100 years, removal of th...
# 165                                               None
# 46   \n      This K23 award will allow Dr. Misty Ha...
# 91                                                None
# 57                                                None
# 148  \n      Congenital esotropia is the most commo...
# 38                                                None
#
#                                brief_summary/textblock  \
# 28   \n      To monitor trends over time, in the in...
# 74   \n      The study is a randomised, placebo-con...
# 18   \n      AIT-082 is a novel small molecule that...
# 64   \n      To evaluate therapeutic interventions ...
# 165  \n      Pre-QuantiPark is a pilot study to eva...
# 46   \n      This study will be the first clinical ...
# 91   \n      The prevalence of obesity in children ...
# 57   \n      This study is being conducted to deter...
# 148  \n      To observe the early course of congeni...
# 38   \n      Low back pain is a common disorder, oc...
#
#     location/facility/address/city location/facility/address/country  \
# 28                          Irvine                     United States
# 74                         Holbaek                           Denmark
# 18                       San Diego                     United States
# 64                            None                              None
# 165                        Creteil                            France
# 46                            None                              None
# 91                       New Haven                     United States
# 57                      Greenville                     United States
# 148                           None                              None
# 38                         Hasselt                           Belgium
#
#     location/facility/address/zip sponsors/lead_sponsor sponsors/agency_class  \
# 28                     92697-4375              \n                        None
# 74                           4300              \n                        None
# 18                     92093-0949              \n                        None
# 64                           None              \n                        None
# 165                         94010              \n                        None
# 46                           None              \n                        None
# 91                     06520-8064              \n                        None
# 57                          27834              \n                        None
# 148                          None              \n                        None
# 38                           3500              \n                        None
#
#     collaborator/agency collaborator/agency_class  \
# 28                 None                      None
# 74                 None                      None
# 18                 None                      None
# 64                 None                      None
# 165                None                      None
# 46                 None                      None
# 91                 None                      None
# 57                 None                      None
# 148                None                      None
# 38                 None                      None
#
#     study_design_info/allocation study_design_info/intervention_model  \
# 28                          None                                 None
# 74                    Randomized                  Parallel Assignment
# 18                    Randomized                                 None
# 64                    Randomized                                 None
# 165               Non-Randomized                  Parallel Assignment
# 46                    Randomized                  Parallel Assignment
# 91                          None                                 None
# 57                Non-Randomized                  Parallel Assignment
# 148                         None                                 None
# 38                Non-Randomized                  Parallel Assignment
#
#     study_design_info/primary_purpose
# 28                               None
# 74                      Basic Science
# 18                          Treatment
# 64                          Treatment
# 165                             Other
# 46                          Treatment
# 91                               None
# 57                         Diagnostic
# 148                              None
# 38                          Treatment

# %%
df.to_json(r'all_json.json')

# %%
# Load json file into new dataframe
df_json = pd.read_json('all_json.json')

# %%
df_json.shape
# Out:
# (173, 26)

# %%
df_json.head()
# Out:
#           nct_id study_first_submitted  \
# 0    NCT00000145    September 23, 1999
# 1    NCT00000151    September 23, 1999
# 10   NCT02786264          May 11, 2016
# 100  NCT00000105      November 3, 1999
# 101  NCT00000111      January 18, 2000
#
#                                              source  \
# 0                      National Eye Institute (NEI)
# 1                      National Eye Institute (NEI)
# 10                                  Yale University
# 100  Masonic Cancer Center, University of Minnesota
# 101   National Center for Research Resources (NCRR)
#
#                                            brief_title  \
# 0                Age-Related Eye Disease Study (AREDS)
# 1    Early Treatment Diabetic Retinopathy Study (ET...
# 10   Association of Type of Anesthetic and Outcomes...
# 100  Vaccination With Tetanus and KLH to Assess Imm...
# 101  Intraoral Grafting of Ex Vivo Produced Oral Mu...
#
#              overall_status verification_date      study_type  \
# 0                 Completed      January 2009  Interventional
# 1                 Completed      October 2003  Interventional
# 10   Active, not recruiting      October 2016   Observational
# 100              Terminated     November 2017   Observational
# 101          Unknown status    September 2000  Interventional
#
#      study_first_posted last_update_submitted last_update_posted    phase  \
# 0    September 24, 1999      January 21, 2009   January 23, 2009  Phase 3
# 1    September 24, 1999     September 1, 2006  September 4, 2006  Phase 3
# 10         May 30, 2016      October 24, 2016   October 26, 2016  Phase 1
# 100    November 4, 1999     November 27, 2017  November 29, 2017  Phase 3
# 101    January 19, 2000         June 23, 2005      June 24, 2005  Phase 4
#
#                 condition condition_browse/mesh_term  \
# 0    Macular Degeneration       Macular Degeneration
# 1               Blindness           Retinal Diseases
# 10        Aortic Stenosis      Aortic Valve Stenosis
# 100                Cancer                       None
# 101        Mouth Diseases             Mouth Diseases
#
#     intervention_browse/mesh_term  \
# 0                            Zinc
# 1                            None
# 10                    Anesthetics
# 100             Freund's Adjuvant
# 101                          None
#
#                         detailed_description/textblock  \
# 0    \n      AMD and cataract are the leading cause...
# 1    \n      ETDRS was a multicenter, randomized cl...
# 10   \n      This study proposes to perform a descr...
# 100  \n      Patients will receive each vaccine onc...
# 101                                               None
#
#                                brief_summary/textblock  \
# 0    \n      To assess the clinical course, prognos...
# 1    \n      To evaluate the effectiveness of both ...
# 10   \n      This study proposes to perform a descr...
# 100  \n      The purpose of this study is to learn ...
# 101  \n      The purpose of this study is to see if...
#
#     location/facility/address/city location/facility/address/country  \
# 0                             None                              None
# 1                             None                              None
# 10                            None                              None
# 100                    Minneapolis                     United States
# 101                           None                              None
#
#     location/facility/address/zip sponsors/lead_sponsor sponsors/agency_class  \
# 0                            None              \n                        None
# 1                            None              \n                        None
# 10                           None              \n                        None
# 100                         55455              \n                        None
# 101                          None              \n                        None
#
#     collaborator/agency collaborator/agency_class  \
# 0                  None                      None
# 1                  None                      None
# 10                 None                      None
# 100                None                      None
# 101                None                      None
#
#     study_design_info/allocation study_design_info/intervention_model  \
# 0                     Randomized                 Factorial Assignment
# 1                     Randomized                                 None
# 10                          None                                 None
# 100                         None                                 None
# 101                   Randomized                  Parallel Assignment
#
#     study_design_info/primary_purpose
# 0                           Treatment
# 1                           Treatment
# 10                               None
# 100                              None
# 101                         Treatment
